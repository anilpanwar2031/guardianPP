# %%
import tabula
import pdfplumber
import pandas as pd
import numpy as np

# %%
pdf_path = "guardianclaim3.pdf"
# pdf_path = "pdf//5.pdf"

# %%
def extract_text_coordinates(pdf_path):
    text_list = []
    with pdfplumber.open(pdf_path) as pdf:
        # Iterate through each page of the PDF
        for page_number in range(len(pdf.pages)):
            page = pdf.pages[page_number]
            page_number = page_number + 1
            # Extract the text content and its coordinates
            for element in page.extract_words(x_tolerance=1, y_tolerance=1, keep_blank_chars=True):
                text_dict = {}
                text = element["text"]
                x, y = element["x0"], element["top"]
                
                text_cord = f"Page {page_number + 1}: Text: {text} Coordinates: X={x}, Y={y}"
                text_dict.update({'page':page_number, 'text':text,'cordx':x,'cordy':y})
                text_list.append(text_dict)
    return text_list

text_list = extract_text_coordinates(pdf_path)

# %%
text_list
# Out:
# [{'page': 1,
#   'text': 'P627402800G',
#   'cordx': 110.4,
#   'cordy': 5.2835999999999785},
#  {'page': 1,
#   'text': 'P627402800G',
#   'cordx': 31.6801,
#   'cordy': 12.72359999999992},
#  {'page': 1,
#   'text': 'PO BOX 981572',
#   'cordx': 94.6801,
#   'cordy': 28.301400000000058},
#  {'page': 1,
#   'text': 'EL PASO, TX  79998-1572',
#   'cordx': 94.6801,
#   'cordy': 38.5014000000001},
#  {'page': 1,
#   'text': '    ',
#   'cordx': 271.92023408,
#   'cordy': 69.48339999999996},
#  {'page': 1, 'text': 'If you have any', 'cordx': 294.84, 'cordy': 74.8614},
#  {'page': 1,
#   'text': '(800) 541-7846',
#   'cordx': 380.40012142879993,
#   'cordy': 75.58140000000003},
#  {'page': 1,
#   'text': 'Forwarding Service Requested',
#   'cordx': 94.6801,
#   'cordy': 80.02130000000011},
#  {'page': 1,
#   'text': 'questions contact:',
#   'cordx': 294.84,
#   'cordy': 86.02120000000002},
#  {'page': 1,
#   'text': 'WWW.GUARDIANANYTIME.COM',
#   'cordx': 380.40012142879993,
#   'cordy': 86.02120000000002},
#  {'page': 1,
#   'text': 'Provider:',
#   'cordx': 294.8399999999999,
#   'cordy': 101.8614},
#  {'page': 1,
#   'text': 'DANIELLE ELIZABETH WEST',
#   'cordx': 382.6802169127999,
#   'cordy': 100.90124400000002},
#  {'page': 1,
#   'text': 'MIXED ADC 630',
#   'cordx': 187.31979162200003,
#   'cordy': 109.34399999999994},
#  {'page': 1,
#   'text': 'Date:',
#   'cordx': 294.8399999999999,
#   'cordy': 111.58134400000006},
#  {'page': 1,
#   'text': '07/03/23',
#   'cordx': 382.6802169127999,
#   'cordy': 111.46142200000008},
#  {'page': 1,
#   'text': '1048 5.3909 MB 2.431',
#   'cordx': 49.9199,
#   'cordy': 118.34399999999994},
#  {'page': 1, 'text': 'Payee:', 'cordx': 294.84, 'cordy': 121.30140000000006},
#  {'page': 1,
#   'text': 'ST LOUIS PEDIATRIC DENTISTRY L',
#   'cordx': 382.6802169128,
#   'cordy': 120.46152000000006},
#  {'page': 1,
#   'text': 'DDFDDFTFTAAAFDDATDDTTATTDFFATAAATAADFTATTTAFDFFDFAATDTDDTDAATDFTD',
#   'cordx': 49.8,
#   'cordy': 125.8667999999999},
#  {'page': 1,
#   'text': 'Check No.:',
#   'cordx': 294.84,
#   'cordy': 131.02132000000006},
#  {'page': 1,
#   'text': '188846369',
#   'cordx': 382.6802169128,
#   'cordy': 130.90132000000006},
#  {'page': 1,
#   'text': 'Payment Amount:',
#   'cordx': 294.84000000000003,
#   'cordy': 140.86148000000003},
#  {'page': 1,
#   'text': '$524.00',
#   'cordx': 382.6802169128,
#   'cordy': 139.90132400000005},
#  {'page': 1,
#   'text': 'ST LOUIS PEDIATRIC DENTISTRY L',
#   'cordx': 49.68010000000001,
#   'cordy': 144.57514000000003},
#  {'page': 1,
#   'text': '100',
#   'cordx': 247.319909575,
#   'cordy': 147.28869999999995},
#  {'page': 1,
#   'text': '2325 DOUGHERTY FERRY RD STE 200',
#   'cordx': 49.68010000000001,
#   'cordy': 151.29506000000003},
#  {'page': 1,
#   'text': 'Expedite cash flow with e-payments. Sign up today!',
#   'cordx': 302.28,
#   'cordy': 152.46000000000004},
#  {'page': 1,
#   'text': 'SAINT LOUIS, MO  63122-3356',
#   'cordx': 49.6801,
#   'cordy': 158.49504000000002},
#  {'page': 1,
#   'text': 'Guardian has contracted with Change Healthcare, a leading provider of ',
#   'cordx': 292.68,
#   'cordy': 167.65499999999997},
#  {'page': 1,
#   'text': 'revenue and payment cycle solutions, to deliver Electronic Funds Transfer ',
#   'cordx': 292.68,
#   'cordy': 177.85500000000002},
#  {'page': 1,
#   'text': '(EFT) services! Sign-up today by going to www.changehealthcare.com/support',
#   'cordx': 292.68,
#   'cordy': 188.05500000000006},
#  {'page': 1,
#   'text': '/customer-resources/enrollment-services for more information. Enrollment for ',
#   'cordx': 292.68,
#   'cordy': 198.255},
#  {'page': 1,
#   'text': 'this service is offered to you at no additional cost and is available online or by ',
#   'cordx': 292.680144546,
#   'cordy': 208.45500000000004},
#  {'page': 1,
#   'text': 'calling 1.866.777.0713 and selecting Option 1.',
#   'cordx': 292.680144546,
#   'cordy': 218.6550000000001},
#  {'page': 1,
#   'text': 'PROVIDER EXPLANATION OF BENEFITS - THIS IS NOT A BILL',
#   'cordx': 100.8,
#   'cordy': 247.89060000000006},
#  {'page': 1,
#   'text': 'Important!  Please examine this statement for accuracy.  Save this statement for tax purposes.',
#   'cordx': 41.039820415799994,
#   'cordy': 266.17870000000005},
#  {'page': 1,
#   'text': 'Patient Account No.:170931',
#   'cordx': 225.83943376399998,
#   'cordy': 282.34128},
#  {'page': 1,
#   'text': 'Claim Number:',
#   'cordx': 18.8398,
#   'cordy': 284.02139999999997},
#  {'page': 1, 'text': '07531F18100', 'cordx': 93.119811492, 'cordy': 283.90148},
#  {'page': 1,
#   'text': 'Plan Number:00526727',
#   'cordx': 465.83932013599997,
#   'cordy': 284.620998},
#  {'page': 1,
#   'text': 'Patient Name:',
#   'cordx': 18.8398,
#   'cordy': 293.02139999999997},
#  {'page': 1,
#   'text': 'CLAIRE C MITCHELL',
#   'cordx': 93.119811492,
#   'cordy': 292.90148},
#  {'page': 1,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 293.02137999999997},
#  {'page': 1,
#   'text': 'MATTHEW W MITCHELL',
#   'cordx': 315.119469344,
#   'cordy': 292.90108},
#  {'page': 1,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 295.18111999999996},
#  {'page': 1, 'text': 'DAUGHTER', 'cordx': 526.6794936904, 'cordy': 295.061198},
#  {'page': 1,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 303.46119799999997},
#  {'page': 1,
#   'text': 'HILLSBORO SCHOOL DISTRICT',
#   'cordx': 93.119811492,
#   'cordy': 303.34128},
#  {'page': 1, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 314.5686},
#  {'page': 1,
#   'text': 'Submitted',
#   'cordx': 72.3602,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Alt',
#   'cordx': 155.16029745327495,
#   'cordy': 313.84860000000003},
#  {'page': 1, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Date of',
#   'cordx': 224.64004397875,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Coverage',
#   'cordx': 490.680086151525,
#   'cordy': 313.84860000000003},
#  {'page': 1, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 313.84860000000003},
#  {'page': 1, 'text': 'No.', 'cordx': 21.719875162250002, 'cordy': 323.68852},
#  {'page': 1,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Code',
#   'cordx': 151.56030081277495,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'No.',
#   'cordx': 186.96031734874998,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 279.120124551525,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Amount',
#   'cordx': 442.320378138025,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Percent',
#   'cordx': 493.919927428275,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Amount',
#   'cordx': 547.1998391022499,
#   'cordy': 322.96891000000005},
#  {'page': 1, 'text': '1', 'cordx': 24.2398, 'cordy': 335.3286},
#  {'page': 1,
#   'text': 'D0120/Periodic Eval',
#   'cordx': 39.83979369292,
#   'cordy': 335.3286},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 335.3286},
#  {'page': 1, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 334.608678},
#  {'page': 1, 'text': '85.00', 'cordx': 302.0403026225, 'cordy': 334.608678},
#  {'page': 1, 'text': '33.00', 'cordx': 359.1601348725, 'cordy': 335.3286},
#  {'page': 1, 'text': '33.00', 'cordx': 409.439859725, 'cordy': 335.3286},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 335.3286},
#  {'page': 1, 'text': '33.00', 'cordx': 571.2001705475, 'cordy': 336.168838},
#  {'page': 1, 'text': '2', 'cordx': 24.2398, 'cordy': 345.0486},
#  {'page': 1,
#   'text': 'D1120/Child Cleaning',
#   'cordx': 39.83979369292,
#   'cordy': 345.0486},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 345.0486},
#  {'page': 1, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 344.208756},
#  {'page': 1, 'text': '95.00', 'cordx': 302.0403026225, 'cordy': 344.208756},
#  {'page': 1, 'text': '54.00', 'cordx': 359.1601348725, 'cordy': 345.0486},
#  {'page': 1, 'text': '54.00', 'cordx': 409.439859725, 'cordy': 345.0486},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 345.0486},
#  {'page': 1, 'text': '54.00', 'cordx': 571.2001705475, 'cordy': 345.768916},
#  {'page': 1, 'text': '3', 'cordx': 24.2398, 'cordy': 354.6486},
#  {'page': 1,
#   'text': 'D0272/Bitewing - 2',
#   'cordx': 39.83979369292,
#   'cordy': 354.6486},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 354.6486},
#  {'page': 1, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 353.928678},
#  {'page': 1, 'text': '65.00', 'cordx': 302.0403026225, 'cordy': 353.928678},
#  {'page': 1, 'text': '46.00', 'cordx': 359.1601348725, 'cordy': 354.6486},
#  {'page': 1, 'text': '46.00', 'cordx': 409.439859725, 'cordy': 354.6486},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 354.6486},
#  {'page': 1, 'text': '46.00', 'cordx': 571.2001705475, 'cordy': 355.368908},
#  {'page': 1, 'text': '4', 'cordx': 24.2398, 'cordy': 364.2486},
#  {'page': 1,
#   'text': 'D1206/Fluoride Varn',
#   'cordx': 39.83979369292,
#   'cordy': 364.2486},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 364.2486},
#  {'page': 1, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 363.528678},
#  {'page': 1, 'text': '60.00', 'cordx': 302.0403026225, 'cordy': 363.528678},
#  {'page': 1, 'text': '29.00', 'cordx': 359.1601348725, 'cordy': 364.2486},
#  {'page': 1, 'text': '29.00', 'cordx': 409.439859725, 'cordy': 364.2486},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 364.2486},
#  {'page': 1, 'text': '29.00', 'cordx': 571.2001705475, 'cordy': 365.088838},
#  {'page': 1,
#   'text': 'TOTALS',
#   'cordx': 223.08016135499994,
#   'cordy': 374.29476},
#  {'page': 1, 'text': '305.00', 'cordx': 297.36, 'cordy': 373.9686},
#  {'page': 1, 'text': '162.00', 'cordx': 355.08, 'cordy': 373.9686},
#  {'page': 1, 'text': '162.00', 'cordx': 405.36005621339996, 'cordy': 373.9686},
#  {'page': 1, 'text': '0.00', 'cordx': 499.080260925, 'cordy': 373.9688},
#  {'page': 1, 'text': '162.00', 'cordx': 567.12, 'cordy': 373.9686},
#  {'page': 1, 'text': ' ', 'cordx': 22.6801, 'cordy': 385.1286},
#  {'page': 1,
#   'text': 'BENEFIT SUMMARY',
#   'cordx': 444.59999176229996,
#   'cordy': 387.7349},
#  {'page': 1,
#   'text': 'TOTAL BENEFIT PAYABLE.........',
#   'cordx': 389.4,
#   'cordy': 399.015},
#  {'page': 1, 'text': '$162.00', 'cordx': 561.36, 'cordy': 399.015},
#  {'page': 1,
#   'text': 'HIGHER ALLOWABLE..................',
#   'cordx': 389.39990019329997,
#   'cordy': 409.45485599999995},
#  {'page': 1, 'text': '$162.00', 'cordx': 561.3598578243, 'cordy': 410.2947},
#  {'page': 1,
#   'text': 'PAID BY OTHER INSURANCE.....',
#   'cordx': 389.400042369,
#   'cordy': 419.2947},
#  {'page': 1, 'text': '$0.00', 'cordx': 570.480336246, 'cordy': 421.45486},
#  {'page': 1,
#   'text': 'ADJUSTMENTS...............................',
#   'cordx': 389.40004236899995,
#   'cordy': 430.45486},
#  {'page': 1, 'text': '$0.00', 'cordx': 570.47297051154, 'cordy': 430.45486},
#  {'page': 1,
#   'text': 'TOTAL BENEFIT PAID..................',
#   'cordx': 389.40004236899995,
#   'cordy': 441.73496},
#  {'page': 1,
#   'text': '$ 162.00',
#   'cordx': 559.0761133032299,
#   'cordy': 441.73496},
#  {'page': 1,
#   'text': "PATIENT'S RESPONSIBILITY.....",
#   'cordx': 389.40004236899995,
#   'cordy': 453.01506},
#  {'page': 1, 'text': '$0.00', 'cordx': 570.46919781828, 'cordy': 453.01506},
#  {'page': 1,
#   'text': 'Remarks for claim # 07531F18100:',
#   'cordx': 18.1199,
#   'cordy': 478.575},
#  {'page': 1,
#   'text': 'A DENTALGUARD PARTICIPATING DENTIST HAS BEEN UTILIZED',
#   'cordx': 18.1199,
#   'cordy': 489.6152},
#  {'page': 1,
#   'text': 'Benefits are based on the use of a Preferred Contracted Dentist.',
#   'cordx': 18.1199,
#   'cordy': 499.33512},
#  {'page': 1,
#   'text': 'You have used     $0.00 of your personal Maximum Rollover Account. $1,500.00 remains in your account',
#   'cordx': 18.1199,
#   'cordy': 508.93512000000004},
#  {'page': 1,
#   'text': '10 Hudson Yards',
#   'cordx': 342.120394076,
#   'cordy': 595.09492},
#  {'page': 1,
#   'text': 'CHECK NO: 188846369',
#   'cordx': 445.68,
#   'cordy': 596.8614},
#  {'page': 1, 'text': 'New York, NY 10001', 'cordx': 342.12, 'cordy': 604.095},
#  {'page': 1,
#   'text': 'CHECK DATE: 07/03/23',
#   'cordx': 445.68,
#   'cordy': 610.3014000000001},
#  {'page': 1, 'text': 'AMOUNT', 'cordx': 488.4000390352, 'cordy': 625.3015},
#  {'page': 1, 'text': '51-44', 'cordx': 427.2, 'cordy': 626.49},
#  {'page': 1, 'text': '119', 'cordx': 429.7199212548, 'cordy': 636.9298},
#  {'page': 1, 'text': '****$524.00', 'cordx': 459.12, 'cordy': 638.0214},
#  {'page': 1, 'text': 'PAY', 'cordx': 49.91950020000007, 'cordy': 649.3012},
#  {'page': 1,
#   'text': 'Five Hundred Twenty Four Dollars',
#   'cordx': 74.39782837705638,
#   'cordy': 649.3012},
#  {'page': 1,
#   'text': 'Void unless presented ',
#   'cordx': 470.76,
#   'cordy': 653.6886},
#  {'page': 1,
#   'text': 'within 180 days',
#   'cordx': 482.3998500725,
#   'cordy': 662.80852},
#  {'page': 1, 'text': 'TO THE', 'cordx': 49.9199, 'cordy': 666.5814},
#  {'page': 1,
#   'text': 'ST LOUIS PEDIATRIC DENTISTRY L',
#   'cordx': 114.119883328,
#   'cordy': 668.86151},
#  {'page': 1, 'text': 'ORDER OF', 'cordx': 49.9199, 'cordy': 677.7412},
#  {'page': 1,
#   'text': 'BANK OF AMERICA',
#   'cordx': 36.8398,
#   'cordy': 705.2099000000001},
#  {'page': 1,
#   'text': '150 WINDSOR STREET, HARTFORD, CT 06120',
#   'cordx': 36.8398,
#   'cordy': 712.04974},
#  {'page': 1,
#   'text': 'C188846369C',
#   'cordx': 94.91999359245003,
#   'cordy': 763.9888},
#  {'page': 1,
#   'text': 'A011900445A',
#   'cordx': 202.92002520884995,
#   'cordy': 763.9888},
#  {'page': 1, 'text': '40355C', 'cordx': 355.92000346094994, 'cordy': 763.9888},
#  {'page': 1,
#   'text': '       114170F 52 FO 7           8401 VNE',
#   'cordx': 14.403799999999999,
#   'cordy': 9.182384986079},
#  {'page': 3,
#   'text': 'P627402800G',
#   'cordx': 110.4,
#   'cordy': 5.2835999999999785},
#  {'page': 3,
#   'text': 'P627402800G',
#   'cordx': 31.6801,
#   'cordy': 12.72359999999992},
#  {'page': 3,
#   'text': 'PO BOX 981572',
#   'cordx': 102.12018156879992,
#   'cordy': 37.30140000000017},
#  {'page': 3,
#   'text': 'EL PASO TX 79998-1572',
#   'cordx': 102.12018156879992,
#   'cordy': 46.901400000000194},
#  {'page': 3,
#   'text': 'If you have any',
#   'cordx': 294.84,
#   'cordy': 65.02140000000009},
#  {'page': 3,
#   'text': '(800) 541-7846',
#   'cordx': 380.40012142879993,
#   'cordy': 65.86170000000016},
#  {'page': 3,
#   'text': '    ',
#   'cordx': 271.92023408,
#   'cordy': 69.48339999999996},
#  {'page': 3,
#   'text': 'questions contact:',
#   'cordx': 294.84,
#   'cordy': 76.18160000000012},
#  {'page': 3,
#   'text': 'WWW.GUARDIANANYTIME.COM',
#   'cordx': 380.40012142879993,
#   'cordy': 76.30150000000015},
#  {'page': 3,
#   'text': 'DANIELLE ELIZABETH WEST',
#   'cordx': 382.6802169127999,
#   'cordy': 93.4616000000002},
#  {'page': 3,
#   'text': 'Provider:',
#   'cordx': 294.8399999999999,
#   'cordy': 95.0214000000002},
#  {'page': 3,
#   'text': 'Date:',
#   'cordx': 294.8399999999999,
#   'cordy': 104.0214000000002},
#  {'page': 3,
#   'text': '07/03/23',
#   'cordx': 382.6802169127999,
#   'cordy': 103.9014000000002},
#  {'page': 3,
#   'text': 'ST LOUIS PEDIATRIC DENTISTRY L',
#   'cordx': 382.6802169128,
#   'cordy': 113.74162000000001},
#  {'page': 3, 'text': 'Payee:', 'cordx': 294.84, 'cordy': 115.30140000000006},
#  {'page': 3,
#   'text': 'Check No.:',
#   'cordx': 294.84,
#   'cordy': 125.02132000000006},
#  {'page': 3,
#   'text': '188846369',
#   'cordx': 382.6802169128,
#   'cordy': 124.90142000000003},
#  {'page': 3,
#   'text': 'Payment Amount:',
#   'cordx': 294.84,
#   'cordy': 134.02132000000006},
#  {'page': 3,
#   'text': '$524.00',
#   'cordx': 382.6802169128,
#   'cordy': 133.90142000000003},
#  {'page': 3,
#   'text': 'Patient Account No.:170932',
#   'cordx': 225.83943376399998,
#   'cordy': 149.7411800000001},
#  {'page': 3,
#   'text': 'Claim Number:',
#   'cordx': 18.8398,
#   'cordy': 151.30140000000006},
#  {'page': 3,
#   'text': '07532F18100',
#   'cordx': 93.119811492,
#   'cordy': 151.18148000000008},
#  {'page': 3,
#   'text': 'Plan Number:00526727',
#   'cordx': 465.83932013599997,
#   'cordy': 151.9008980000001},
#  {'page': 3,
#   'text': 'Patient Name:',
#   'cordx': 18.8398,
#   'cordy': 160.30140000000006},
#  {'page': 3,
#   'text': 'LEVI N MITCHELL',
#   'cordx': 93.119811492,
#   'cordy': 160.18148000000008},
#  {'page': 3,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 160.3013800000001},
#  {'page': 3,
#   'text': 'MATTHEW W MITCHELL',
#   'cordx': 315.119469344,
#   'cordy': 160.1809800000001},
#  {'page': 3,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 162.58102000000008},
#  {'page': 3,
#   'text': 'SON',
#   'cordx': 526.6794936904,
#   'cordy': 162.4610980000001},
#  {'page': 3,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 170.86109800000008},
#  {'page': 3,
#   'text': 'HILLSBORO SCHOOL DISTRICT',
#   'cordx': 93.119811492,
#   'cordy': 170.74128000000007},
#  {'page': 3, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 181.84859999999992},
#  {'page': 3, 'text': 'Submitted', 'cordx': 72.3602, 'cordy': 181.1286},
#  {'page': 3, 'text': 'Alt', 'cordx': 155.16029745327495, 'cordy': 181.1286},
#  {'page': 3, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 181.1286},
#  {'page': 3, 'text': 'Date of', 'cordx': 224.64004397875, 'cordy': 181.1286},
#  {'page': 3,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 181.1286},
#  {'page': 3,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 181.1286},
#  {'page': 3,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 181.1286},
#  {'page': 3,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 181.1286},
#  {'page': 3, 'text': 'Coverage', 'cordx': 490.680086151525, 'cordy': 181.1286},
#  {'page': 3, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 181.1286},
#  {'page': 3,
#   'text': 'No.',
#   'cordx': 21.719875162250002,
#   'cordy': 190.96890999999994},
#  {'page': 3,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Code',
#   'cordx': 151.56030081277495,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'No.',
#   'cordx': 186.96031734874998,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 279.120124551525,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Amount',
#   'cordx': 442.320378138025,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Percent',
#   'cordx': 493.919927428275,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Amount',
#   'cordx': 547.1998391022499,
#   'cordy': 190.24851999999998},
#  {'page': 3, 'text': '1', 'cordx': 24.2398, 'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': 'D0120/Periodic Eval',
#   'cordx': 39.83979369292,
#   'cordy': 202.72859999999991},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': '06/27/23',
#   'cordx': 224.8801224475,
#   'cordy': 202.00867799999992},
#  {'page': 3,
#   'text': '85.00',
#   'cordx': 302.0403026225,
#   'cordy': 202.00867799999992},
#  {'page': 3,
#   'text': '33.00',
#   'cordx': 359.1601348725,
#   'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': '33.00',
#   'cordx': 409.439859725,
#   'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': '33.00',
#   'cordx': 571.2001705475,
#   'cordy': 203.44851799999992},
#  {'page': 3, 'text': '2', 'cordx': 24.2398, 'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': 'D1120/Child Cleaning',
#   'cordx': 39.83979369292,
#   'cordy': 212.32859999999994},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': '06/27/23',
#   'cordx': 224.8801224475,
#   'cordy': 211.60867799999994},
#  {'page': 3,
#   'text': '95.00',
#   'cordx': 302.0403026225,
#   'cordy': 211.60867799999994},
#  {'page': 3,
#   'text': '54.00',
#   'cordx': 359.1601348725,
#   'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': '54.00',
#   'cordx': 409.439859725,
#   'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': '54.00',
#   'cordx': 571.2001705475,
#   'cordy': 213.04851799999994},
#  {'page': 3, 'text': '3', 'cordx': 24.2398, 'cordy': 222.04859999999996},
#  {'page': 3,
#   'text': 'D0272/Bitewing - 2',
#   'cordx': 39.83979369292,
#   'cordy': 222.04859999999996},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 222.04859999999996},
#  {'page': 3, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 221.208756},
#  {'page': 3, 'text': '65.00', 'cordx': 302.0403026225, 'cordy': 221.208756},
#  {'page': 3,
#   'text': '46.00',
#   'cordx': 359.1601348725,
#   'cordy': 222.04859999999996},
#  {'page': 3,
#   'text': '46.00',
#   'cordx': 409.439859725,
#   'cordy': 222.04859999999996},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 222.04859999999996},
#  {'page': 3, 'text': '46.00', 'cordx': 571.2001705475, 'cordy': 222.768916},
#  {'page': 3, 'text': '4', 'cordx': 24.2398, 'cordy': 231.6486},
#  {'page': 3,
#   'text': 'D1206/Fluoride Varn',
#   'cordx': 39.83979369292,
#   'cordy': 231.6486},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 231.6486},
#  {'page': 3, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 230.928678},
#  {'page': 3, 'text': '60.00', 'cordx': 302.0403026225, 'cordy': 230.928678},
#  {'page': 3, 'text': '29.00', 'cordx': 359.1601348725, 'cordy': 231.6486},
#  {'page': 3, 'text': '29.00', 'cordx': 409.439859725, 'cordy': 231.6486},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 231.6486},
#  {'page': 3,
#   'text': '29.00',
#   'cordx': 571.2001705475,
#   'cordy': 232.36890800000003},
#  {'page': 3, 'text': '5', 'cordx': 24.2398, 'cordy': 241.2485999999999},
#  {'page': 3,
#   'text': 'D0230/Periapical Add',
#   'cordx': 39.83979369292,
#   'cordy': 241.2485999999999},
#  {'page': 3, 'text': 'D0220', 'cordx': 147.36, 'cordy': 240.52859999999998},
#  {'page': 3,
#   'text': 'FM',
#   'cordx': 188.03974046500002,
#   'cordy': 241.24852199999998},
#  {'page': 3,
#   'text': '06/27/23',
#   'cordx': 224.8801224475,
#   'cordy': 240.5286779999999},
#  {'page': 3,
#   'text': '35.00',
#   'cordx': 302.0403026225,
#   'cordy': 240.5286779999999},
#  {'page': 3,
#   'text': '22.00',
#   'cordx': 359.1601348725,
#   'cordy': 241.2485999999999},
#  {'page': 3,
#   'text': '22.00',
#   'cordx': 409.439859725,
#   'cordy': 241.2485999999999},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 241.2485999999999},
#  {'page': 3,
#   'text': '22.00',
#   'cordx': 571.2001705475,
#   'cordy': 241.96890799999994},
#  {'page': 3, 'text': '6', 'cordx': 24.2398, 'cordy': 250.84859999999992},
#  {'page': 3,
#   'text': 'D0230/Periapical Add',
#   'cordx': 39.83979369292,
#   'cordy': 250.84859999999992},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 250.84859999999992},
#  {'page': 3,
#   'text': '06/27/23',
#   'cordx': 224.8801224475,
#   'cordy': 250.12867799999992},
#  {'page': 3,
#   'text': '35.00',
#   'cordx': 302.0403026225,
#   'cordy': 250.12867799999992},
#  {'page': 3,
#   'text': '16.00',
#   'cordx': 359.1601348725,
#   'cordy': 250.84859999999992},
#  {'page': 3,
#   'text': '16.00',
#   'cordx': 409.439859725,
#   'cordy': 250.84859999999992},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 250.84859999999992},
#  {'page': 3,
#   'text': '16.00',
#   'cordx': 571.2001705475,
#   'cordy': 251.68883799999992},
#  {'page': 3,
#   'text': 'TOTALS',
#   'cordx': 223.08016135499994,
#   'cordy': 260.89477999999997},
#  {'page': 3, 'text': '375.00', 'cordx': 297.36, 'cordy': 260.56859999999995},
#  {'page': 3, 'text': '200.00', 'cordx': 355.08, 'cordy': 260.56859999999995},
#  {'page': 3,
#   'text': '200.00',
#   'cordx': 405.36005621339996,
#   'cordy': 260.56859999999995},
#  {'page': 3,
#   'text': '0.00',
#   'cordx': 499.080260925,
#   'cordy': 260.56889999999987},
#  {'page': 3, 'text': '200.00', 'cordx': 567.12, 'cordy': 260.56859999999995},
#  {'page': 3, 'text': ' ', 'cordx': 22.6801, 'cordy': 271.8485999999999},
#  {'page': 3,
#   'text': 'BENEFIT SUMMARY',
#   'cordx': 444.59999176229996,
#   'cordy': 274.33489999999995},
#  {'page': 3,
#   'text': 'TOTAL BENEFIT PAYABLE.........',
#   'cordx': 389.4,
#   'cordy': 285.615},
#  {'page': 3, 'text': '$200.00', 'cordx': 561.36, 'cordy': 285.615},
#  {'page': 3,
#   'text': 'HIGHER ALLOWABLE..................',
#   'cordx': 389.39990019329997,
#   'cordy': 296.174778},
#  {'page': 3, 'text': '$200.00', 'cordx': 561.3598578243, 'cordy': 296.8947},
#  {'page': 3,
#   'text': 'PAID BY OTHER INSURANCE.....',
#   'cordx': 389.400042369,
#   'cordy': 305.8947},
#  {'page': 3, 'text': '$0.00', 'cordx': 570.480336246, 'cordy': 308.17478},
#  {'page': 3,
#   'text': 'ADJUSTMENTS...............................',
#   'cordx': 389.40004236899995,
#   'cordy': 317.17478},
#  {'page': 3, 'text': '$0.00', 'cordx': 570.47297051154, 'cordy': 317.17478},
#  {'page': 3,
#   'text': 'TOTAL BENEFIT PAID..................',
#   'cordx': 389.40004236899995,
#   'cordy': 328.33498},
#  {'page': 3,
#   'text': '$ 200.00',
#   'cordx': 559.0761133032299,
#   'cordy': 328.33498},
#  {'page': 3,
#   'text': "PATIENT'S RESPONSIBILITY.....",
#   'cordx': 389.40004236899995,
#   'cordy': 339.61508},
#  {'page': 3, 'text': '$0.00', 'cordx': 570.46919781828, 'cordy': 339.61508},
#  {'page': 3,
#   'text': 'Remarks for claim # 07532F18100:',
#   'cordx': 18.1199,
#   'cordy': 365.175},
#  {'page': 3,
#   'text': 'A DENTALGUARD PARTICIPATING DENTIST HAS BEEN UTILIZED',
#   'cordx': 18.1199,
#   'cordy': 376.3352},
#  {'page': 3,
#   'text': '6.  The dental plan covers the maximum allowable for a full mouth series of radiographic images.',
#   'cordx': 18.1199,
#   'cordy': 385.9352},
#  {'page': 3,
#   'text': 'Benefits are based on the use of a Preferred Contracted Dentist.',
#   'cordx': 18.1199,
#   'cordy': 395.53520000000003},
#  {'page': 3,
#   'text': 'Due to a claim payment denial, in whole or part, in accordance with Missouri Law, an Enrollee,',
#   'cordx': 18.1199,
#   'cordy': 405.25512000000003},
#  {'page': 3,
#   'text': "their representative ('Enrollee'), or their dentist, has the right to submit an appeal/grievance",
#   'cordx': 18.1199,
#   'cordy': 414.85512000000006},
#  {'page': 3,
#   'text': 'due to the availability, delivery, or quality of a dental service, including an appeal/grievance',
#   'cordx': 18.1199,
#   'cordy': 424.4551200000001},
#  {'page': 3,
#   'text': 'regarding an adverse determination made pursuant to utilization review, claim payments, the',
#   'cordx': 18.1199,
#   'cordy': 434.0551200000001},
#  {'page': 3,
#   'text': "handling or reimbursement for such service(s), or any other matter pertaining to the Enrollee's",
#   'cordx': 18.1199,
#   'cordy': 443.7750400000001},
#  {'page': 3,
#   'text': 'contractual relationship with Guardian.',
#   'cordx': 18.1199,
#   'cordy': 453.3750400000001},
#  {'page': 3,
#   'text': 'If your appeal/grievance is related to a utilization review which resulted in an adverse',
#   'cordx': 18.1199,
#   'cordy': 462.97504000000015},
#  {'page': 3,
#   'text': 'determination, the determination was made by a licensed dentist.',
#   'cordx': 18.1199,
#   'cordy': 472.69496000000015},
#  {'page': 3,
#   'text': 'If you wish to submit an appeal/grievance, please submit your written request along with all',
#   'cordx': 18.1199,
#   'cordy': 482.2949600000002},
#  {'page': 3,
#   'text': 'supporting documentation to: the Guardian Life Insurance Company of America, Grievance',
#   'cordx': 18.1199,
#   'cordy': 491.8949600000002},
#  {'page': 3,
#   'text': 'Department, (P.O. Box 981573, El Paso, TX 79998-1573, or fax to (509) 468-6399).',
#   'cordx': 18.1199,
#   'cordy': 501.6152700000002},
#  {'page': 3,
#   'text': 'All diagnostic and treatment information should be submitted with your request. If you do not',
#   'cordx': 18.1199,
#   'cordy': 511.2152700000002},
#  {'page': 3,
#   'text': 'include the necessary clinical information with your request, Guardian will request radiographic',
#   'cordx': 18.1199,
#   'cordy': 520.8152700000003},
#  {'page': 3,
#   'text': 'images and/or any other information needed to review the treatment.',
#   'cordx': 18.1199,
#   'cordy': 530.5351900000003},
#  {'page': 3,
#   'text': 'Guardian will send acknowledgement of the appeal/grievance within ten (10) business days of receipt',
#   'cordx': 18.1199,
#   'cordy': 540.1351900000002},
#  {'page': 3,
#   'text': 'of the request.',
#   'cordx': 18.1199,
#   'cordy': 549.7351900000002},
#  {'page': 3,
#   'text': 'A final decision for the appeal/grievance will be made within twenty (20) business days of the date',
#   'cordx': 18.1199,
#   'cordy': 559.4551100000002},
#  {'page': 3,
#   'text': 'the request is received by Guardian. If the investigation cannot be completed within twenty (20)',
#   'cordx': 18.1199,
#   'cordy': 569.0551100000002},
#  {'page': 3,
#   'text': 'business days, the enrollee will be notified prior to the conclusion of the twenty (20) business',
#   'cordx': 18.1199,
#   'cordy': 578.6551100000001},
#  {'page': 3,
#   'text': "days that the investigation will be completed within thirty (30) business days of Guardian's",
#   'cordx': 18.1199,
#   'cordy': 588.2551100000002},
#  {'page': 3,
#   'text': 'receipt of the request. Within five (5) business days of the completion of the investigation, a',
#   'cordx': 18.1199,
#   'cordy': 597.9750300000002},
#  {'page': 3,
#   'text': 'final determination will be made. The appeal/grievance will be reviewed by a different licensed',
#   'cordx': 18.1199,
#   'cordy': 607.5750300000002},
#  {'page': 3,
#   'text': 'dentist, of the same or similar specialty as the service being reviewed, than the one who rendered',
#   'cordx': 18.1199,
#   'cordy': 617.1750300000002},
#  {'page': 3,
#   'text': 'the initial adverse determination.  Guardian will issue a written notification of the decision, via',
#   'cordx': 18.1199,
#   'cordy': 626.8949500000002},
#  {'page': 3,
#   'text': "us mail, to the Enrollee and the Enrollee's dentist within fifteen (15) business days of completion",
#   'cordx': 18.1199,
#   'cordy': 636.4949500000002},
#  {'page': 3,
#   'text': 'of the investigation.  The notice will include the factual basis and specific criteria the',
#   'cordx': 18.1199,
#   'cordy': 646.0949500000002},
#  {'page': 3,
#   'text': 'determination was based on and information on how to appeal the determination.',
#   'cordx': 18.1199,
#   'cordy': 655.8152600000002},
#  {'page': 3,
#   'text': 'If the treating dentist believes the denial of this service requires an expedited appeal, an',
#   'cordx': 18.1199,
#   'cordy': 665.4152600000002},
#  {'page': 3,
#   'text': 'expedited appeal may only be requested when the regular appeal process would delay the rendering',
#   'cordx': 18.1199,
#   'cordy': 675.0152600000001},
#  {'page': 3,
#   'text': 'of the service in a manner that would be detrimental to the health of the patient. An expedited',
#   'cordx': 18.1199,
#   'cordy': 684.7351800000001},
#  {'page': 3,
#   'text': 'appeal may be submitted orally or in writing. Both the treating dentist and the utilization',
#   'cordx': 18.1199,
#   'cordy': 694.3351800000002},
#  {'page': 3,
#   'text': 'review entity will attempt to share the maximum information by telephone, facsimile machine,',
#   'cordx': 18.1199,
#   'cordy': 703.9351800000002},
#  {'page': 3,
#   'text': 'or other means to resolve the expedited appeal in a satisfactory manner. The decision for an',
#   'cordx': 18.1199,
#   'cordy': 713.6551000000002},
#  {'page': 3,
#   'text': 'expedited appeal shall be rendered no later than seventy-two (72) hours after receipt of the',
#   'cordx': 18.1199,
#   'cordy': 723.2551000000002},
#  {'page': 3,
#   'text': 'request. The treating dentist will be notified of the determination by telephone. Written',
#   'cordx': 18.1199,
#   'cordy': 732.8551000000002},
#  {'page': 3,
#   'text': 'confirmation will be provided to the Enrollee and the treating dentist within three (3) business',
#   'cordx': 18.1199,
#   'cordy': 742.5750200000002},
#  {'page': 3,
#   'text': 'days of the determination.',
#   'cordx': 18.1199,
#   'cordy': 752.1750200000001},
#  {'page': 3,
#   'text': 'An Enrollee may request an additional written Statement of the clinical rationale and clinical',
#   'cordx': 18.1199,
#   'cordy': 761.7750200000002},
#  {'page': 3,
#   'text': '       114170F 52 FO 8           8401 VNE',
#   'cordx': 14.403799999999999,
#   'cordy': 9.182384986079},
#  {'page': 4,
#   'text': 'P627402800G',
#   'cordx': 110.4,
#   'cordy': 5.2835999999999785},
#  {'page': 4,
#   'text': 'P627402800G',
#   'cordx': 31.6801,
#   'cordy': 12.72359999999992},
#  {'page': 4,
#   'text': 'PO BOX 981572',
#   'cordx': 102.12018156879992,
#   'cordy': 37.30140000000017},
#  {'page': 4,
#   'text': 'EL PASO TX 79998-1572',
#   'cordx': 102.12018156879992,
#   'cordy': 46.901400000000194},
#  {'page': 4,
#   'text': 'If you have any',
#   'cordx': 294.84,
#   'cordy': 65.02140000000009},
#  {'page': 4,
#   'text': '(800) 541-7846',
#   'cordx': 380.40012142879993,
#   'cordy': 65.86170000000016},
#  {'page': 4,
#   'text': '    ',
#   'cordx': 271.92023408,
#   'cordy': 69.48339999999996},
#  {'page': 4,
#   'text': 'questions contact:',
#   'cordx': 294.84,
#   'cordy': 76.18160000000012},
#  {'page': 4,
#   'text': 'WWW.GUARDIANANYTIME.COM',
#   'cordx': 380.40012142879993,
#   'cordy': 76.30150000000015},
#  {'page': 4,
#   'text': 'DANIELLE ELIZABETH WEST',
#   'cordx': 382.6802169127999,
#   'cordy': 93.4616000000002},
#  {'page': 4,
#   'text': 'Provider:',
#   'cordx': 294.8399999999999,
#   'cordy': 95.0214000000002},
#  {'page': 4,
#   'text': 'Date:',
#   'cordx': 294.8399999999999,
#   'cordy': 104.0214000000002},
#  {'page': 4,
#   'text': '07/03/23',
#   'cordx': 382.6802169127999,
#   'cordy': 103.9014000000002},
#  {'page': 4,
#   'text': 'ST LOUIS PEDIATRIC DENTISTRY L',
#   'cordx': 382.6802169128,
#   'cordy': 113.74162000000001},
#  {'page': 4, 'text': 'Payee:', 'cordx': 294.84, 'cordy': 115.30140000000006},
#  {'page': 4,
#   'text': 'Check No.:',
#   'cordx': 294.84,
#   'cordy': 125.02132000000006},
#  {'page': 4,
#   'text': '188846369',
#   'cordx': 382.6802169128,
#   'cordy': 124.90142000000003},
#  {'page': 4,
#   'text': 'Payment Amount:',
#   'cordx': 294.84,
#   'cordy': 134.02132000000006},
#  {'page': 4,
#   'text': '$524.00',
#   'cordx': 382.6802169128,
#   'cordy': 133.90142000000003},
#  {'page': 4,
#   'text': 'Remarks for claim # 07532F18100:',
#   'cordx': 18.1199,
#   'cordy': 152.89499999999998},
#  {'page': 4,
#   'text': 'criteria utilized in the investigation and the adverse determination process by submitting a',
#   'cordx': 18.1199,
#   'cordy': 163.9352},
#  {'page': 4,
#   'text': 'written request to: the Guardian Life Insurance Company of America, Dental Grievance Department,',
#   'cordx': 18.1199,
#   'cordy': 173.65512},
#  {'page': 4,
#   'text': '(P.O. Box 981573, El Paso, TX 79998-1573, or fax to (509) 468-6399).',
#   'cordx': 18.1199,
#   'cordy': 183.25512000000003},
#  {'page': 4,
#   'text': 'For assistance with the appeal process, you may contact the Director of the Department of Commerce',
#   'cordx': 18.1199,
#   'cordy': 192.85512000000006},
#  {'page': 4,
#   'text': 'and Insurance at:P.O. Box 690, Jefferson City, Missouri, 65102-0690, 800-726-7390, Fax 573-526-4898,',
#   'cordx': 18.1199,
#   'cordy': 202.57504000000006},
#  {'page': 4,
#   'text': 'CONSUMERAFFAIRS@INSURANCE.MO.GOV (e-mail address). An Enrollee may file an appeal/grievance with the',
#   'cordx': 18.1199,
#   'cordy': 212.17504000000008},
#  {'page': 4,
#   'text': 'Director of the Department of Commerce and Insurance at any time.',
#   'cordx': 18.1199,
#   'cordy': 221.7750400000001},
#  {'page': 4,
#   'text': 'You have used     $0.00 of your personal Maximum Rollover Account.   $600.00 remains in your account',
#   'cordx': 18.1199,
#   'cordy': 231.37504000000013},
#  {'page': 4,
#   'text': 'Patient Account No.:170933',
#   'cordx': 225.83943376399998,
#   'cordy': 254.6211800000001},
#  {'page': 4,
#   'text': 'Claim Number:',
#   'cordx': 18.8398,
#   'cordy': 256.18140000000005},
#  {'page': 4,
#   'text': '07530F18100',
#   'cordx': 93.119811492,
#   'cordy': 256.0614800000001},
#  {'page': 4,
#   'text': 'Plan Number:00526727',
#   'cordx': 465.83932013599997,
#   'cordy': 256.7813070000001},
#  {'page': 4,
#   'text': 'Patient Name:',
#   'cordx': 18.8398,
#   'cordy': 265.18140000000005},
#  {'page': 4,
#   'text': 'MASON A MITCHELL',
#   'cordx': 93.119811492,
#   'cordy': 265.0614800000001},
#  {'page': 4,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 265.1813800000001},
#  {'page': 4,
#   'text': 'MATTHEW W MITCHELL',
#   'cordx': 315.119469344,
#   'cordy': 265.0613800000001},
#  {'page': 4,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 267.4614200000001},
#  {'page': 4,
#   'text': 'SON',
#   'cordx': 526.6794936904,
#   'cordy': 267.3411070000001},
#  {'page': 4,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 275.74110700000006},
#  {'page': 4,
#   'text': 'HILLSBORO SCHOOL DISTRICT',
#   'cordx': 93.119811492,
#   'cordy': 275.62128000000007},
#  {'page': 4, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 286.72860000000003},
#  {'page': 4, 'text': 'Submitted', 'cordx': 72.3602, 'cordy': 286.0086},
#  {'page': 4, 'text': 'Alt', 'cordx': 155.16029745327495, 'cordy': 286.0086},
#  {'page': 4, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 286.0086},
#  {'page': 4, 'text': 'Date of', 'cordx': 224.64004397875, 'cordy': 286.0086},
#  {'page': 4,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 286.0086},
#  {'page': 4,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 286.0086},
#  {'page': 4,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 286.0086},
#  {'page': 4,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 286.0086},
#  {'page': 4, 'text': 'Coverage', 'cordx': 490.680086151525, 'cordy': 286.0086},
#  {'page': 4, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 286.0086},
#  {'page': 4, 'text': 'No.', 'cordx': 21.719875162250002, 'cordy': 295.84852},
#  {'page': 4,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 295.12852},
#  {'page': 4, 'text': 'Code', 'cordx': 151.56030081277495, 'cordy': 295.12852},
#  {'page': 4, 'text': 'No.', 'cordx': 186.96031734874998, 'cordy': 295.12852},
#  {'page': 4,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 295.12852},
#  {'page': 4, 'text': 'Charge', 'cordx': 279.120124551525, 'cordy': 295.12852},
#  {'page': 4,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 295.12852},
#  {'page': 4,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 295.12852},
#  {'page': 4, 'text': 'Amount', 'cordx': 442.320378138025, 'cordy': 295.12852},
#  {'page': 4, 'text': 'Percent', 'cordx': 493.919927428275, 'cordy': 295.12852},
#  {'page': 4, 'text': 'Amount', 'cordx': 547.1998391022499, 'cordy': 295.12852},
#  {'page': 4, 'text': '1', 'cordx': 24.2398, 'cordy': 307.6086},
#  {'page': 4,
#   'text': 'D0120/Periodic Eval',
#   'cordx': 39.83979369292,
#   'cordy': 307.6086},
#  {'page': 4, 'text': 'FM', 'cordx': 188.04, 'cordy': 307.6086},
#  {'page': 4, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 306.888678},
#  {'page': 4, 'text': '85.00', 'cordx': 302.0403026225, 'cordy': 306.888678},
#  {'page': 4, 'text': '33.00', 'cordx': 359.1601348725, 'cordy': 307.6086},
#  {'page': 4, 'text': '33.00', 'cordx': 409.439859725, 'cordy': 307.6086},
#  {'page': 4, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 307.6086},
#  {'page': 4,
#   'text': '33.00',
#   'cordx': 571.2001705475,
#   'cordy': 308.32851800000003},
#  {'page': 4, 'text': '2', 'cordx': 24.2398, 'cordy': 317.2086},
#  {'page': 4,
#   'text': 'D1120/Child Cleaning',
#   'cordx': 39.83979369292,
#   'cordy': 317.2086},
#  {'page': 4, 'text': 'FM', 'cordx': 188.04, 'cordy': 317.2086},
#  {'page': 4, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 316.488678},
#  {'page': 4, 'text': '95.00', 'cordx': 302.0403026225, 'cordy': 316.488678},
#  {'page': 4, 'text': '54.00', 'cordx': 359.1601348725, 'cordy': 317.2086},
#  {'page': 4, 'text': '54.00', 'cordx': 409.439859725, 'cordy': 317.2086},
#  {'page': 4, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 317.2086},
#  {'page': 4, 'text': '54.00', 'cordx': 571.2001705475, 'cordy': 317.928518},
#  {'page': 4, 'text': '3', 'cordx': 24.2398, 'cordy': 326.9286},
#  {'page': 4,
#   'text': 'D0272/Bitewing - 2',
#   'cordx': 39.83979369292,
#   'cordy': 326.9286},
#  {'page': 4, 'text': 'FM', 'cordx': 188.04, 'cordy': 326.9286},
#  {'page': 4, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 326.088756},
#  {'page': 4, 'text': '65.00', 'cordx': 302.0403026225, 'cordy': 326.088756},
#  {'page': 4, 'text': '46.00', 'cordx': 359.1601348725, 'cordy': 326.9286},
#  {'page': 4, 'text': '46.00', 'cordx': 409.439859725, 'cordy': 326.9286},
#  {'page': 4, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 326.9286},
#  {'page': 4, 'text': '46.00', 'cordx': 571.2001705475, 'cordy': 327.648526},
#  {'page': 4, 'text': '4', 'cordx': 24.2398, 'cordy': 336.5286},
#  {'page': 4,
#   'text': 'D1206/Fluoride Varn',
#   'cordx': 39.83979369292,
#   'cordy': 336.5286},
#  {'page': 4, 'text': 'FM', 'cordx': 188.04, 'cordy': 336.5286},
#  {'page': 4, 'text': '06/27/23', 'cordx': 224.8801224475, 'cordy': 335.808678},
#  {'page': 4, 'text': '60.00', 'cordx': 302.0403026225, 'cordy': 335.808678},
#  {'page': 4, 'text': '29.00', 'cordx': 359.1601348725, 'cordy': 336.5286},
#  {'page': 4, 'text': '29.00', 'cordx': 409.439859725, 'cordy': 336.5286},
#  {'page': 4, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 336.5286},
#  {'page': 4, 'text': '29.00', 'cordx': 571.2001705475, 'cordy': 337.248518},
#  {'page': 4,
#   'text': 'TOTALS',
#   'cordx': 223.08016135499994,
#   'cordy': 346.45518000000004},
#  {'page': 4, 'text': '305.00', 'cordx': 297.36, 'cordy': 346.1286},
#  {'page': 4, 'text': '162.00', 'cordx': 355.08, 'cordy': 346.1286},
#  {'page': 4, 'text': '162.00', 'cordx': 405.36005621339996, 'cordy': 346.1286},
#  {'page': 4,
#   'text': '0.00',
#   'cordx': 499.080260925,
#   'cordy': 346.12850000000003},
#  {'page': 4, 'text': '162.00', 'cordx': 567.12, 'cordy': 346.1286},
#  {'page': 4, 'text': ' ', 'cordx': 22.6801, 'cordy': 357.40860000000004},
#  {'page': 4,
#   'text': 'BENEFIT SUMMARY',
#   'cordx': 444.59999176229996,
#   'cordy': 360.0152},
#  {'page': 4,
#   'text': 'TOTAL BENEFIT PAYABLE.........',
#   'cordx': 389.4,
#   'cordy': 371.175},
#  {'page': 4, 'text': '$162.00', 'cordx': 561.36, 'cordy': 371.175},
#  {'page': 4,
#   'text': 'HIGHER ALLOWABLE..................',
#   'cordx': 389.39990019329997,
#   'cordy': 381.735078},
#  {'page': 4, 'text': '$162.00', 'cordx': 561.3598578243, 'cordy': 382.455},
#  {'page': 4,
#   'text': 'PAID BY OTHER INSURANCE.....',
#   'cordx': 389.400042369,
#   'cordy': 391.4551},
#  {'page': 4, 'text': '$0.00', 'cordx': 570.480336246, 'cordy': 393.73518},
#  {'page': 4,
#   'text': 'ADJUSTMENTS...............................',
#   'cordx': 389.40004236899995,
#   'cordy': 402.73518},
#  {'page': 4, 'text': '$0.00', 'cordx': 570.47297051154, 'cordy': 402.73518},
#  {'page': 4,
#   'text': 'TOTAL BENEFIT PAID..................',
#   'cordx': 389.40004236899995,
#   'cordy': 414.01528},
#  {'page': 4,
#   'text': '$ 162.00',
#   'cordx': 559.0761133032299,
#   'cordy': 414.01528},
#  {'page': 4,
#   'text': "PATIENT'S RESPONSIBILITY.....",
#   'cordx': 389.40004236899995,
#   'cordy': 425.17508000000004},
#  {'page': 4,
#   'text': '$0.00',
#   'cordx': 570.46919781828,
#   'cordy': 425.17508000000004},
#  {'page': 4,
#   'text': 'Remarks for claim # 07530F18100:',
#   'cordx': 18.1199,
#   'cordy': 450.735},
#  {'page': 4,
#   'text': 'A DENTALGUARD PARTICIPATING DENTIST HAS BEEN UTILIZED',
#   'cordx': 18.1199,
#   'cordy': 461.89480000000003},
#  {'page': 4,
#   'text': 'Benefits are based on the use of a Preferred Contracted Dentist.',
#   'cordx': 18.1199,
#   'cordy': 471.49480000000005},
#  {'page': 4,
#   'text': 'You have used     $0.00 of your personal Maximum Rollover Account. $1,500.00 remains in your account',
#   'cordx': 18.1199,
#   'cordy': 481.21511000000004},
#  {'page': 4,
#   'text': 'Comments:',
#   'cordx': 18.1199,
#   'cordy': 505.21511000000004},
#  {'page': 4,
#   'text': 'Current Dental Terminology © 2021 American Dental Association.  All rights reserved.',
#   'cordx': 18.1199,
#   'cordy': 513.97488},
#  {'page': 4,
#   'text': 'Log on to www.GuardianAnytime.com  for instant access to clinical policy guidelines and benefits information for Guardian members. Verify eligibility, view',
#   'cordx': 18.12017438699999,
#   'cordy': 525.975},
#  {'page': 4,
#   'text': 'benefits, check claim status and more!',
#   'cordx': 18.12017438699999,
#   'cordy': 534.975},
#  {'page': 4,
#   'text': '       114170B 52 FO 8           8401 VNE',
#   'cordx': 14.403799999999999,
#   'cordy': 9.182384986079}]

# %%
dfs = []
x2 = 0
y2 = 0
for text_d in text_list:
    x = text_d['cordx']
    y = text_d['cordy']
    if x2<x:
        x2 = text_d['cordx']
    if y2<y:
        y2 = text_d['cordy']    
x2 = x2+20
y2 = y2+20
print("YYYY", y2)
for i in range(len(text_list)):
    x1 = y1 = ''
    if 'Line' in text_list[i]['text']:
        print("Line", text_list[i]['text'])
        x1 = text_list[i]['cordx']
        y1 = text_list[i]['cordy']
        page_number = text_list[i]['page']
        for j in range(i,len(text_list)):
            
            if page_number == text_list[j]['page']:
                if 'BENEFIT SUMMARY' in text_list[j]['text']:
                    print("Bene", text_list[j]['text'])
                    print("PAG", text_list[j]['page'] )
                    page = int(text_list[j]['page'])
                    y2 = text_list[j]['cordy']
                    print(f"x1 = {x1}, y1 = {y1}, x2 = {x2}, y2 = {y2}")
                    tabula_dfs = tabula.read_pdf(pdf_path, guess=False, pages=page , stream=True, encoding="utf-8",
                                     area=(y1, x1, y2, x2), multiple_tables=True)
                    df_filled = tabula_dfs[0].fillna('')
                    dfs.append(df_filled[1:])
                    break
            
            if page_number == text_list[j]['page']:
                if '10 Hudson Yards' in text_list[j]['text']:
                    print("10 Hudson", text_list[j]['text'])
                    print("PAG", text_list[j]['page'] )
                    page = int(text_list[j]['page'])
                    y2 = text_list[j]['cordy']
                    print(f"x1 = {x1}, y1 = {y1}, x2 = {x2}, y2 = {y2}")
                    tabula_dfs = tabula.read_pdf(pdf_path, guess=False, pages=page , stream=True, encoding="utf-8",
                                     area=(y1, x1, y2, x2), multiple_tables=True)
                    df_filled = tabula_dfs[0].fillna('')
                    dfs.append(df_filled[1:])
                    break
                
            
            if page_number == text_list[j]['page']:
#                 if 'BENEFIT SUMMARY' not in text_list[j]['text'] and '10 Hudson Yards' not in text_list[j]['text']:
                if 'VNE' in text_list[j]['text']:
                    y2 = 780
                    page = int(text_list[j]['page'])
                    print(f"x1 = {x1}, y1 = {y1}, x2 = {x2}, y2 = {y2}")
                    tabula_dfs = tabula.read_pdf(pdf_path, guess=False, pages=page , stream=True, encoding="utf-8",
                                     area=(y1, x1, y2, x2), multiple_tables=True)
                    df_filled = tabula_dfs[0].fillna('')
                    dfs.append(df_filled[1:])
                    break
# Out:
# YYYY 783.9888
# Line Line
# Bene BENEFIT SUMMARY
# PAG 1
# x1 = 18.8398, y1 = 314.5686, x2 = 591.2001705475, y2 = 387.7349
# Got stderr: Jul 17, 2023 8:48:21 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 17, 2023 8:48:21 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 17, 2023 8:48:21 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 17, 2023 8:48:21 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 17, 2023 8:48:21 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 17, 2023 8:48:21 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 17, 2023 8:48:21 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Line Line
# Bene BENEFIT SUMMARY
# PAG 3
# x1 = 18.8398, y1 = 181.84859999999992, x2 = 591.2001705475, y2 = 274.33489999999995
# Got stderr: Jul 17, 2023 8:48:21 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 17, 2023 8:48:22 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Line Line
# Bene BENEFIT SUMMARY
# PAG 4
# x1 = 18.8398, y1 = 286.72860000000003, x2 = 591.2001705475, y2 = 360.0152
# Got stderr: Jul 17, 2023 8:48:22 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 17, 2023 8:48:22 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn

# %%
print(len(dfs))
dfs[0]
# Out:
# 3
#   Line             Submitted Alt Tooth   Date of Submitted.1 Considered  \
# 1    1   D0120/Periodic Eval        FM  06/27/23       85.00      33.00
# 2    2  D1120/Child Cleaning        FM  06/27/23       95.00      54.00
# 3    3    D0272/Bitewing - 2        FM  06/27/23       65.00      46.00
# 4    4   D1206/Fluoride Varn        FM  06/27/23       60.00      29.00
# 5                                         TOTALS      305.00     162.00
#
#   Covered Deductible Coverage Benefit
# 1   33.00                100%   33.00
# 2   54.00                100%   54.00
# 3   46.00                100%   46.00
# 4   29.00                100%   29.00
# 5  162.00                0.00  162.00

# %%
search_string = 'TOTALS'
final = []
stack_list = []
for d in dfs:
    last_row = d.iloc[-1]
    col = last_row[4]
    
    print(col)
    print(type(col))
    if 'TOTALS' in col:
        print("In the if")
        if stack_list:
            new_df = pd.concat(stack_list + [d] , axis=0)
            final.append(new_df)
            stack_list = []
        else:
            final.append(d)    
    else:
        stack_list.append(d)
# Out:
# TOTALS
# <class 'str'>
# In the if
# TOTALS
# <class 'str'>
# In the if
# TOTALS
# <class 'str'>
# In the if

# %%
print(len(final))
# Out:
# 3

# %%
tdfs =[]

for df in final:
    df = df[~df.apply(lambda row: row.astype(str).str.contains('TOTALS', case=False)).any(axis=1)]
    df.rename(columns={'Date of': 'Date'}, inplace=True)
    df.fillna('', inplace=True)
    df.drop('Line', axis=1, inplace=True)
    tdfs.append(df)
# Out:
# C:\Users\pytho\AppData\Local\Temp\ipykernel_30860\98455734.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Date of': 'Date'}, inplace=True)
# C:\Users\pytho\AppData\Local\Temp\ipykernel_30860\98455734.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna('', inplace=True)
# C:\Users\pytho\AppData\Local\Temp\ipykernel_30860\98455734.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Line', axis=1, inplace=True)
# C:\Users\pytho\AppData\Local\Temp\ipykernel_30860\98455734.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Date of': 'Date'}, inplace=True)
# C:\Users\pytho\AppData\Local\Temp\ipykernel_30860\98455734.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna('', inplace=True)
# C:\Users\pytho\AppData\Local\Temp\ipykernel_30860\98455734.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Line', axis=1, inplace=True)
# C:\Users\pytho\AppData\Local\Temp\ipykernel_30860\98455734.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Date of': 'Date'}, inplace=True)
# C:\Users\pytho\AppData\Local\Temp\ipykernel_30860\98455734.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna('', inplace=True)
# C:\Users\pytho\AppData\Local\Temp\ipykernel_30860\98455734.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Line', axis=1, inplace=True)

# %%
tdfs[0]
# Out:
#               Submitted Alt Tooth      Date Submitted.1 Considered Covered  \
# 1   D0120/Periodic Eval        FM  06/27/23       85.00      33.00   33.00
# 2  D1120/Child Cleaning        FM  06/27/23       95.00      54.00   54.00
# 3    D0272/Bitewing - 2        FM  06/27/23       65.00      46.00   46.00
# 4   D1206/Fluoride Varn        FM  06/27/23       60.00      29.00   29.00
#
#   Deductible Coverage Benefit
# 1                100%   33.00
# 2                100%   54.00
# 3                100%   46.00
# 4                100%   29.00

# %%
new_dict = []
for td in tdfs:
    tab = td.to_dict(orient='records')
    for i in range(len(tab)):
        new_dict.append(tab[i])
    
#     new_dict.append(td.to_dict(orient='records'))

# %%
print(len(new_dict))
# Out:
# 14

# %%
tab_dict = []

change_keys = [("Alt","AltCode"),("Tooth", "ToothNo"),("Date", "ServiceDate"), ("Submitted.1", "SubmittedCharges"),
               ("Benefit", "PayableAmount"), ("Considered", "ActualAllowed"),
               ("Deductible", "ContractualObligations"),("Covered", "CoveredCharge"),("Coverage", "CoveragePercent")]
for d in new_dict:
    for k in change_keys:
        old_key = k[0]
        new_key = k[1]
        value = d[old_key]
        d[new_key] = value
        
        
    for k in change_keys:
        del d[k[0]]
    print("D",d)
    tab_dict.append(d)
# Out:
# D {'Submitted': 'D0120/Periodic Eval', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '85.00', 'PayableAmount': '33.00', 'ActualAllowed': '33.00', 'ContractualObligations': '', 'CoveredCharge': '33.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1120/Child Cleaning', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '95.00', 'PayableAmount': '54.00', 'ActualAllowed': '54.00', 'ContractualObligations': '', 'CoveredCharge': '54.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0272/Bitewing - 2', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '65.00', 'PayableAmount': '46.00', 'ActualAllowed': '46.00', 'ContractualObligations': '', 'CoveredCharge': '46.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1206/Fluoride Varn', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '60.00', 'PayableAmount': '29.00', 'ActualAllowed': '29.00', 'ContractualObligations': '', 'CoveredCharge': '29.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0120/Periodic Eval', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '85.00', 'PayableAmount': '33.00', 'ActualAllowed': '33.00', 'ContractualObligations': '', 'CoveredCharge': '33.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1120/Child Cleaning', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '95.00', 'PayableAmount': '54.00', 'ActualAllowed': '54.00', 'ContractualObligations': '', 'CoveredCharge': '54.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0272/Bitewing - 2', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '65.00', 'PayableAmount': '46.00', 'ActualAllowed': '46.00', 'ContractualObligations': '', 'CoveredCharge': '46.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1206/Fluoride Varn', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '60.00', 'PayableAmount': '29.00', 'ActualAllowed': '29.00', 'ContractualObligations': '', 'CoveredCharge': '29.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0230/Periapical Add', 'AltCode': 'D0220', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '35.00', 'PayableAmount': '22.00', 'ActualAllowed': '22.00', 'ContractualObligations': '', 'CoveredCharge': '22.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0230/Periapical Add', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '35.00', 'PayableAmount': '16.00', 'ActualAllowed': '16.00', 'ContractualObligations': '', 'CoveredCharge': '16.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0120/Periodic Eval', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '85.00', 'PayableAmount': '33.00', 'ActualAllowed': '33.00', 'ContractualObligations': '', 'CoveredCharge': '33.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1120/Child Cleaning', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '95.00', 'PayableAmount': '54.00', 'ActualAllowed': '54.00', 'ContractualObligations': '', 'CoveredCharge': '54.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0272/Bitewing - 2', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '65.00', 'PayableAmount': '46.00', 'ActualAllowed': '46.00', 'ContractualObligations': '', 'CoveredCharge': '46.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1206/Fluoride Varn', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '06/27/23', 'SubmittedCharges': '60.00', 'PayableAmount': '29.00', 'ActualAllowed': '29.00', 'ContractualObligations': '', 'CoveredCharge': '29.00', 'CoveragePercent': '100%'}

# %%
tab_dict
# Out:
# [{'Submitted': 'D0120/Periodic Eval',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '85.00',
#   'PayableAmount': '33.00',
#   'ActualAllowed': '33.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '33.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '95.00',
#   'PayableAmount': '54.00',
#   'ActualAllowed': '54.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '54.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '65.00',
#   'PayableAmount': '46.00',
#   'ActualAllowed': '46.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '46.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '60.00',
#   'PayableAmount': '29.00',
#   'ActualAllowed': '29.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '29.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '85.00',
#   'PayableAmount': '33.00',
#   'ActualAllowed': '33.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '33.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '95.00',
#   'PayableAmount': '54.00',
#   'ActualAllowed': '54.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '54.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '65.00',
#   'PayableAmount': '46.00',
#   'ActualAllowed': '46.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '46.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '60.00',
#   'PayableAmount': '29.00',
#   'ActualAllowed': '29.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '29.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0230/Periapical Add',
#   'AltCode': 'D0220',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '35.00',
#   'PayableAmount': '22.00',
#   'ActualAllowed': '22.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '22.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0230/Periapical Add',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '35.00',
#   'PayableAmount': '16.00',
#   'ActualAllowed': '16.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '16.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '85.00',
#   'PayableAmount': '33.00',
#   'ActualAllowed': '33.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '33.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '95.00',
#   'PayableAmount': '54.00',
#   'ActualAllowed': '54.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '54.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '65.00',
#   'PayableAmount': '46.00',
#   'ActualAllowed': '46.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '46.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '06/27/23',
#   'SubmittedCharges': '60.00',
#   'PayableAmount': '29.00',
#   'ActualAllowed': '29.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '29.00',
#   'CoveragePercent': '100%'}]

# %%
# dfs = []
# x2 = 0
# for text_d in text_list:
#     x = text_d['cordx']
#     if x2<x:
#         x2 = text_d['cordx']
# x2 = x2+20      
# for i in range(len(text_list)):
#     x1 = y1 = y2 = ''
#     if 'Line' in text_list[i]['text']:
#         print("Line", text_list[i]['text'])
#         x1 = text_list[i]['cordx']
#         y1 = text_list[i]['cordy']
#         page_number = text_list[i]['page'])
#         for j in range(i,len(text_list)):
#             if 'BENEFIT SUMMARY' in text_list[j]['text']:
#                 print("Bene", text_list[j]['text'])
#                 page = int(text_list[j]['page'])
#                 y2 = text_list[j]['cordy']
#                 print(f"x1 = {x1}, y1 = {y1}, x2 = {x2}, y2 = {y2}")
#                 tabula_dfs = tabula.read_pdf(pdf_path, guess=False, pages=page , stream=True, encoding="utf-8",
#                                  area=(y1, x1, y2, x2), multiple_tables=True)
#                 dfs.append(tabula_dfs[0])
                
#                 break
