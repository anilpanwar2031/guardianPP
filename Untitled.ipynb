# %%
my_list = [
    {"key1": "value3", "key2": "value4"},
    {"key1": "value1", "key2": "value2"},
    {"key1": "value1", "key2": "value5"}
]

# Specify the key-value pair to check for
target_key = "key1"
target_value = "value1"

# Find the index of the first matching dictionary
index = next((i for i, d in enumerate(my_list) if d.get(target_key) == target_value), None)

# Delete the dictionary if a match is found
if index is not None:
    del my_list[index]

print(my_list)
# Out:
# [{'key1': 'value3', 'key2': 'value4'}, {'key1': 'value1', 'key2': 'value5'}]

# %%
patients = [
        {
            "SubscriberID": "",
            "PatientName": "MARILYN LARKIN",
            "Relationship": "DAUGHTER",
            "ClaimId": "27129F13500",
            "PatientAccount": "120371633",
            "PlanNumber": "00042176",
            "SubscriberName": "DANIEL LARKIN",
            "PlanType": "SPEED OF LIGHT OPS, LLC",
            "TransactionFee": "",
            "url": "",
            "Notes": "REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE Submitted ADA Codes/DescriptionTooth No.Date of ServiceSubmitted ChargeCoverage PercentAlt CodeConsidered ChargeCovered ChargeDeductible AmountBenefit AmountLine No.Claim Number: Patient Name:27128F13500 ANDREW LARKIN SPEED OF LIGHT OPS, LLCPatient Account No.: Employee Name:120371632 DANIEL LARKINPlan Number: Relationship: SON00042176 Planholder: 1 D0120/Periodic Eval 23.00 23.00 05/11/23 23.00 39.00 100% FM",
            "PayerClaimID": "27129F13500",
            "TotalAmount": "$472.00",
            "ClaimStatus": "",
            "RenderingProvider": "BRADLEY J SMITH",
            "Payer": "PO BOX 981572 EL PASO, TX  79998-1572",
            "PayerName": "Guardian",
            "PayerAddress": "PO BOX 981572",
            "PayerCity": "EL PASO",
            "PayerState": "TX",
            "PayerZip": "79998-1572",
            "Payee": "UT BCDO SPECIALTY DENTAL SERVI 8822 S REDWOOD RD STE 201 WEST JORDAN, UT  84088-9336",
            "PayeeName": "UT BCDO SPECIALTY DENTAL SERVI",
            "PayeeAddress": "8822 S REDWOOD RD STE 201",
            "PayeeCity": "WEST JORDAN",
            "PayeeState": "UT",
            "PayeeZip": "84088-9336",
            "Provider": "BRADLEY J SMITH",
            "EFT_CheckDate": "05/16/23",
            "EFT_CheckNumber": "187889273",
            "PaidByOtherInsurance": "$0.00",
            "TotalBenefitPaid": "$ 38.00",
            "PatientResp": "$0.00",
            "TotalBenfitPayable": "$38.00",
            "HigherAllowable": "$38.00",
            "PPGridViewId": "",
            "PPTransPayorListID": "",
            "PayeeTaxID": "",
            "PayerContact": "(800) 541-7846",
            "PayerID": "",
            "PaymentMethodCode": "",
            "RecordID": "",
            "RenderingProviderID": "",
            "RecordId": 1
        },
        {
            "SubscriberID": "",
            "PatientName": "ANDREW LARKIN",
            "Relationship": "SON",
            "ClaimId": "27128F13500",
            "PatientAccount": "120371632",
            "PlanNumber": "00042176",
            "SubscriberName": "DANIEL LARKIN",
            "PlanType": "SPEED OF LIGHT OPS, LLC",
OSTER LARKIN SPEED OF LIGHT OPS, LLCPatient Account No.: Employee Name:120371631 DANIEL LARKINPlan Number: Relationship: SON00042176 Planholder: 180.00 299.00 180.00 180.00 $180.00 PAID BY OTHER INSURANCE..... $0.00 ADJUSTMENTS............................... $0.00 TOTAL BENEFIT PAID.................. $ 180.00 PATIENT'S RESPONSIBILITY..... $0.00TOTALS TOTAL BENEFIT PAYABLE.........BENEFIT SUMMARY $180.00 HIGHER ALLOWABLE.................. 0.00 Remarks for claim # 27127F13500: REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE",
            "PayerClaimID": "27128F13500",
            "TotalAmount": "$472.00",
            "ClaimStatus": "",
            "RenderingProvider": "BRADLEY J SMITH",
            "Payer": "PO BOX 981572 EL PASO, TX  79998-1572",
            "PayerName": "Guardian",
            "PayerAddress": "PO BOX 981572",
            "PayerCity": "EL PASO",
            "PayerState": "TX",
            "PayerZip": "79998-1572",
            "Payee": "UT BCDO SPECIALTY DENTAL SERVI 8822 S REDWOOD RD STE 201 WEST JORDAN, UT  84088-9336",
            "PayeeName": "UT BCDO SPECIALTY DENTAL SERVI",
            "PayeeAddress": "8822 S REDWOOD RD STE 201",
            "PayeeCity": "WEST JORDAN",
            "PayeeState": "UT",
            "PayeeZip": "84088-9336",
            "Provider": "BRADLEY J SMITH",
            "EFT_CheckDate": "05/16/23",
            "EFT_CheckNumber": "187889273",
            "PaidByOtherInsurance": "$0.00",
            "TotalBenefitPaid": "$ 127.00",
            "PatientResp": "$0.00",
            "TotalBenfitPayable": "$127.00",
            "HigherAllowable": "$127.00",
            "PPGridViewId": "",
            "PPTransPayorListID": "",
            "PayeeTaxID": "",
            "PayerContact": "(800) 541-7846",
            "PayerID": "",
            "PaymentMethodCode": "",
            "RecordID": "",
            "RenderingProviderID": "",
            "RecordId": 2
        },
        {
            "SubscriberID": "",
            "PatientName": "ANDREW LARKIN",
            "Relationship": "SON",
            "ClaimId": "27128F13500",
            "PatientAccount": "120371632",
            "PlanNumber": "00042176",
            "SubscriberName": "DANIEL LARKIN",
            "PlanType": "SPEED OF LIGHT OPS, LLC",
            "TransactionFee": "",
            "url": "",
            "Notes": "REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE Submitted ADA Codes/DescriptionTooth No.Date of ServiceSubmitted ChargeCoverage PercentAlt CodeConsidered ChargeCovered ChargeDeductible AmountBenefit AmountLine No.Claim Number: Patient Name:27126F13500 COLLIN LARKIN SPEED OF LIGHT OPS, LLCPatient Account No.: Employee Name:120371630 DANIEL LARKINPlan Number: Relationship: SON00042176 Planholder: 1 D0120/Periodic Eval 23.00 23.00 05/11/23 23.00 39.00 100% FM 2 D0240/Occlusal Image 16.00 16.00 05/11/23 16.00 27.00 100% FM 3 D0240/Occlusal Image 16.00 16.00 05/11/23 16.00 27.00 100% FM 4
            "Payer": "PO BOX 981572 EL PASO, TX  79998-1572",
            "PayerName": "Guardian",
            "PayerAddress": "PO BOX 981572",
            "PayerCity": "EL PASO",
            "PayerState": "TX",
            "PayerZip": "79998-1572",
            "Payee": "UT BCDO SPECIALTY DENTAL SERVI 8822 S REDWOOD RD STE 201 WEST JORDAN, UT  84088-9336",
            "PayeeName": "UT BCDO SPECIALTY DENTAL SERVI",
            "PayeeAddress": "8822 S REDWOOD RD STE 201",
            "PayeeCity": "WEST JORDAN",
            "PayeeState": "UT",
            "PayeeZip": "84088-9336",
            "Provider": "BRADLEY J SMITH",
            "EFT_CheckDate": "05/16/23",
            "EFT_CheckNumber": "187889273",
            "PaidByOtherInsurance": "$0.00",
            "TotalBenefitPaid": "$ 127.00",
            "PatientResp": "$0.00",
            "TotalBenfitPayable": "$127.00",
            "HigherAllowable": "$127.00",
            "PPGridViewId": "",
            "PPTransPayorListID": "",
            "PayeeTaxID": "",
            "PayerContact": "(800) 541-7846",
            "PayerID": "",
            "PaymentMethodCode": "",
            "RecordID": "",
            "RenderingProviderID": "",
            "RecordId": 3
        },
        {
            "SubscriberID": "",
            "PatientName": "COLLIN LARKIN",
            "Relationship": "SON",
            "ClaimId": "27126F13500",
            "PatientAccount": "120371630",
            "PlanNumber": "00042176",
            "SubscriberName": "DANIEL LARKIN",
            "PlanType": "SPEED OF LIGHT OPS, LLC",
            "TransactionFee": "",
            "url": "",
            "Notes": "REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE Submitted ADA Codes/DescriptionTooth No.Date of ServiceSubmitted ChargeCoverage PercentAlt CodeConsidered ChargeCovered ChargeDeductible AmountBenefit AmountLine No.Claim Number: Patient Name:27127F13500 FOSTER LARKIN SPEED OF LIGHT OPS, LLCPatient Account No.: Employee Name:120371631 DANIEL LARKINPlan Number: Relationship: SON00042176 Planholder: 1 D0120/Periodic Eval 23.00 23.00 05/11/23 23.00 39.00 100% FM 2 D0272/Bitewing - 2 22.00 22.00 05/11/23 22.00 36.00 100% FM 3 D1120/Child Cleaning 35.00 35.00 05/11/23 35.00 52.00 100% FM 4 D1206/Fluoride Varn 15.00 15.00 05/11/23 15.00 36.00 100% FM 5 D0330/Panoramic 53.00 53.00 05/11/23 53.00 82.00 100% FM 6 D0240/Occlusal Image 16.00 16.00 05/11/23 16.00 27.00 100% FM 7 D0240/Occlusal Image 16.00 16.00 05/11/23 16.00 27.00 100% FMP627402800G   ENV 30298      2 OF 2 F P627402800G190127    If you have any questions contact:(800) 541-7846 WWW.GUARDIANANYTIME.COM Provider: Date:BRADLEY J SMITH 05/16/23EL PASO TX 79998-1572PO BOX 981572 Payee: Check No.: Payment Amount:UT BCDO SPECIALTY DENTAL SER 187889273 $472.00 Submitted ADA Codes/DescriptionTooth No.Date of ServiceSubmitted ChargeCoverage PercentAlt CodeConsidered ChargeCovered ChargeDeductible AmountBenefit AmountLine No.Claim Number: Patient Name:27127F13500 FOSTER LARKIN SPEED OF LIGHT OPS, LLCPatient Account No.: Employee Name:120371631 DANIEL LARKINPlan Number: Relationship: SON00042176 Planholder: 180.00 299.00 180.00 180.00 $180.00 PAID BY OTHER INSURANCE..... $0.00 ADJUSTMENTS............................... $0.00 TOTAL BENEFIT PAID.................. $ 180.00 PATIENT'S RESPONSIBILITY..... $0.00TOTALS TOTAL BENEFIT PAYABLE.........BENEFIT SUMMARY $180.00 HIGHER ALLOWABLE.................. 0.00 Remarks for claim # 27127F13500: REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE",
            "PayerClaimID": "27126F13500",
            "TotalAmount": "$472.00",
            "ClaimStatus": "",
            "RenderingProvider": "BRADLEY J SMITH",
            "Payer": "PO BOX 981572 EL PASO, TX  79998-1572",
            "PayerName": "Guardian",
            "PayerAddress": "PO BOX 981572",
            "PayerCity": "EL PASO",
            "PayerState": "TX",
            "PayerZip": "79998-1572",
            "Payee": "UT BCDO SPECIALTY DENTAL SERVI 8822 S REDWOOD RD STE 201 WEST JORDAN, UT  84088-9336",
            "PayeeName": "UT BCDO SPECIALTY DENTAL SERVI",
            "PayeeAddress": "8822 S REDWOOD RD STE 201",
            "PayeeCity": "WEST JORDAN",
            "PayeeState": "UT",
            "PayeeZip": "84088-9336",
            "Provider": "BRADLEY J SMITH",
            "EFT_CheckDate": "05/16/23",
            "EFT_CheckNumber": "187889273",
            "PaidByOtherInsurance": "$0.00",
            "TotalBenefitPaid": "$ 127.00",
            "PatientResp": "$0.00",
            "TotalBenfitPayable": "$127.00",
            "HigherAllowable": "$127.00",
            "PPGridViewId": "",
            "PPTransPayorListID": "",
            "PayeeTaxID": "",
            "PayerContact": "(800) 541-7846",
            "PayerID": "",
            "PaymentMethodCode": "",
            "RecordID": "",
            "RenderingProviderID": "",
            "RecordId": 4
        },
        {
            "SubscriberID": "",
            "PatientName": "FOSTER LARKIN",
            "Relationship": "SON",
            "ClaimId": "27127F13500",
            "PatientAccount": "120371631",
            "PlanNumber": "00042176",
            "SubscriberName": "DANIEL LARKIN",
            "PlanType": "SPEED OF LIGHT OPS, LLC",
            "TransactionFee": "",
            "url": "",
            "Notes": "REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE",
            "PayerClaimID": "27127F13500",
            "TotalAmount": "$472.00",
            "ClaimStatus": "",
            "RenderingProvider": "BRADLEY J SMITH",
            "Payer": "PO BOX 981572 EL PASO, TX  79998-1572",
            "PayerName": "Guardian",
            "PayerAddress": "PO BOX 981572",
            "PayerCity": "EL PASO",
            "PayerState": "TX",
            "PayerZip": "79998-1572",
            "Payee": "UT BCDO SPECIALTY DENTAL SERVI 8822 S REDWOOD RD STE 201 WEST JORDAN, UT  84088-9336",
            "PayeeName": "UT BCDO SPECIALTY DENTAL SERVI",
            "PayeeAddress": "8822 S REDWOOD RD STE 201",
            "PayeeCity": "WEST JORDAN",
            "PayeeState": "UT",
            "PayeeZip": "84088-9336",
            "Provider": "BRADLEY J SMITH",
            "EFT_CheckDate": "05/16/23",
            "EFT_CheckNumber": "187889273",
            "PaidByOtherInsurance": "$0.00",
            "TotalBenefitPaid": "$ 127.00",
            "PatientResp": "$0.00",
            "TotalBenfitPayable": "$127.00",
            "HigherAllowable": "$127.00",
            "PPGridViewId": "",
            "PPTransPayorListID": "",
            "PayeeTaxID": "",
            "PayerContact": "(800) 541-7846",
            "PayerID": "",
            "PaymentMethodCode": "",
            "RecordID": "",
            "RenderingProviderID": "",
            "RecordId": 5
        },
        {
            "SubscriberID": "",
            "PatientName": "FOSTER LARKIN",
            "Relationship": "SON",
            "ClaimId": "27127F13500",
            "PatientAccount": "120371631",
            "PlanNumber": "00042176",
            "SubscriberName": "DANIEL LARKIN",
            "PlanType": "SPEED OF LIGHT OPS, LLC",
            "TransactionFee": "",
            "url": "",
            "Notes": "REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE",
            "PayerClaimID": "27127F13500",
            "TotalAmount": "$472.00",
            "ClaimStatus": "",
            "RenderingProvider": "BRADLEY J SMITH",
            "Payer": "PO BOX 981572 EL PASO, TX  79998-1572",
            "PayerName": "Guardian",
            "PayerAddress": "PO BOX 981572",
            "PayerCity": "EL PASO",
            "PayerState": "TX",
            "PayerZip": "79998-1572",
            "Payee": "UT BCDO SPECIALTY DENTAL SERVI 8822 S REDWOOD RD STE 201 WEST JORDAN, UT  84088-9336",
            "PayeeName": "UT BCDO SPECIALTY DENTAL SERVI",
            "PayeeAddress": "8822 S REDWOOD RD STE 201",
            "PayeeCity": "WEST JORDAN",
            "PayeeState": "UT",
            "PayeeZip": "84088-9336",
            "Provider": "BRADLEY J SMITH",
            "EFT_CheckDate": "05/16/23",
            "EFT_CheckNumber": "187889273",
            "PaidByOtherInsurance": "$0.00",
            "TotalBenefitPaid": "$ 127.00",
            "PatientResp": "$0.00",
            "TotalBenfitPayable": "$127.00",
            "HigherAllowable": "$127.00",
            "PPGridViewId": "",
            "PPTransPayorListID": "",
            "PayeeTaxID": "",
            "PayerContact": "(800) 541-7846",
            "PayerID": "",
            "PaymentMethodCode": "",
            "RecordID": "",
            "RenderingProviderID": "",
            "RecordId": 6
        }
    ]

# %%
pl = len(patients)
indexlist = []
for i in range(pl):
    print(patients[i]["ClaimId"])
    try:
        for j in range(i+1,pl+1):
            try:
                if patients[i]["ClaimId"] == patients[j]["ClaimId"]:
                    indexlist.append(j)
            except:
                pass
    except:
        pass
    
indexlist.sort(reverse=True)

for index in indexlist:
    del patients[index]
print(len(patients))   
for p in patients:
    print(p)
    print("\n")
# Out:
# 27129F13500
# 27128F13500
# 27126F13500
# 27127F13500
# 4
# ...
