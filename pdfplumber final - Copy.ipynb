# %%
import tabula
import pdfplumber

# %%
pdf_path = "guardian.pdf"

# %%
def extract_text_coordinates(pdf_path):
    text_list = []
    with pdfplumber.open(pdf_path) as pdf:
        # Iterate through each page of the PDF
        for page_number in range(len(pdf.pages)):
            page = pdf.pages[page_number]
            page_number = page_number + 1
            # Extract the text content and its coordinates
            for element in page.extract_words(x_tolerance=1, y_tolerance=1, keep_blank_chars=True):
                text_dict = {}
                text = element["text"]
                x, y = element["x0"], element["top"]
                
                text_cord = f"Page {page_number + 1}: Text: {text} Coordinates: X={x}, Y={y}"
                text_dict.update({'page':page_number, 'text':text,'cordx':x,'cordy':y})
                text_list.append(text_dict)
    return text_list

text_list = extract_text_coordinates(pdf_path)

# %%
text_list
# Out:
# [{'page': 1,
#   'text': 'P627402800G',
#   'cordx': 110.4,
#   'cordy': 5.2835999999999785},
#  {'page': 1,
#   'text': 'P627402800G',
#   'cordx': 31.6801,
#   'cordy': 12.72359999999992},
#  {'page': 1,
#   'text': 'PO BOX 981572',
#   'cordx': 94.6801,
#   'cordy': 28.301400000000058},
#  {'page': 1,
#   'text': 'EL PASO, TX  79998-1572',
#   'cordx': 94.6801,
#   'cordy': 38.5014000000001},
#  {'page': 1,
#   'text': 'GROUP PLAN ADMINISTRATORS',
#   'cordx': 380.4,
#   'cordy': 64.18140000000005},
#  {'page': 1,
#   'text': ' 020105   ',
#   'cordx': 271.92023408,
#   'cordy': 69.48339999999996},
#  {'page': 1, 'text': 'If you have any', 'cordx': 294.84, 'cordy': 74.8614},
#  {'page': 1,
#   'text': '(800) 541-7846',
#   'cordx': 380.40012142879993,
#   'cordy': 75.58140000000003},
#  {'page': 1,
#   'text': 'Electronic Service Requested',
#   'cordx': 94.6801,
#   'cordy': 80.02130000000011},
#  {'page': 1,
#   'text': 'questions contact:',
#   'cordx': 294.84,
#   'cordy': 86.02120000000002},
#  {'page': 1,
#   'text': 'WWW.GUARDIANANYTIME.COM',
#   'cordx': 380.40012142879993,
#   'cordy': 86.02120000000002},
#  {'page': 1,
#   'text': 'Provider:',
#   'cordx': 294.8399999999999,
#   'cordy': 101.8614},
#  {'page': 1,
#   'text': 'DAVID HADLEY',
#   'cordx': 382.6802169127999,
#   'cordy': 100.90124400000002},
#  {'page': 1,
#   'text': 'ALL FOR AADC 840',
#   'cordx': 170.75986395799998,
#   'cordy': 109.34399999999994},
#  {'page': 1,
#   'text': 'Date:',
#   'cordx': 294.8399999999999,
#   'cordy': 111.58134400000006},
#  {'page': 1,
#   'text': '05/31/2023',
#   'cordx': 382.6802169127999,
#   'cordy': 111.46142200000008},
#  {'page': 1,
#   'text': '31349 0.5738 AB 0.504',
#   'cordx': 49.9199,
#   'cordy': 118.34399999999994},
#  {'page': 1, 'text': 'Payee:', 'cordx': 294.84, 'cordy': 121.30140000000006},
#  {'page': 1,
#   'text': 'UT BCDO SPECIALTY DENTAL SER',
#   'cordx': 382.6802169128,
#   'cordy': 120.46152000000006},
#  {'page': 1,
#   'text': 'FDADFDATFDDAADTFFTFADFAFTTDAADFFFTATFAFFAAFDAFATDATADATTDFDATTFFD',
#   'cordx': 49.8,
#   'cordy': 125.8667999999999},
#  {'page': 1,
#   'text': 'Check No.:',
#   'cordx': 294.84,
#   'cordy': 131.02132000000006},
#  {'page': 1,
#   'text': '188218572',
#   'cordx': 382.6802169128,
#   'cordy': 130.90132000000006},
#  {'page': 1,
#   'text': 'Payment Amount:',
#   'cordx': 294.84000000000003,
#   'cordy': 140.86148000000003},
#  {'page': 1,
#   'text': '$160.00',
#   'cordx': 382.6802169128,
#   'cordy': 139.90132400000005},
#  {'page': 1,
#   'text': 'UT BCDO SPECIALTY DENTAL SERVI',
#   'cordx': 49.68010000000001,
#   'cordy': 144.57514000000003},
#  {'page': 1,
#   'text': '517',
#   'cordx': 247.319909575,
#   'cordy': 147.28869999999995},
#  {'page': 1,
#   'text': '3401 N CENTER ST STE 250',
#   'cordx': 49.68010000000001,
#   'cordy': 151.29506000000003},
#  {'page': 1,
#   'text': 'Expedite cash flow with e-payments. Sign up today!',
#   'cordx': 302.28,
#   'cordy': 152.46000000000004},
#  {'page': 1,
#   'text': 'LEHI, UT  84043-7501',
#   'cordx': 49.6801,
#   'cordy': 158.49504000000002},
#  {'page': 1,
#   'text': 'Guardian has contracted with Change Healthcare, a leading provider of ',
#   'cordx': 292.68,
#   'cordy': 167.65499999999997},
#  {'page': 1,
#   'text': 'revenue and payment cycle solutions, to deliver Electronic Funds Transfer ',
#   'cordx': 292.68,
#   'cordy': 177.85500000000002},
#  {'page': 1,
#   'text': '(EFT) services! Sign-up today by going to www.changehealthcare.com/support',
#   'cordx': 292.68,
#   'cordy': 188.05500000000006},
#  {'page': 1,
#   'text': '/customer-resources/enrollment-services for more information. Enrollment for ',
#   'cordx': 292.68,
#   'cordy': 198.255},
#  {'page': 1,
#   'text': 'this service is offered to you at no additional cost and is available online or by ',
#   'cordx': 292.680144546,
#   'cordy': 208.45500000000004},
#  {'page': 1,
#   'text': 'calling 1.866.777.0713 and selecting Option 1.',
#   'cordx': 292.680144546,
#   'cordy': 218.6550000000001},
#  {'page': 1,
#   'text': 'PROVIDER EXPLANATION OF BENEFITS - THIS IS NOT A BILL',
#   'cordx': 100.8,
#   'cordy': 247.89060000000006},
#  {'page': 1,
#   'text': 'Important!  Please examine this statement for accuracy.  Save this statement for tax purposes.',
#   'cordx': 41.039820415799994,
#   'cordy': 266.17870000000005},
#  {'page': 1,
#   'text': 'Patient Account No.:121148667',
#   'cordx': 225.83943376399998,
#   'cordy': 282.34128},
#  {'page': 1,
#   'text': 'Claim Number:',
#   'cordx': 18.8398,
#   'cordy': 284.02139999999997},
#  {'page': 1, 'text': '32884F15100', 'cordx': 93.119811492, 'cordy': 283.90148},
#  {'page': 1,
#   'text': 'Plan Number:00518516',
#   'cordx': 465.83932013599997,
#   'cordy': 284.620998},
#  {'page': 1,
#   'text': 'Patient Name:',
#   'cordx': 18.8398,
#   'cordy': 293.02139999999997},
#  {'page': 1,
#   'text': 'LANAYA ROPER',
#   'cordx': 93.119811492,
#   'cordy': 292.90148},
#  {'page': 1,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 293.02137999999997},
#  {'page': 1,
#   'text': 'BLAKE ROPER',
#   'cordx': 315.119469344,
#   'cordy': 292.90108},
#  {'page': 1,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 295.18111999999996},
#  {'page': 1, 'text': 'DAUGHTER', 'cordx': 526.6794936904, 'cordy': 295.061198},
#  {'page': 1,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 303.46119799999997},
#  {'page': 1,
#   'text': 'ONBOARDIQ, INC.',
#   'cordx': 93.119811492,
#   'cordy': 303.34128},
#  {'page': 1, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 314.5686},
#  {'page': 1,
#   'text': 'Submitted',
#   'cordx': 72.3602,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Alt',
#   'cordx': 155.16029745327495,
#   'cordy': 313.84860000000003},
#  {'page': 1, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Date of',
#   'cordx': 224.64004397875,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Coverage',
#   'cordx': 490.680086151525,
#   'cordy': 313.84860000000003},
#  {'page': 1, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 313.84860000000003},
#  {'page': 1, 'text': 'No.', 'cordx': 21.719875162250002, 'cordy': 323.68852},
#  {'page': 1,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Code',
#   'cordx': 151.56030081277495,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'No.',
#   'cordx': 186.96031734874998,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 279.120124551525,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Amount',
#   'cordx': 442.320378138025,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Percent',
#   'cordx': 493.919927428275,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Amount',
#   'cordx': 547.1998391022499,
#   'cordy': 322.96891000000005},
#  {'page': 1, 'text': '1', 'cordx': 24.2398, 'cordy': 335.3286},
#  {'page': 1,
#   'text': 'D0120/Periodic Eval',
#   'cordx': 39.83979369292,
#   'cordy': 335.3286},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 335.3286},
#  {'page': 1, 'text': '05/30/23', 'cordx': 224.8801224475, 'cordy': 334.608678},
#  {'page': 1, 'text': '39.00', 'cordx': 302.0403026225, 'cordy': 334.608678},
#  {'page': 1, 'text': '23.00', 'cordx': 359.1601348725, 'cordy': 335.3286},
#  {'page': 1, 'text': '23.00', 'cordx': 409.439859725, 'cordy': 335.3286},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 335.3286},
#  {'page': 1, 'text': '23.00', 'cordx': 571.2001705475, 'cordy': 336.168838},
#  {'page': 1, 'text': '2', 'cordx': 24.2398, 'cordy': 345.0486},
#  {'page': 1,
#   'text': 'D0220/Periapical 1st',
#   'cordx': 39.83979369292,
#   'cordy': 345.0486},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 345.0486},
#  {'page': 1, 'text': '05/30/23', 'cordx': 224.8801224475, 'cordy': 344.208756},
#  {'page': 1, 'text': '22.00', 'cordx': 302.0403026225, 'cordy': 344.208756},
#  {'page': 1, 'text': '13.00', 'cordx': 359.1601348725, 'cordy': 345.0486},
#  {'page': 1, 'text': '13.00', 'cordx': 409.439859725, 'cordy': 345.0486},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 345.0486},
#  {'page': 1, 'text': '13.00', 'cordx': 571.2001705475, 'cordy': 345.768916},
#  {'page': 1, 'text': '3', 'cordx': 24.2398, 'cordy': 354.6486},
#  {'page': 1,
#   'text': 'D0230/Periapical Add',
#   'cordx': 39.83979369292,
#   'cordy': 354.6486},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 354.6486},
#  {'page': 1,
#   'text': '05/30/23',
#   'cordx': 224.87972321750004,
#   'cordy': 353.928678},
#  {'page': 1,
#   'text': '19.00',
#   'cordx': 302.03990339250004,
#   'cordy': 353.928678},
#  {'page': 1, 'text': '8.00', 'cordx': 363.23986624250006, 'cordy': 354.6486},
#  {'page': 1, 'text': '8.00', 'cordx': 413.51999032500004, 'cordy': 354.6486},
#  {'page': 1, 'text': '100%', 'cordx': 496.80026659250007, 'cordy': 354.6486},
#  {'page': 1, 'text': '8.00', 'cordx': 575.2799019175001, 'cordy': 355.368908},
#  {'page': 1, 'text': '4', 'cordx': 24.2398, 'cordy': 364.2486},
#  {'page': 1,
#   'text': 'D0272/Bitewing - 2',
#   'cordx': 39.83979369292,
#   'cordy': 364.2486},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 364.2486},
#  {'page': 1,
#   'text': '05/30/23',
#   'cordx': 224.88022225500004,
#   'cordy': 363.528678},
#  {'page': 1, 'text': '36.00', 'cordx': 302.04040243, 'cordy': 363.528678},
#  {'page': 1, 'text': '21.00', 'cordx': 359.16023468000003, 'cordy': 364.2486},
#  {'page': 1, 'text': '0.00', 'cordx': 413.51999032500004, 'cordy': 364.2486},
#  {'page': 1, 'text': '100%', 'cordx': 496.80076563, 'cordy': 364.2486},
#  {'page': 1, 'text': '0.00', 'cordx': 575.280400955, 'cordy': 365.088838},
#  {'page': 1, 'text': '5', 'cordx': 24.2398, 'cordy': 373.9686},
#  {'page': 1,
#   'text': 'D1120/Child Cleaning',
#   'cordx': 39.83979369292,
#   'cordy': 373.9686},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 373.9686},
#  {'page': 1,
#   'text': '05/30/23',
#   'cordx': 224.8801224475,
#   'cordy': 373.12836599999997},
#  {'page': 1,
#   'text': '52.00',
#   'cordx': 302.0403026225,
#   'cordy': 373.12836599999997},
#  {'page': 1, 'text': '36.00', 'cordx': 359.1601348725, 'cordy': 373.9686},
#  {'page': 1, 'text': '36.00', 'cordx': 409.439859725, 'cordy': 373.9686},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 373.9686},
#  {'page': 1,
#   'text': '36.00',
#   'cordx': 571.2001705475,
#   'cordy': 374.68852599999997},
#  {'page': 1,
#   'text': 'TOTALS',
#   'cordx': 223.07999323199996,
#   'cordy': 383.89518},
#  {'page': 1, 'text': '168.00', 'cordx': 297.36, 'cordy': 383.5686},
#  {'page': 1, 'text': '101.00', 'cordx': 355.08, 'cordy': 383.5686},
#  {'page': 1, 'text': '80.00', 'cordx': 409.43980395182996, 'cordy': 383.5686},
#  {'page': 1,
#   'text': '0.00',
#   'cordx': 499.080260925,
#   'cordy': 383.56850000000003},
#  {'page': 1, 'text': '80.00', 'cordx': 571.2, 'cordy': 383.5686},
#  {'page': 1, 'text': ' ', 'cordx': 22.6801, 'cordy': 394.84860000000003},
#  {'page': 1,
#   'text': 'BENEFIT SUMMARY',
#   'cordx': 444.59999176229996,
#   'cordy': 397.3349},
#  {'page': 1,
#   'text': 'TOTAL BENEFIT PAYABLE.........',
#   'cordx': 389.4,
#   'cordy': 408.615},
#  {'page': 1, 'text': '$80.00', 'cordx': 565.92, 'cordy': 408.615},
#  {'page': 1,
#   'text': 'HIGHER ALLOWABLE..................',
#   'cordx': 389.3999001933,
#   'cordy': 419.174778},
#  {'page': 1, 'text': '$80.00', 'cordx': 565.9200259473, 'cordy': 419.8947},
#  {'page': 1,
#   'text': 'PAID BY OTHER INSURANCE.....',
#   'cordx': 389.39987424599997,
#   'cordy': 428.8947},
#  {'page': 1, 'text': '$0.00', 'cordx': 570.480168123, 'cordy': 431.17478},
#  {'page': 1,
#   'text': 'ADJUSTMENTS...............................',
#   'cordx': 389.39987424599997,
#   'cordy': 440.17478},
#  {'page': 1, 'text': '$0.00', 'cordx': 570.47280238854, 'cordy': 440.17478},
#  {'page': 1,
#   'text': 'TOTAL BENEFIT PAID..................',
#   'cordx': 389.39987424599997,
#   'cordy': 451.33498},
#  {'page': 1, 'text': '$ 80.00', 'cordx': 563.63578394112, 'cordy': 451.33498},
#  {'page': 1,
#   'text': "PATIENT'S RESPONSIBILITY.....",
#   'cordx': 389.39987424599997,
#   'cordy': 462.61508},
#  {'page': 1, 'text': '$21.00', 'cordx': 565.90883163027, 'cordy': 462.61508},
#  {'page': 1,
#   'text': 'Remarks for claim # 32884F15100:',
#   'cordx': 18.1199,
#   'cordy': 488.175},
#  {'page': 1,
#   'text': 'A DENTALGUARD PARTICIPATING DENTIST HAS BEEN UTILIZED',
#   'cordx': 18.1199,
#   'cordy': 499.3352},
#  {'page': 1,
#   'text': '4.  The dental plan covers bitewing radiographic images only once in any 12 consecutive month period,',
#   'cordx': 18.1199,
#   'cordy': 508.9352},
#  {'page': 1,
#   'text': 'up to a maximum of four films or a set of 7-8 vertical films, in one visit.',
#   'cordx': 18.1199,
#   'cordy': 518.5352},
#  {'page': 1,
#   'text': 'Benefits are based on the use of a Preferred Contracted Dentist.',
#   'cordx': 18.1199,
#   'cordy': 528.25512},
#  {'page': 1,
#   'text': 'You have used     $0.00 of your personal Maximum Rollover Account.   $500.00 remains in your account',
#   'cordx': 18.1199,
#   'cordy': 537.85512},
#  {'page': 1,
#   'text': '10 Hudson Yards',
#   'cordx': 342.120394076,
#   'cordy': 595.09492},
#  {'page': 1,
#   'text': 'CHECK NO: 188218572',
#   'cordx': 445.68,
#   'cordy': 596.8614},
#  {'page': 1, 'text': 'New York, NY 10001', 'cordx': 342.12, 'cordy': 604.095},
#  {'page': 1,
#   'text': 'CHECK DATE: 06/01/23',
#   'cordx': 445.68,
#   'cordy': 610.3014000000001},
#  {'page': 1, 'text': 'AMOUNT', 'cordx': 488.4000390352, 'cordy': 625.3015},
#  {'page': 1, 'text': '51-44', 'cordx': 427.2, 'cordy': 626.49},
#  {'page': 1, 'text': '119', 'cordx': 429.7199212548, 'cordy': 636.9298},
#  {'page': 1, 'text': '****$160.00', 'cordx': 459.12, 'cordy': 638.0214},
#  {'page': 1, 'text': 'PAY', 'cordx': 49.91950020000007, 'cordy': 649.3012},
#  {'page': 1,
#   'text': 'One Hundred Sixty  Dollars',
#   'cordx': 74.39782837705638,
#   'cordy': 649.3012},
#  {'page': 1,
#   'text': 'Void unless presented ',
#   'cordx': 470.76,
#   'cordy': 653.6886},
#  {'page': 1,
#   'text': 'within 180 days',
#   'cordx': 482.3998500725,
#   'cordy': 662.80852},
#  {'page': 1, 'text': 'TO THE', 'cordx': 49.9199, 'cordy': 666.5814},
#  {'page': 1,
#   'text': 'UT BCDO SPECIALTY DENTAL SERVI',
#   'cordx': 114.119883328,
#   'cordy': 668.86151},
#  {'page': 1, 'text': 'ORDER OF', 'cordx': 49.9199, 'cordy': 677.7412},
#  {'page': 1,
#   'text': 'BANK OF AMERICA',
#   'cordx': 36.8398,
#   'cordy': 705.2099000000001},
#  {'page': 1,
#   'text': '150 WINDSOR STREET, HARTFORD, CT 06120',
#   'cordx': 36.8398,
#   'cordy': 712.04974},
#  {'page': 1,
#   'text': 'C188218572C',
#   'cordx': 94.91999359245003,
#   'cordy': 763.9888},
#  {'page': 1,
#   'text': 'A011900445A',
#   'cordx': 202.92002520884995,
#   'cordy': 763.9888},
#  {'page': 1, 'text': '42236C', 'cordx': 355.92000346094994, 'cordy': 763.9888},
#  {'page': 1,
#   'text': '        2 FO 1           94313 VNE',
#   'cordx': 14.403799999999999,
#   'cordy': 9.182313641940482},
#  {'page': 2,
#   'text': 'P627402800G',
#   'cordx': 110.4,
#   'cordy': 5.2835999999999785},
#  {'page': 2,
#   'text': 'P627402800G',
#   'cordx': 31.6801,
#   'cordy': 12.72359999999992},
#  {'page': 2,
#   'text': 'PO BOX 981572',
#   'cordx': 102.12018156879992,
#   'cordy': 37.30140000000017},
#  {'page': 2,
#   'text': 'EL PASO TX 79998-1572',
#   'cordx': 102.12018156879992,
#   'cordy': 46.901400000000194},
#  {'page': 2,
#   'text': 'If you have any',
#   'cordx': 294.84,
#   'cordy': 65.02140000000009},
#  {'page': 2,
#   'text': '(800) 541-7846',
#   'cordx': 380.40012142879993,
#   'cordy': 65.86170000000016},
#  {'page': 2,
#   'text': '    ',
#   'cordx': 271.92023408,
#   'cordy': 69.48339999999996},
#  {'page': 2,
#   'text': 'questions contact:',
#   'cordx': 294.84,
#   'cordy': 76.18160000000012},
#  {'page': 2,
#   'text': 'WWW.GUARDIANANYTIME.COM',
#   'cordx': 380.40012142879993,
#   'cordy': 76.30150000000015},
#  {'page': 2,
#   'text': 'DAVID HADLEY',
#   'cordx': 382.6802169127999,
#   'cordy': 93.4616000000002},
#  {'page': 2,
#   'text': 'Provider:',
#   'cordx': 294.8399999999999,
#   'cordy': 95.0214000000002},
#  {'page': 2,
#   'text': 'Date:',
#   'cordx': 294.8399999999999,
#   'cordy': 104.0214000000002},
#  {'page': 2,
#   'text': '05/31/2023',
#   'cordx': 382.6802169127999,
#   'cordy': 103.9014000000002},
#  {'page': 2,
#   'text': 'UT BCDO SPECIALTY DENTAL SER',
#   'cordx': 382.6802169128,
#   'cordy': 113.74162000000001},
#  {'page': 2, 'text': 'Payee:', 'cordx': 294.84, 'cordy': 115.30140000000006},
#  {'page': 2,
#   'text': 'Check No.:',
#   'cordx': 294.84,
#   'cordy': 125.02132000000006},
#  {'page': 2,
#   'text': '188218572',
#   'cordx': 382.6802169128,
#   'cordy': 124.90142000000003},
#  {'page': 2,
#   'text': 'Payment Amount:',
#   'cordx': 294.84,
#   'cordy': 134.02132000000006},
#  {'page': 2,
#   'text': '$160.00',
#   'cordx': 382.6802169128,
#   'cordy': 133.90142000000003},
#  {'page': 2,
#   'text': 'Patient Account No.:121148666',
#   'cordx': 225.83943376399998,
#   'cordy': 163.90119000000004},
#  {'page': 2,
#   'text': 'Claim Number:',
#   'cordx': 18.8398,
#   'cordy': 165.46140000000003},
#  {'page': 2, 'text': '32883F15100', 'cordx': 93.119811492, 'cordy': 165.34109},
#  {'page': 2,
#   'text': 'Plan Number:00518516',
#   'cordx': 465.83932013599997,
#   'cordy': 166.0616980000001},
#  {'page': 2,
#   'text': 'Patient Name:',
#   'cordx': 18.8398,
#   'cordy': 174.46140000000003},
#  {'page': 2,
#   'text': 'TREYTON ROPER',
#   'cordx': 93.119811492,
#   'cordy': 174.34109},
#  {'page': 2,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 174.46139000000005},
#  {'page': 2,
#   'text': 'BLAKE ROPER',
#   'cordx': 315.119469344,
#   'cordy': 174.34139000000005},
#  {'page': 2,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 176.74142000000006},
#  {'page': 2,
#   'text': 'SON',
#   'cordx': 526.6794936904,
#   'cordy': 176.6214980000001},
#  {'page': 2,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 185.02149800000007},
#  {'page': 2,
#   'text': 'ONBOARDIQ, INC.',
#   'cordx': 93.119811492,
#   'cordy': 184.90129000000002},
#  {'page': 2, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 196.0086},
#  {'page': 2,
#   'text': 'Submitted',
#   'cordx': 72.3602,
#   'cordy': 195.28859999999997},
#  {'page': 2,
#   'text': 'Alt',
#   'cordx': 155.16029745327495,
#   'cordy': 195.28859999999997},
#  {'page': 2, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 195.28859999999997},
#  {'page': 2,
#   'text': 'Date of',
#   'cordx': 224.64004397875,
#   'cordy': 195.28859999999997},
#  {'page': 2,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 195.28859999999997},
#  {'page': 2,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 195.28859999999997},
#  {'page': 2,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 195.28859999999997},
#  {'page': 2,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 195.28859999999997},
#  {'page': 2,
#   'text': 'Coverage',
#   'cordx': 490.680086151525,
#   'cordy': 195.28859999999997},
#  {'page': 2, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 195.28859999999997},
#  {'page': 2,
#   'text': 'No.',
#   'cordx': 21.719875162250002,
#   'cordy': 205.12851999999998},
#  {'page': 2,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 204.40851999999995},
#  {'page': 2,
#   'text': 'Code',
#   'cordx': 151.56030081277495,
#   'cordy': 204.40851999999995},
#  {'page': 2,
#   'text': 'No.',
#   'cordx': 186.96031734874998,
#   'cordy': 204.40851999999995},
#  {'page': 2,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 204.40851999999995},
#  {'page': 2,
#   'text': 'Charge',
#   'cordx': 279.120124551525,
#   'cordy': 204.40851999999995},
#  {'page': 2,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 204.40851999999995},
#  {'page': 2,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 204.40851999999995},
#  {'page': 2,
#   'text': 'Amount',
#   'cordx': 442.320378138025,
#   'cordy': 204.40851999999995},
#  {'page': 2,
#   'text': 'Percent',
#   'cordx': 493.919927428275,
#   'cordy': 204.40851999999995},
#  {'page': 2,
#   'text': 'Amount',
#   'cordx': 547.1998391022499,
#   'cordy': 204.40851999999995},
#  {'page': 2, 'text': '1', 'cordx': 24.2398, 'cordy': 216.8886},
#  {'page': 2,
#   'text': 'D0120/Periodic Eval',
#   'cordx': 39.83979369292,
#   'cordy': 216.8886},
#  {'page': 2, 'text': 'FM', 'cordx': 188.04, 'cordy': 216.8886},
#  {'page': 2, 'text': '05/30/23', 'cordx': 224.8801224475, 'cordy': 216.168678},
#  {'page': 2, 'text': '39.00', 'cordx': 302.0403026225, 'cordy': 216.168678},
#  {'page': 2, 'text': '23.00', 'cordx': 359.1601348725, 'cordy': 216.8886},
#  {'page': 2, 'text': '23.00', 'cordx': 409.439859725, 'cordy': 216.8886},
#  {'page': 2, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 216.8886},
#  {'page': 2, 'text': '23.00', 'cordx': 571.2001705475, 'cordy': 217.608518},
#  {'page': 2, 'text': '2', 'cordx': 24.2398, 'cordy': 226.4885999999999},
#  {'page': 2,
#   'text': 'D0220/Periapical 1st',
#   'cordx': 39.83979369292,
#   'cordy': 226.4885999999999},
#  {'page': 2, 'text': 'FM', 'cordx': 188.04, 'cordy': 226.4885999999999},
#  {'page': 2,
#   'text': '05/30/23',
#   'cordx': 224.8801224475,
#   'cordy': 225.7686779999999},
#  {'page': 2,
#   'text': '22.00',
#   'cordx': 302.0403026225,
#   'cordy': 225.7686779999999},
#  {'page': 2,
#   'text': '13.00',
#   'cordx': 359.1601348725,
#   'cordy': 226.4885999999999},
#  {'page': 2,
#   'text': '13.00',
#   'cordx': 409.439859725,
#   'cordy': 226.4885999999999},
#  {'page': 2,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 226.4885999999999},
#  {'page': 2,
#   'text': '13.00',
#   'cordx': 571.2001705475,
#   'cordy': 227.32844799999987},
#  {'page': 2, 'text': '3', 'cordx': 24.2398, 'cordy': 236.20859999999993},
#  {'page': 2,
#   'text': 'D0230/Periapical Add',
#   'cordx': 39.83979369292,
#   'cordy': 236.20859999999993},
#  {'page': 2, 'text': 'FM', 'cordx': 188.04, 'cordy': 236.20859999999993},
#  {'page': 2,
#   'text': '05/30/23',
#   'cordx': 224.87972321750004,
#   'cordy': 235.36875599999996},
#  {'page': 2,
#   'text': '19.00',
#   'cordx': 302.03990339250004,
#   'cordy': 235.36875599999996},
#  {'page': 2,
#   'text': '8.00',
#   'cordx': 363.23986624250006,
#   'cordy': 236.20859999999993},
#  {'page': 2,
#   'text': '8.00',
#   'cordx': 413.51999032500004,
#   'cordy': 236.20859999999993},
#  {'page': 2,
#   'text': '100%',
#   'cordx': 496.80026659250007,
#   'cordy': 236.20859999999993},
#  {'page': 2,
#   'text': '8.00',
#   'cordx': 575.2799019175001,
#   'cordy': 236.92852599999992},
#  {'page': 2, 'text': '4', 'cordx': 24.2398, 'cordy': 245.80859999999996},
#  {'page': 2,
#   'text': 'D1120/Child Cleaning',
#   'cordx': 39.83979369292,
#   'cordy': 245.80859999999996},
#  {'page': 2, 'text': 'FM', 'cordx': 188.04, 'cordy': 245.80859999999996},
#  {'page': 2,
#   'text': '05/30/23',
#   'cordx': 224.8801224475,
#   'cordy': 245.08867799999996},
#  {'page': 2,
#   'text': '52.00',
#   'cordx': 302.0403026225,
#   'cordy': 245.08867799999996},
#  {'page': 2,
#   'text': '36.00',
#   'cordx': 359.1601348725,
#   'cordy': 245.80859999999996},
#  {'page': 2,
#   'text': '36.00',
#   'cordx': 409.439859725,
#   'cordy': 245.80859999999996},
#  {'page': 2,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 245.80859999999996},
#  {'page': 2,
#   'text': '36.00',
#   'cordx': 571.2001705475,
#   'cordy': 246.52851799999996},
#  {'page': 2, 'text': '5', 'cordx': 24.2398, 'cordy': 255.40859999999998},
#  {'page': 2,
#   'text': 'D0274/Bitewing - 4',
#   'cordx': 39.83979369292,
#   'cordy': 255.40859999999998},
#  {'page': 2, 'text': 'FM', 'cordx': 188.04, 'cordy': 255.40859999999998},
#  {'page': 2,
#   'text': '05/30/23',
#   'cordx': 224.88022225500004,
#   'cordy': 254.68867799999998},
#  {'page': 2,
#   'text': '52.00',
#   'cordx': 302.04040243,
#   'cordy': 254.68867799999998},
#  {'page': 2,
#   'text': '31.00',
#   'cordx': 359.16023468000003,
#   'cordy': 255.40859999999998},
#  {'page': 2,
#   'text': '0.00',
#   'cordx': 413.51999032500004,
#   'cordy': 255.40859999999998},
#  {'page': 2,
#   'text': '100%',
#   'cordx': 496.80076563,
#   'cordy': 255.40859999999998},
#  {'page': 2,
#   'text': '0.00',
#   'cordx': 575.280400955,
#   'cordy': 256.24844799999994},
#  {'page': 2,
#   'text': 'TOTALS',
#   'cordx': 223.07999323199996,
#   'cordy': 265.45475999999996},
#  {'page': 2, 'text': '184.00', 'cordx': 297.36, 'cordy': 265.1286},
#  {'page': 2, 'text': '111.00', 'cordx': 355.08, 'cordy': 265.1286},
#  {'page': 2, 'text': '80.00', 'cordx': 409.43980395182996, 'cordy': 265.1286},
#  {'page': 2,
#   'text': '0.00',
#   'cordx': 499.080260925,
#   'cordy': 265.12839999999994},
#  {'page': 2, 'text': '80.00', 'cordx': 571.2, 'cordy': 265.1286},
#  {'page': 2, 'text': ' ', 'cordx': 22.6801, 'cordy': 276.2886},
#  {'page': 2,
#   'text': 'BENEFIT SUMMARY',
#   'cordx': 444.59999176229996,
#   'cordy': 278.8949},
#  {'page': 2,
#   'text': 'TOTAL BENEFIT PAYABLE.........',
#   'cordx': 389.4,
#   'cordy': 290.175},
#  {'page': 2, 'text': '$80.00', 'cordx': 565.92, 'cordy': 290.175},
#  {'page': 2,
#   'text': 'HIGHER ALLOWABLE..................',
#   'cordx': 389.3999001933,
#   'cordy': 300.615256},
#  {'page': 2, 'text': '$80.00', 'cordx': 565.9200259473, 'cordy': 301.4551},
#  {'page': 2,
#   'text': 'PAID BY OTHER INSURANCE.....',
#   'cordx': 389.39987424599997,
#   'cordy': 310.4551},
#  {'page': 2,
#   'text': '$0.00',
#   'cordx': 570.480168123,
#   'cordy': 312.61526000000003},
#  {'page': 2,
#   'text': 'ADJUSTMENTS...............................',
#   'cordx': 389.39987424599997,
#   'cordy': 321.61526000000003},
#  {'page': 2,
#   'text': '$0.00',
#   'cordx': 570.47280238854,
#   'cordy': 321.61526000000003},
#  {'page': 2,
#   'text': 'TOTAL BENEFIT PAID..................',
#   'cordx': 389.39987424599997,
#   'cordy': 332.89496},
#  {'page': 2, 'text': '$ 80.00', 'cordx': 563.63578394112, 'cordy': 332.89496},
#  {'page': 2,
#   'text': "PATIENT'S RESPONSIBILITY.....",
#   'cordx': 389.39987424599997,
#   'cordy': 344.17466},
#  {'page': 2, 'text': '$31.00', 'cordx': 565.90883163027, 'cordy': 344.17466},
#  {'page': 2,
#   'text': 'Remarks for claim # 32883F15100:',
#   'cordx': 18.1199,
#   'cordy': 369.735},
#  {'page': 2,
#   'text': 'A DENTALGUARD PARTICIPATING DENTIST HAS BEEN UTILIZED',
#   'cordx': 18.1199,
#   'cordy': 380.7748},
#  {'page': 2,
#   'text': '5.  The dental plan covers bitewing radiographic images only once in any 12 consecutive month period,',
#   'cordx': 18.1199,
#   'cordy': 390.49511},
#  {'page': 2,
#   'text': 'up to a maximum of four films or a set of 7-8 vertical films, in one visit.',
#   'cordx': 18.1199,
#   'cordy': 400.09511000000003},
#  {'page': 2,
#   'text': 'Benefits are based on the use of a Preferred Contracted Dentist.',
#   'cordx': 18.1199,
#   'cordy': 409.69511000000006},
#  {'page': 2,
#   'text': 'Comments:',
#   'cordx': 18.1199,
#   'cordy': 433.81541000000004},
#  {'page': 2,
#   'text': 'Current Dental Terminology © 2021 American Dental Association.  All rights reserved.',
#   'cordx': 18.1199,
#   'cordy': 442.575},
#  {'page': 2,
#   'text': 'Log on to www.GuardianAnytime.com  for instant access to clinical policy guidelines and benefits information for Guardian members. Verify eligibility, view',
#   'cordx': 18.12017438699999,
#   'cordy': 454.575},
#  {'page': 2,
#   'text': 'benefits, check claim status and more!',
#   'cordx': 18.12017438699999,
#   'cordy': 463.575},
#  {'page': 2,
#   'text': '       501020 2 FO 2           94313 VNE',
#   'cordx': 14.403799999999999,
#   'cordy': 9.182384986079}]

# %%
dfs = []
x2 = 0
for text_d in text_list:
    x = text_d['cordx']
    if x2<x:
        x2 = text_d['cordx']
x2 = x2+20      
for i in range(len(text_list)):
    x1 = y1 = y2 = ''
    if 'Line' in text_list[i]['text']:
        print("Line", text_list[i]['text'])
        x1 = text_list[i]['cordx']
        y1 = text_list[i]['cordy']
        for j in range(i,len(text_list)):
            if 'BENEFIT SUMMARY' in text_list[j]['text']:
                print("Bene", text_list[j]['text'])
                page = int(text_list[j]['page'])
                y2 = text_list[j]['cordy']
                print(f"x1 = {x1}, y1 = {y1}, x2 = {x2}, y2 = {y2}")
                tabula_dfs = tabula.read_pdf(pdf_path, guess=False, pages=page , stream=True, encoding="utf-8",
                                 area=(y1, x1, y2, x2), multiple_tables=True)
                dfs.append(tabula_dfs[0])
                
                break
# Out:
# Line Line
# Bene BENEFIT SUMMARY
# x1 = 18.8398, y1 = 314.5686, x2 = 595.280400955, y2 = 397.3349
# Got stderr: Jul 04, 2023 9:57:57 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 04, 2023 9:57:57 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 04, 2023 9:57:57 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 04, 2023 9:57:57 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 04, 2023 9:57:57 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 04, 2023 9:57:57 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 04, 2023 9:57:57 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Line Line
# Bene BENEFIT SUMMARY
# x1 = 18.8398, y1 = 196.0086, x2 = 595.280400955, y2 = 278.8949
# Got stderr: Jul 04, 2023 9:57:57 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 04, 2023 9:57:57 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn

# %%
dfs[0]
# Out:
#   Line              Submitted   Alt Tooth   Date of Submitted.1 Considered  \
# 0  No.  ADA Codes/Description  Code   No.   Service      Charge     Charge
# 1    1    D0120/Periodic Eval   NaN    FM  05/30/23       39.00      23.00
# 2    2   D0220/Periapical 1st   NaN    FM  05/30/23       22.00      13.00
# 3    3   D0230/Periapical Add   NaN    FM  05/30/23       19.00       8.00
# 4    4     D0272/Bitewing - 2   NaN    FM  05/30/23       36.00      21.00
# 5    5   D1120/Child Cleaning   NaN    FM  05/30/23       52.00      36.00
# 6  NaN                    NaN   NaN   NaN    TOTALS      168.00     101.00
#
#   Covered Deductible Coverage Benefit
# 0  Charge     Amount  Percent  Amount
# 1   23.00        NaN     100%   23.00
# 2   13.00        NaN     100%   13.00
# 3    8.00        NaN     100%    8.00
# 4    0.00        NaN     100%    0.00
# 5   36.00        NaN     100%   36.00
# 6   80.00        NaN     0.00   80.00

# %%
dfs[1]
# Out:
#   Line              Submitted   Alt Tooth   Date of Submitted.1 Considered  \
# 0  No.  ADA Codes/Description  Code   No.   Service      Charge     Charge
# 1    1    D0120/Periodic Eval   NaN    FM  05/30/23       39.00      23.00
# 2    2   D0220/Periapical 1st   NaN    FM  05/30/23       22.00      13.00
# 3    3   D0230/Periapical Add   NaN    FM  05/30/23       19.00       8.00
# 4    4   D1120/Child Cleaning   NaN    FM  05/30/23       52.00      36.00
# 5    5     D0274/Bitewing - 4   NaN    FM  05/30/23       52.00      31.00
# 6  NaN                    NaN   NaN   NaN    TOTALS      184.00     111.00
#
#   Covered Deductible Coverage Benefit
# 0  Charge     Amount  Percent  Amount
# 1   23.00        NaN     100%   23.00
# 2   13.00        NaN     100%   13.00
# 3    8.00        NaN     100%    8.00
# 4   36.00        NaN     100%   36.00
# 5    0.00        NaN     100%    0.00
# 6   80.00        NaN     0.00   80.00

# %%
tdfs =[]

for df in dfs:
    df = df[~df.apply(lambda row: row.astype(str).str.contains('TOTALS', case=False)).any(axis=1)][1:]
    df.rename(columns={'Date of': 'Date'}, inplace=True)
    df.fillna('', inplace=True)
    df.drop('Line', axis=1, inplace=True)
    tdfs.append(df)

# %%
new_dict = []
for td in tdfs:
    tab = td.to_dict(orient='records')
    for i in range(len(tab)):
        new_dict.append(tab[i])
    
#     new_dict.append(td.to_dict(orient='records'))

# %%
nd = new_dict
nd
# Out:
# [{'Submitted': 'D0120/Periodic Eval',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '39.00',
#   'Considered': '23.00',
#   'Covered': '23.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '23.00'},
#  {'Submitted': 'D0220/Periapical 1st',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '22.00',
#   'Considered': '13.00',
#   'Covered': '13.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '13.00'},
#  {'Submitted': 'D0230/Periapical Add',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '19.00',
#   'Considered': '8.00',
#   'Covered': '8.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '8.00'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '36.00',
#   'Considered': '21.00',
#   'Covered': '0.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '0.00'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '52.00',
#   'Considered': '36.00',
#   'Covered': '36.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '36.00'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '39.00',
#   'Considered': '23.00',
#   'Covered': '23.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '23.00'},
#  {'Submitted': 'D0220/Periapical 1st',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '22.00',
#   'Considered': '13.00',
#   'Covered': '13.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '13.00'},
#  {'Submitted': 'D0230/Periapical Add',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '19.00',
#   'Considered': '8.00',
#   'Covered': '8.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '8.00'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '52.00',
#   'Considered': '36.00',
#   'Covered': '36.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '36.00'},
#  {'Submitted': 'D0274/Bitewing - 4',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/30/23',
#   'Submitted.1': '52.00',
#   'Considered': '31.00',
#   'Covered': '0.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '0.00'}]

# %%
tab_dict = []

change_keys = [("Alt","AltCode"),("Tooth", "ToothNo"),("Date", "ServiceDate"), ("Submitted.1", "SubmittedCharges"),
               ("Benefit", "PayableAmount"), ("Considered", "ActualAllowed"),
               ("Deductible", "ContractualObligations"),("Covered", "CoveredCharge"),("Coverage", "CoveragePercent")]
for d in new_dict:
    for k in change_keys:
        old_key = k[0]
        new_key = k[1]
        value = d[old_key]
        d[new_key] = value
        
        
    for k in change_keys:
        del d[k[0]]
    print("D",d)
    tab_dict.append(d)
# Out:
# D {'Submitted': 'D0120/Periodic Eval', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '39.00', 'PayableAmount': '23.00', 'ActualAllowed': '23.00', 'ContractualObligations': '', 'CoveredCharge': '23.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0220/Periapical 1st', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '22.00', 'PayableAmount': '13.00', 'ActualAllowed': '13.00', 'ContractualObligations': '', 'CoveredCharge': '13.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0230/Periapical Add', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '19.00', 'PayableAmount': '8.00', 'ActualAllowed': '8.00', 'ContractualObligations': '', 'CoveredCharge': '8.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0272/Bitewing - 2', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '36.00', 'PayableAmount': '0.00', 'ActualAllowed': '21.00', 'ContractualObligations': '', 'CoveredCharge': '0.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1120/Child Cleaning', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '52.00', 'PayableAmount': '36.00', 'ActualAllowed': '36.00', 'ContractualObligations': '', 'CoveredCharge': '36.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0120/Periodic Eval', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '39.00', 'PayableAmount': '23.00', 'ActualAllowed': '23.00', 'ContractualObligations': '', 'CoveredCharge': '23.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0220/Periapical 1st', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '22.00', 'PayableAmount': '13.00', 'ActualAllowed': '13.00', 'ContractualObligations': '', 'CoveredCharge': '13.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0230/Periapical Add', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '19.00', 'PayableAmount': '8.00', 'ActualAllowed': '8.00', 'ContractualObligations': '', 'CoveredCharge': '8.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1120/Child Cleaning', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '52.00', 'PayableAmount': '36.00', 'ActualAllowed': '36.00', 'ContractualObligations': '', 'CoveredCharge': '36.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0274/Bitewing - 4', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/30/23', 'SubmittedCharges': '52.00', 'PayableAmount': '0.00', 'ActualAllowed': '31.00', 'ContractualObligations': '', 'CoveredCharge': '0.00', 'CoveragePercent': '100%'}

# %%
tab_dict
# Out:
# [{'Submitted': 'D0120/Periodic Eval',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '39.00',
#   'PayableAmount': '23.00',
#   'ActualAllowed': '23.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '23.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0220/Periapical 1st',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '22.00',
#   'PayableAmount': '13.00',
#   'ActualAllowed': '13.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '13.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0230/Periapical Add',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '19.00',
#   'PayableAmount': '8.00',
#   'ActualAllowed': '8.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '8.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '36.00',
#   'PayableAmount': '0.00',
#   'ActualAllowed': '21.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '0.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '52.00',
#   'PayableAmount': '36.00',
#   'ActualAllowed': '36.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '36.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '39.00',
#   'PayableAmount': '23.00',
#   'ActualAllowed': '23.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '23.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0220/Periapical 1st',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '22.00',
#   'PayableAmount': '13.00',
#   'ActualAllowed': '13.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '13.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0230/Periapical Add',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '19.00',
#   'PayableAmount': '8.00',
#   'ActualAllowed': '8.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '8.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '52.00',
#   'PayableAmount': '36.00',
#   'ActualAllowed': '36.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '36.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0274/Bitewing - 4',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/30/23',
#   'SubmittedCharges': '52.00',
#   'PayableAmount': '0.00',
#   'ActualAllowed': '31.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '0.00',
#   'CoveragePercent': '100%'}]

# %%
# import pdfplumber

# def extract_text_coordinates(pdf_path):
#     text_cord_list = []
#     with pdfplumber.open(pdf_path) as pdf:
#         # Iterate through each page of the PDF
#         for page_number in range(len(pdf.pages)):
#             page = pdf.pages[page_number]
#             # Extract the text content and its coordinates
#             for element in page.extract_words(x_tolerance=1, y_tolerance=1, keep_blank_chars=True):
#                 text_cord_dict = {}
#                 text = element["text"]
#                 x, y = element["x0"], element["top"]
#                 page_number = page_number + 1
#                 text_cord = f"Page {page_number + 1}: Text: {text} Coordinates: X={x}, Y={y}"
#                 text_cord_dict.update({'page':page_numbr, 'text':text,'coordx':x,'coordy':y})
#                 text_cord_list.append(text_cord)
#     return text_cord_list
# # Specify the path to your PDF file
# pdf_path = "guardian1.pdf"

# # Call the function to extract text coordinates
# text_cord_list = extract_text_coordinates(pdf_path)
