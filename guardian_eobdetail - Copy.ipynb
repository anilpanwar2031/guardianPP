# %%
import tabula
from tabula import read_pdf

# %%
file_path = 'guardian.pdf'
dict_list = tabula.read_pdf(file_path, pages='all')
# Out:
# Got stderr: Jun 20, 2023 3:31:49 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:49 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:49 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:49 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:49 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:49 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:49 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 20, 2023 3:31:50 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn

# %%
claimlist = ['32884F15100', '32883F15100']
dfs = []
for i, d in enumerate(dict_list):
    claimn = claimlist[i]
    d['Claim'] = claimn
    dfs.append(d)
dfs
# Out:
# [     Claim Number: 32884F15100 Unnamed: 0 Unnamed: 1  \
#  0   Patient Name: LANAYA ROPER        NaN        NaN
#  1  Planholder: ONBOARDIQ, INC.        NaN        NaN
#  2               Line Submitted        Alt      Tooth
#  3    No. ADA Codes/Description       Code        No.
#  4        1 D0120/Periodic Eval        NaN         FM
#  5       2 D0220/Periapical 1st        NaN         FM
#  6       3 D0230/Periapical Add        NaN         FM
#  7         4 D0272/Bitewing - 2        NaN         FM
#  8       5 D1120/Child Cleaning        NaN         FM
#  9                          NaN        NaN        NaN
#
#    Patient Account No.:121148667 Unnamed: 2         Plan Number:00518516  \
#  0    Employee Name: BLAKE ROPER        NaN       Relationship: DAUGHTER
#  1                           NaN        NaN                          NaN
#  2  Date of Submitted Considered    Covered  Deductible Coverage Benefit
#  3         Service Charge Charge     Charge        Amount Percent Amount
#  4          05/30/23 39.00 23.00      23.00                   100% 23.00
#  5          05/30/23 22.00 13.00      13.00                   100% 13.00
#  6           05/30/23 19.00 8.00       8.00                    100% 8.00
#  7          05/30/23 36.00 21.00       0.00                    100% 0.00
#  8          05/30/23 52.00 36.00      36.00                   100% 36.00
#  9          TOTALS 168.00 101.00      80.00                   0.00 80.00
#
#           Claim
#  0  32884F15100
#  1  32884F15100
#  2  32884F15100
#  3  32884F15100
#  4  32884F15100
#  5  32884F15100
#  6  32884F15100
#  7  32884F15100
#  8  32884F15100
#  9  32884F15100  ,
#       Claim Number: 32883F15100 Unnamed: 0 Unnamed: 1  \
#  0  Patient Name: TREYTON ROPER        NaN        NaN
#  1  Planholder: ONBOARDIQ, INC.        NaN        NaN
#  2               Line Submitted        Alt      Tooth
#  3    No. ADA Codes/Description       Code        No.
#  4        1 D0120/Periodic Eval        NaN         FM
#  5       2 D0220/Periapical 1st        NaN         FM
#  6       3 D0230/Periapical Add        NaN         FM
#  7       4 D1120/Child Cleaning        NaN         FM
#  8         5 D0274/Bitewing - 4        NaN         FM
#  9                          NaN        NaN        NaN
#
#    Patient Account No.:121148666 Unnamed: 2         Plan Number:00518516  \
#  0    Employee Name: BLAKE ROPER        NaN            Relationship: SON
#  1                           NaN        NaN                          NaN
#  2  Date of Submitted Considered    Covered  Deductible Coverage Benefit
#  3         Service Charge Charge     Charge        Amount Percent Amount
#  4          05/30/23 39.00 23.00      23.00                   100% 23.00
#  5          05/30/23 22.00 13.00      13.00                   100% 13.00
#  6           05/30/23 19.00 8.00       8.00                    100% 8.00
#  7          05/30/23 52.00 36.00      36.00                   100% 36.00
#  8          05/30/23 52.00 31.00       0.00                    100% 0.00
#  9          TOTALS 184.00 111.00      80.00                   0.00 80.00
#
#           Claim
#  0  32883F15100
#  1  32883F15100
#  2  32883F15100
#  3  32883F15100
#  4  32883F15100
#  5  32883F15100
#  6  32883F15100
#  7  32883F15100
#  8  32883F15100
#  9  32883F15100  ]

# %%
lst = []
claimlist = ['32884F15100', '32883F15100']
for ind, tab in enumerate(dfs):
#     claimn = claimlist[ind]
#     tab['ClaimNumber'] = claimn
#     print("TAB", tab)
    c = 1
    if any('Patient Name' in col for col in tab.columns):
        new_columns_name = {}
        for i in range(len(tab.columns)):
            old_name = tab.columns[i]
            new_name = f'columns{i + 1}'
            new_columns_name[old_name] = new_name
            
            tab = tab.rename(columns=new_columns_name)
#         tabd = tab.to_dict('records')    
        lst.append(tab.to_dict('records'))
    if len(lst) == 0:
        if any('Claim Number' in col for col in tab.columns):
            new_columns_name = {}
            for i in range(len(tab.columns)):
                old_name = tab.columns[i]
                new_name = f'columns{i + 1}'
                new_columns_name[old_name] = new_name
                tab = tab.rename(columns=new_columns_name)
            lst.append(tab.to_dict('records'))     
lst
# Out:
# [[{'columns1': 'Patient Name: LANAYA ROPER',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': 'Employee Name: BLAKE ROPER',
#    'columns5': nan,
#    'columns6': 'Relationship: DAUGHTER',
#    'columns7': '32884F15100'},
#   {'columns1': 'Planholder: ONBOARDIQ, INC.',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': nan,
#    'columns5': nan,
#    'columns6': nan,
#    'columns7': '32884F15100'},
#   {'columns1': 'Line Submitted',
#    'columns2': 'Alt',
#    'columns3': 'Tooth',
#    'columns4': 'Date of Submitted Considered',
#    'columns5': 'Covered',
#    'columns6': 'Deductible Coverage Benefit',
#    'columns7': '32884F15100'},
#   {'columns1': 'No. ADA Codes/Description',
#    'columns2': 'Code',
#    'columns3': 'No.',
#    'columns4': 'Service Charge Charge',
#    'columns5': 'Charge',
#    'columns6': 'Amount Percent Amount',
#    'columns7': '32884F15100'},
#   {'columns1': '1 D0120/Periodic Eval',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/30/23 39.00 23.00',
#    'columns5': '23.00',
#    'columns6': '100% 23.00',
#    'columns7': '32884F15100'},
#   {'columns1': '2 D0220/Periapical 1st',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/30/23 22.00 13.00',
#    'columns5': '13.00',
#    'columns6': '100% 13.00',
#    'columns7': '32884F15100'},
#   {'columns1': '3 D0230/Periapical Add',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/30/23 19.00 8.00',
#    'columns5': '8.00',
#    'columns6': '100% 8.00',
#    'columns7': '32884F15100'},
#   {'columns1': '4 D0272/Bitewing - 2',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/30/23 36.00 21.00',
#    'columns5': '0.00',
#    'columns6': '100% 0.00',
#    'columns7': '32884F15100'},
#   {'columns1': '5 D1120/Child Cleaning',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/30/23 52.00 36.00',
#    'columns5': '36.00',
#    'columns6': '100% 36.00',
#    'columns7': '32884F15100'},
#   {'columns1': nan,
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': 'TOTALS 168.00 101.00',
#    'columns5': '80.00',
#    'columns6': '0.00 80.00',
#    'columns7': '32884F15100'}]]

# %%
temp_lst = []
for i in range(len(lst)):
    for obj in lst[i]:
        print("Obj", obj)
        if type(obj.get('columns1')) != float:
            temp_lst.append(obj)

filtered_lst = []
for i in range(len(temp_lst)):
    if not temp_lst[i]['columns1'].startswith('Patient Name') and not temp_lst[i]['columns1'].startswith('Planholder') and not temp_lst[i]['columns1'].startswith('Line Submitted') and not temp_lst[i]['columns1'].startswith('No.'):
        filtered_lst.append(temp_lst[i])
    if not temp_lst[i]['columns1'].startswith('Claim Number') and not temp_lst[i]['columns1'].startswith('Planholder') and not temp_lst[i]['columns1'].startswith('Line Submitted') and not temp_lst[i]['columns1'].startswith('No.'):
        filtered_lst.append(temp_lst[i])    
# print("filtered_lst>>>>>>>>>>>>>>>>>",filtered_lst)
# filtered_lst
# print(len(filtered_lst))
# Out:
# Obj {'columns1': 'Patient Name: LANAYA ROPER', 'columns2': nan, 'columns3': nan, 'columns4': 'Employee Name: BLAKE ROPER', 'columns5': nan, 'columns6': 'Relationship: DAUGHTER', 'columns7': '32884F15100'}
# Obj {'columns1': 'Planholder: ONBOARDIQ, INC.', 'columns2': nan, 'columns3': nan, 'columns4': nan, 'columns5': nan, 'columns6': nan, 'columns7': '32884F15100'}
# Obj {'columns1': 'Line Submitted', 'columns2': 'Alt', 'columns3': 'Tooth', 'columns4': 'Date of Submitted Considered', 'columns5': 'Covered', 'columns6': 'Deductible Coverage Benefit', 'columns7': '32884F15100'}
# Obj {'columns1': 'No. ADA Codes/Description', 'columns2': 'Code', 'columns3': 'No.', 'columns4': 'Service Charge Charge', 'columns5': 'Charge', 'columns6': 'Amount Percent Amount', 'columns7': '32884F15100'}
# Obj {'columns1': '1 D0120/Periodic Eval', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/30/23 39.00 23.00', 'columns5': '23.00', 'columns6': '100% 23.00', 'columns7': '32884F15100'}
# Obj {'columns1': '2 D0220/Periapical 1st', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/30/23 22.00 13.00', 'columns5': '13.00', 'columns6': '100% 13.00', 'columns7': '32884F15100'}
# Obj {'columns1': '3 D0230/Periapical Add', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/30/23 19.00 8.00', 'columns5': '8.00', 'columns6': '100% 8.00', 'columns7': '32884F15100'}
# Obj {'columns1': '4 D0272/Bitewing - 2', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/30/23 36.00 21.00', 'columns5': '0.00', 'columns6': '100% 0.00', 'columns7': '32884F15100'}
# Obj {'columns1': '5 D1120/Child Cleaning', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/30/23 52.00 36.00', 'columns5': '36.00', 'columns6': '100% 36.00', 'columns7': '32884F15100'}
# Obj {'columns1': nan, 'columns2': nan, 'columns3': nan, 'columns4': 'TOTALS 168.00 101.00', 'columns5': '80.00', 'columns6': '0.00 80.00', 'columns7': '32884F15100'}

# %%
# def remove_duplicate_dict(data_list):
#     unique_dicts = list(set(map(lambda x: tuple(sorted(x.items())), data_list)))
#     if len(unique_dicts) < len(data_list):
#         return [dict(t) for t in unique_dicts]
#     else:
#         return data_list

# updated_list = remove_duplicate_dict(filtered_lst)


ls = filtered_lst
for f in ls[:]:
    for k in f.keys():
        if 'Patient' in str(f[k]):
            ls.remove(f)

print("filtered lsit", len(ls))

new_lst = []
for obj in ls:
    new_dict = {}
    columns2 = str(obj['columns2']).split()
    columns3 = obj['columns3'].split()
    columns4 = obj['columns4'].split()
    
    
    if 'columns6' in obj:
        columns6 = obj['columns6'].split()
        columns5 = obj['columns5'].split()

        if len(columns6) == 3:
            new_dict.update({'DeductibleAmount': columns6[0],'CoveragePercent': columns6[1],'BenefitAmount': columns6[2]})
        if len(columns6) == 2:
            new_dict.update({'DeductibleAmount': '','CoveragePercent': columns6[0],'BenefitAmount': columns6[1]})

        if len(columns5) == 3:
            new_dict.update({'SubmittedCharge': columns5[0],'ConsideredCharge': columns5[1],'CoveredCharge': columns5[2]})
        if len(columns5) == 2:
            new_dict.update({'ConsideredCharge': columns5[0],'CoveredCharge': columns5[1]})   
        if len(columns5) == 1:
            new_dict.update({'CoveredCharge': columns5[0]})    


        if len(columns4) == 3:
            new_dict.update({'DateOfService': columns4[0],'SubmittedCharge': columns4[1],'ConsideredCharge': columns4[2]})
        if len(columns4) == 2:
            new_dict.update({'DateOfService': columns4[0],'SubmittedCharge': columns4[1]})
        if len(columns4) == 1:
            new_dict.update({'DateOfService': columns4[0]})

        if len(columns3) == 1:
            new_dict.update({'ToothNo': columns3[0]})

        if len(columns2) == 1:
            new_dict.update({'AltCode': ''})   
        new_dict.update({'SubmittedADACodesDescription': obj["columns1"]})   


    elif 'columns5' in obj:
        columns5 = obj['columns5'].split()
        if len(columns5) == 3:
            new_dict.update({'DeductibleAmount': columns5[0],'CoveragePercent': columns5[1],'BenefitAmount': columns5[2]})
        if len(columns5) == 2:
            new_dict.update({'DeductibleAmount': '','CoveragePercent': columns5[0],'BenefitAmount': columns5[1]})
        
        if len(columns4) == 3:
            new_dict.update({'SubmittedCharge': columns4[0],'ConsideredCharge': columns4[1],'CoveredCharge': columns4[2]})
        if len(columns4) == 2:
            new_dict.update({'ConsideredCharge': columns4[0],'CoveredCharge': columns4[1]})   
        if len(columns4) == 1:
            new_dict.update({'CoveredCharge': columns4[0]})
        
        if len(columns3) == 3:
            new_dict.update({'DateOfService': columns3[0],'SubmittedCharge': columns3[1],'ConsideredCharge': columns3[2]})
        if len(columns3) == 2:
            new_dict.update({'DateOfService': columns3[0],'SubmittedCharge': columns3[1]})
        if len(columns3) == 1:
            new_dict.update({'DateOfService': columns3[0]})
        
        if len(columns2) == 2:
            new_dict.update({'ToothNo': columns2[0],'DateOfService': columns2[1]})
        if len(columns2) == 1:
            new_dict.update({'ToothNo': columns2[0]})   
        
        new_dict.update({'SubmittedADACodesDescription': obj["columns1"],'AltCode': ""})
        
        
   
        
        
    elif 'columns4' in obj:
        if len(columns4) == 3:
            new_dict.update({'DeductibleAmount': columns4[0],'CoveragePercent': columns4[1],'BenefitAmount': columns4[2]})
        if len(columns4) == 2:
            new_dict.update({'DeductibleAmount': '','CoveragePercent': columns4[0],'BenefitAmount': columns4[1]})
        
        if len(columns3) == 4:
            new_dict.update({'DateOfService': columns3[0], 'SubmittedCharge': columns3[1],'ConsideredCharge': columns3[2],'CoveredCharge': columns3[3]})
        if len(columns3) == 3:
            new_dict.update({'SubmittedCharge': columns3[0],'ConsideredCharge': columns3[1],'CoveredCharge': columns3[2]})
        if len(columns3) == 2:
            new_dict.update({'ConsideredCharge': columns3[0],'CoveredCharge': columns3[1]})   
        if len(columns3) == 1:
            new_dict.update({'CoveredCharge': columns3[0]})
        
        
        if len(columns2) == 2:
            new_dict.update({'ToothNo': columns2[0],'DateOfService': columns2[1]})
        if len(columns2) == 1:
            new_dict.update({'ToothNo': columns2[0]})   
        
        new_dict.update({'SubmittedADACodesDescription': obj["columns1"],'AltCode': ""})
        
        
        
    
                
    new_lst.append(new_dict)
new_lst
# Out:
# filtered lsit 10
# [{'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '23.00',
#   'CoveredCharge': '23.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '39.00',
#   'ConsideredCharge': '23.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '1 D0120/Periodic Eval'},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '23.00',
#   'CoveredCharge': '23.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '39.00',
#   'ConsideredCharge': '23.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '1 D0120/Periodic Eval'},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '13.00',
#   'CoveredCharge': '13.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '22.00',
#   'ConsideredCharge': '13.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '2 D0220/Periapical 1st'},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '13.00',
#   'CoveredCharge': '13.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '22.00',
#   'ConsideredCharge': '13.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '2 D0220/Periapical 1st'},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '8.00',
#   'CoveredCharge': '8.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '19.00',
#   'ConsideredCharge': '8.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '3 D0230/Periapical Add'},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '8.00',
#   'CoveredCharge': '8.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '19.00',
#   'ConsideredCharge': '8.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '3 D0230/Periapical Add'},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '0.00',
#   'CoveredCharge': '0.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '36.00',
#   'ConsideredCharge': '21.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '4 D0272/Bitewing - 2'},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '0.00',
#   'CoveredCharge': '0.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '36.00',
#   'ConsideredCharge': '21.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '4 D0272/Bitewing - 2'},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '36.00',
#   'CoveredCharge': '36.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '52.00',
#   'ConsideredCharge': '36.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '5 D1120/Child Cleaning'},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'BenefitAmount': '36.00',
#   'CoveredCharge': '36.00',
#   'DateOfService': '05/30/23',
#   'SubmittedCharge': '52.00',
#   'ConsideredCharge': '36.00',
#   'ToothNo': 'FM',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '5 D1120/Child Cleaning'}]

# %%
print(len(new_lst))
# Out:
# 10
