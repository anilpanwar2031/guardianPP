# %%
import pdfplumber

file_path ="t1.pdf"

# %%
with pdfplumber.open(file_path) as pdf:
  
    for page in pdf.pages:
        tables = page.extract_tables()
        t = 1
        for table in tables:
            print(table)
# Out:
# [['', '']]
# [[''], ['MO1924-1000']]
# [[None, 'Adjustment\nNotice*'], ['6/22/23 D1120 D1120 $45.00 $45.00 $0.00 $0.00 100% $0.00 $45.00', '40389'], ['6/22/23 D0230 D0230 $0.00 $0.00 $0.00 $0.00 0% $0.00 $0.00', '1051'], ['6/22/23 D0220 D0220 $0.00 $0.00 $0.00 $0.00 0% $0.00 $0.00', '1051 1075'], ['6/22/23 D0120 D0120 $66.00 $66.00 $0.00 $0.00 100% $0.00 $66.00', '40389'], ['6/22/23 D0274 D0210 $88.00 $88.00 $0.00 $0.00 0% $88.00 $0.00', '1051 1075'], ['6/22/23 D1206 D1206 $31.00 $31.00 $0.00 $0.00 100% $0.00 $31.00', '40389'], ['6/22/23 D0230 D0230 $0.00 $0.00 $0.00 $0.00 0% $0.00 $0.00', '1051'], ['$445.00 $230.00 $230.00 $0.00 $0.00 $88.00 $142.00', '']]
# [['', '$88.00']]
# [[''], ['MO1924-1000']]
# ...
