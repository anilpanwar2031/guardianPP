# %%
import tabula
from tabula import read_pdf

# %%
file_path = 'C:\\guardian\\SD%20Payor%20Scraping\\guardian.pdf'
dict_list = tabula.read_pdf(file_path, pages='all')
# Out:
# Got stderr: May 31, 2023 11:50:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:25 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# May 31, 2023 11:50:25 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn

# %%
print(len(dict_list))
dict_list
# Out:
# 2
# [      Claim Number: 36343F13200 Unnamed: 0  \
#  0   Patient Name: EDMUND GROVER        NaN
#  1  Planholder: VARO MONEY, INC.        NaN
#  2                Line Submitted  Alt Tooth
#  3     No. ADA Codes/Description   Code No.
#  4        1 D2392/Pst Composite2          T
#  5            2 D7140/Extraction          S
#  6        3 D1510/Space Maintain         LR
#  7         4 D9230/Analgesia/N20         FM
#  8                           NaN        NaN
#
#            Patient Account No.:120262917         Plan Number:00558774
#  0        Employee Name: GEOFFREY GROVER            Relationship: SON
#  1                                   NaN                          NaN
#  2  Date of Submitted Considered Covered  Deductible Coverage Benefit
#  3          Service Charge Charge Charge        Amount Percent Amount
#  4         05/09/23 152.00 100.00 100.00              50.00 90% 45.00
#  5           05/09/23 119.00 69.00 69.00                    90% 62.10
#  6         05/09/23 228.00 149.00 149.00                   90% 134.10
#  7             05/09/23 30.00 29.00 0.00                     90% 0.00
#  8           TOTALS 529.00 347.00 318.00           50.00 26.80 241.20  ,
#         Claim Number: 36347F13200 Unnamed: 0 Unnamed: 1  \
#  0     Patient Name: ANDREW CASEY        NaN        NaN
#  1   Planholder: GOENGINEER, INC.        NaN        NaN
#  2                 Line Submitted        Alt      Tooth
#  3      No. ADA Codes/Description       Code        No.
#  4          1 D0120/Periodic Eval        NaN         FM
#  5         2 D0240/Occlusal Image        NaN         FM
#  6         3 D0240/Occlusal Image        NaN         FM
#  7         4 D1120/Child Cleaning        NaN         FM
#  8          5 D1206/Fluoride Varn        NaN         FM
#  9           6 D0274/Bitewing - 4        NaN         FM
#  10                           NaN        NaN        NaN
#
#             Patient Account No.:120320346         Plan Number:00581682
#  0            Employee Name: ANDREW CASEY            Relationship: SON
#  1                                    NaN                          NaN
#  2   Date of Submitted Considered Covered  Deductible Coverage Benefit
#  3           Service Charge Charge Charge        Amount Percent Amount
#  4             05/10/23 39.00 27.00 27.00                   100% 27.00
#  5             05/10/23 27.00 14.00 14.00                   100% 14.00
#  6             05/10/23 27.00 14.00 14.00                   100% 14.00
#  7             05/10/23 52.00 39.00 39.00                   100% 39.00
#  8             05/10/23 36.00 16.00 16.00                   100% 16.00
#  9              05/10/23 52.00 30.00 0.00                    100% 0.00
#  10           TOTALS 233.00 140.00 110.00                  0.00 110.00  ]

# %%
lst = []
for ind, tab in enumerate(dict_list):
    if any('Claim Number' in col for col in tab.columns):
        new_columns_name = {}
        for i in range(len(tab.columns)):
            old_name = tab.columns[i]
            new_name = f'columns{i + 1}'
            new_columns_name[old_name] = new_name
            tab = tab.rename(columns=new_columns_name)
        lst.append(tab.to_dict('records'))
lst
# Out:
# [[{'columns1': 'Patient Name: EDMUND GROVER',
#    'columns2': nan,
#    'columns3': 'Employee Name: GEOFFREY GROVER',
#    'columns4': 'Relationship: SON'},
#   {'columns1': 'Planholder: VARO MONEY, INC.',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': nan},
#   {'columns1': 'Line Submitted',
#    'columns2': 'Alt Tooth',
#    'columns3': 'Date of Submitted Considered Covered',
#    'columns4': 'Deductible Coverage Benefit'},
#   {'columns1': 'No. ADA Codes/Description',
#    'columns2': 'Code No.',
#    'columns3': 'Service Charge Charge Charge',
#    'columns4': 'Amount Percent Amount'},
#   {'columns1': '1 D2392/Pst Composite2',
#    'columns2': 'T',
#    'columns3': '05/09/23 152.00 100.00 100.00',
#    'columns4': '50.00 90% 45.00'},
#   {'columns1': '2 D7140/Extraction',
#    'columns2': 'S',
#    'columns3': '05/09/23 119.00 69.00 69.00',
#    'columns4': '90% 62.10'},
#   {'columns1': '3 D1510/Space Maintain',
#    'columns2': 'LR',
#    'columns3': '05/09/23 228.00 149.00 149.00',
#    'columns4': '90% 134.10'},
#   {'columns1': '4 D9230/Analgesia/N20',
#    'columns2': 'FM',
#    'columns3': '05/09/23 30.00 29.00 0.00',
#    'columns4': '90% 0.00'},
#   {'columns1': nan,
#    'columns2': nan,
#    'columns3': 'TOTALS 529.00 347.00 318.00',
#    'columns4': '50.00 26.80 241.20'}],
#  [{'columns1': 'Patient Name: ANDREW CASEY',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': 'Employee Name: ANDREW CASEY',
#    'columns5': 'Relationship: SON'},
#   {'columns1': 'Planholder: GOENGINEER, INC.',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': nan,
#    'columns5': nan},
#   {'columns1': 'Line Submitted',
#    'columns2': 'Alt',
#    'columns3': 'Tooth',
#    'columns4': 'Date of Submitted Considered Covered',
#    'columns5': 'Deductible Coverage Benefit'},
#   {'columns1': 'No. ADA Codes/Description',
#    'columns2': 'Code',
#    'columns3': 'No.',
#    'columns4': 'Service Charge Charge Charge',
#    'columns5': 'Amount Percent Amount'},
#   {'columns1': '1 D0120/Periodic Eval',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/10/23 39.00 27.00 27.00',
#    'columns5': '100% 27.00'},
#   {'columns1': '2 D0240/Occlusal Image',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/10/23 27.00 14.00 14.00',
#    'columns5': '100% 14.00'},
#   {'columns1': '3 D0240/Occlusal Image',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/10/23 27.00 14.00 14.00',
#    'columns5': '100% 14.00'},
#   {'columns1': '4 D1120/Child Cleaning',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/10/23 52.00 39.00 39.00',
#    'columns5': '100% 39.00'},
#   {'columns1': '5 D1206/Fluoride Varn',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/10/23 36.00 16.00 16.00',
#    'columns5': '100% 16.00'},
#   {'columns1': '6 D0274/Bitewing - 4',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '05/10/23 52.00 30.00 0.00',
#    'columns5': '100% 0.00'},
#   {'columns1': nan,
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': 'TOTALS 233.00 140.00 110.00',
#    'columns5': '0.00 110.00'}]]

# %%
temp_lst = []
for i in range(len(lst)):
    for obj in lst[i]:
        if type(obj.get('columns1')) != float:
            temp_lst.append(obj)

filtered_lst = []
for i in range(len(temp_lst)):
    if not temp_lst[i]['columns1'].startswith('Patient Name') and not temp_lst[i]['columns1'].startswith('Planholder') and not temp_lst[i]['columns1'].startswith('Line Submitted') and not temp_lst[i]['columns1'].startswith('No.'):
        filtered_lst.append(temp_lst[i])
print("filtered_lst>>>>>>>>>>>>>>>>>",filtered_lst)
filtered_lst
# Out:
# filtered_lst>>>>>>>>>>>>>>>>> [{'columns1': '1 D2392/Pst Composite2', 'columns2': 'T', 'columns3': '05/09/23 152.00 100.00 100.00', 'columns4': '50.00 90% 45.00'}, {'columns1': '2 D7140/Extraction', 'columns2': 'S', 'columns3': '05/09/23 119.00 69.00 69.00', 'columns4': '90% 62.10'}, {'columns1': '3 D1510/Space Maintain', 'columns2': 'LR', 'columns3': '05/09/23 228.00 149.00 149.00', 'columns4': '90% 134.10'}, {'columns1': '4 D9230/Analgesia/N20', 'columns2': 'FM', 'columns3': '05/09/23 30.00 29.00 0.00', 'columns4': '90% 0.00'}, {'columns1': '1 D0120/Periodic Eval', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/10/23 39.00 27.00 27.00', 'columns5': '100% 27.00'}, {'columns1': '2 D0240/Occlusal Image', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/10/23 27.00 14.00 14.00', 'columns5': '100% 14.00'}, {'columns1': '3 D0240/Occlusal Image', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/10/23 27.00 14.00 14.00', 'columns5': '100% 14.00'}, {'columns1': '4 D1120/Child Cleaning', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/10/23 52.00 39.00 39.00', 'columns5': '100% 39.00'}, {'columns1': '5 D1206/Fluoride Varn', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/10/23 36.00 16.00 16.00', 'columns5': '100% 16.00'}, {'columns1': '6 D0274/Bitewing - 4', 'columns2': nan, 'columns3': 'FM', 'columns4': '05/10/23 52.00 30.00 0.00', 'columns5': '100% 0.00'}]
# [{'columns1': '1 D2392/Pst Composite2',
#   'columns2': 'T',
#   'columns3': '05/09/23 152.00 100.00 100.00',
#   'columns4': '50.00 90% 45.00'},
#  {'columns1': '2 D7140/Extraction',
#   'columns2': 'S',
#   'columns3': '05/09/23 119.00 69.00 69.00',
#   'columns4': '90% 62.10'},
#  {'columns1': '3 D1510/Space Maintain',
#   'columns2': 'LR',
#   'columns3': '05/09/23 228.00 149.00 149.00',
#   'columns4': '90% 134.10'},
#  {'columns1': '4 D9230/Analgesia/N20',
#   'columns2': 'FM',
#   'columns3': '05/09/23 30.00 29.00 0.00',
#   'columns4': '90% 0.00'},
#  {'columns1': '1 D0120/Periodic Eval',
#   'columns2': nan,
#   'columns3': 'FM',
#   'columns4': '05/10/23 39.00 27.00 27.00',
#   'columns5': '100% 27.00'},
#  {'columns1': '2 D0240/Occlusal Image',
#   'columns2': nan,
#   'columns3': 'FM',
#   'columns4': '05/10/23 27.00 14.00 14.00',
#   'columns5': '100% 14.00'},
#  {'columns1': '3 D0240/Occlusal Image',
#   'columns2': nan,
#   'columns3': 'FM',
#   'columns4': '05/10/23 27.00 14.00 14.00',
#   'columns5': '100% 14.00'},
#  {'columns1': '4 D1120/Child Cleaning',
#   'columns2': nan,
#   'columns3': 'FM',
#   'columns4': '05/10/23 52.00 39.00 39.00',
#   'columns5': '100% 39.00'},
#  {'columns1': '5 D1206/Fluoride Varn',
#   'columns2': nan,
#   'columns3': 'FM',
#   'columns4': '05/10/23 36.00 16.00 16.00',
#   'columns5': '100% 16.00'},
#  {'columns1': '6 D0274/Bitewing - 4',
#   'columns2': nan,
#   'columns3': 'FM',
#   'columns4': '05/10/23 52.00 30.00 0.00',
#   'columns5': '100% 0.00'}]

# %%
new_lst = []
new_dict = {}
for obj in filtered_lst:
    columns3 = obj['columns3'].split()

    if 'columns6' in obj:
        columns6 = str(obj['columns6']).split()
        columns4 = obj['columns4'].split()
        if len(columns6) == 3 and len(columns4) == 3:
            new_dict = {
                'SubmittedADACodesDescription': obj["columns1"],
                'AltCode': obj["columns2"],
                'ToothNo': obj["columns3"],
                'DateOfService': columns4[0],
                'SubmittedCharge': columns4[1],
                'ConsideredCharge': columns4[2],
                'CoveredCharge': obj["columns5"],
                'DeductibleAmount': columns6[0],
                'CoveragePercent': columns6[1],
                'BenefitAmount': columns6[2]
            }
        elif len(columns6) == 2 and len(columns4) == 3:
            new_dict = {
                'SubmittedADACodesDescription': obj["columns1"],
                'AltCode': obj["columns2"],
                'ToothNo': obj["columns3"],
                'DateOfService': columns4[0],
                'SubmittedCharge': columns4[1],
                'ConsideredCharge': columns4[2],
                'CoveredCharge': obj["columns5"],
                'DeductibleAmount': "",
                'CoveragePercent': columns6[0],
                'BenefitAmount': columns6[1]
            }
        elif len(columns6) == 1 and len(columns4) == 4:
            new_dict = {
                'SubmittedADACodesDescription': obj["columns1"],
                'AltCode': obj["columns2"],
                'ToothNo': obj["columns3"],
                'DateOfService': columns4[0],
                'SubmittedCharge': columns4[1],
                'ConsideredCharge': columns4[2],
                'CoveredCharge': columns4[3],
                'DeductibleAmount': "",
                'CoveragePercent': obj["columns5"],
                'BenefitAmount': str(obj["columns6"])
            }
    elif len(columns3) == 3:
        # columns3 = obj['columns3'].split()
        columns2 = obj['columns2'].split()
        columns4 = obj['columns4'].split()
        new_dict = {
            'SubmittedADACodesDescription': obj["columns1"],
            'AltCode': "",
            'ToothNo': columns2[0],
            'DateOfService': columns2[1],
            'SubmittedCharge': columns3[0],
            'ConsideredCharge': columns3[1],
            'CoveredCharge': columns3[2],
            'DeductibleAmount': "",
            'CoveragePercent': columns4[0],
            'BenefitAmount': str(columns4[1])
        }

    else:
        columns3 = obj['columns3'].split()
        columns4 = obj['columns4'].split()
        new_dict = {
            'SubmittedADACodesDescription': obj["columns1"],
            'AltCode': "",
            'ToothNo': obj["columns2"],
            'DateOfService': columns3[0],
            'SubmittedCharge': columns3[1],
            'ConsideredCharge': columns3[2],
            'CoveredCharge': columns3[3],
            'DeductibleAmount': "",
            'CoveragePercent': columns4[0],
            'BenefitAmount': columns4[1]
        }

    if str(new_dict['AltCode']) == 'nan':
        new_dict['AltCode'] = str(new_dict['AltCode']).replace('nan','')
    if str(new_dict['ToothNo']) == 'nan':
        new_dict['ToothNo'] = str(new_dict['ToothNo']).replace('nan','')
    new_lst.append(new_dict)
print("new_lst>>>>>>>>>>>>>",new_lst)
new_lst
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 73
#      66     columns3 = obj['columns3'].split()
#      67     columns4 = obj['columns4'].split()
#      68     new_dict = {
#      69         'SubmittedADACodesDescription': obj["columns1"],
#      70         'AltCode': "",
#      71         'ToothNo': obj["columns2"],
#      72         'DateOfService': columns3[0],
# ---> 73         'SubmittedCharge': columns3[1],
#      74         'ConsideredCharge': columns3[2],
#      75         'CoveredCharge': columns3[3],
#      76         'DeductibleAmount': "",
#      77         'CoveragePercent': columns4[0],
#      78         'BenefitAmount': columns4[1]
#      79     }
#      81 if str(new_dict['AltCode']) == 'nan':
#      82     new_dict['AltCode'] = str(new_dict['AltCode']).replace('nan','')
#
# IndexError: list index out of range

# %%
for i in new_lst:
    data['RcmEobClaimDetail'].append(i)

ADACodes = ""
Description = ""
for i in range(len(data['RcmEobClaimDetail'])):
    for key, values in data['RcmEobClaimDetail'][i].items():
        if key == "SubmittedADACodesDescription":
            cdtcodes_type_of_service = values
            ADACodes, Description = cdtcodes_type_of_service.split("/",1)
    data['RcmEobClaimDetail'][i]["ADACodes"] = ADACodes
    data['RcmEobClaimDetail'][i]["Description"] = Description
    del data['RcmEobClaimDetail'][i]["SubmittedADACodesDescription"]

for obj in data['RcmEobClaimDetail']:
    ads_code = obj["ADACodes"].split()
    if len(ads_code) == 2:
        obj["ADACodes"] = ads_code[1]
print("data>>>>>>>>>>>>>>",data)
