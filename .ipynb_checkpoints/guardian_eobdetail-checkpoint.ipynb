# %%
import tabula
from tabula import read_pdf

# %%
file_path = 'pdf\\4.pdf'
dict_list = tabula.read_pdf(file_path, pages='all')
# Out:
# Got stderr: Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:33 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:34 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 29, 2023 8:08:34 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn

# %%
# claimlist = ['32884F15100', '32883F15100']
# dfs = []
# for i, d in enumerate(dict_list):
#     claimn = claimlist[i]
#     d['Claim'] = claimn
#     dfs.append(d)
# dfs

# %%
lst = []
claimlist = ['36343F13200', '36347F13200']
for ind, tab in enumerate(dict_list):
    claimn = claimlist[ind]
    tab['Claim Number'] = claimn
   
    if any('Patient Name' in col for col in tab.columns):
        new_columns_name = {}
        for i in range(len(tab.columns)):
            old_name = tab.columns[i]
            new_name = f'columns{i + 1}'
            new_columns_name[old_name] = new_name
            
            tab = tab.rename(columns=new_columns_name)
#         tabd = tab.to_dict('records')    
        lst.append(tab.to_dict('records'))
#     if len(lst) == 0:
    if any('Claim Number' in col for col in tab.columns):
        new_columns_name = {}
        for i in range(len(tab.columns)):
            old_name = tab.columns[i]
            new_name = f'columns{i + 1}'
            new_columns_name[old_name] = new_name
            tab = tab.rename(columns=new_columns_name)
        lst.append(tab.to_dict('records'))     
lst
# Out:
# [[{'columns1': 'Patient Name: BRYCE ROPER',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': 'Employee Name: BLAKE ROPER',
#    'columns5': nan,
#    'columns6': 'Relationship: SON',
#    'columns7': nan,
#    'columns8': '36343F13200'},
#   {'columns1': 'Planholder: ONBOARDIQ, INC.',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': nan,
#    'columns5': nan,
#    'columns6': nan,
#    'columns7': nan,
#    'columns8': '36343F13200'},
#   {'columns1': 'Line Submitted',
#    'columns2': 'Alt',
#    'columns3': 'Tooth',
#    'columns4': 'Date of Submitted Considered',
#    'columns5': 'Covered',
#    'columns6': 'Deductible Coverage Benefit',
#    'columns7': nan,
#    'columns8': '36343F13200'},
#   {'columns1': 'No. ADA Codes/Description',
#    'columns2': 'Code',
#    'columns3': 'No.',
#    'columns4': 'Service Charge Charge',
#    'columns5': 'Charge',
#    'columns6': 'Amount Percent Amount',
#    'columns7': nan,
#    'columns8': '36343F13200'},
#   {'columns1': '1 D1351/Tooth Sealant',
#    'columns2': nan,
#    'columns3': '02',
#    'columns4': '06/15/23 37.00 27.00',
#    'columns5': '0.00',
#    'columns6': '100%',
#    'columns7': 0.0,
#    'columns8': '36343F13200'},
#   {'columns1': '2 D1351/Tooth Sealant',
#    'columns2': nan,
#    'columns3': '15',
#    'columns4': '06/15/23 37.00 27.00',
#    'columns5': '0.00',
#    'columns6': '100%',
#    'columns7': 0.0,
#    'columns8': '36343F13200'},
#   {'columns1': '3 D1351/Tooth Sealant',
#    'columns2': nan,
#    'columns3': '18',
#    'columns4': '06/15/23 37.00 27.00',
#    'columns5': '0.00',
#    'columns6': '100%',
#    'columns7': 0.0,
#    'columns8': '36343F13200'},
#   {'columns1': '4 D1351/Tooth Sealant',
#    'columns2': nan,
#    'columns3': '31',
#    'columns4': '06/15/23 37.00 27.00',
#    'columns5': '0.00',
#    'columns6': '100%',
#    'columns7': 0.0,
#    'columns8': '36343F13200'},
#   {'columns1': nan,
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': 'TOTALS 148.00 108.00',
#    'columns5': '0.00',
#    'columns6': '0.00',
#    'columns7': 0.0,
#    'columns8': '36343F13200'}],
#  [{'columns1': 'Patient Name: TREYTON ROPER',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': 'Employee Name: BLAKE ROPER',
#    'columns5': nan,
#    'columns6': 'Relationship: SON',
#    'columns7': nan,
#    'columns8': nan,
#    'columns9': nan,
#    'columns10': '36347F13200'},
#   {'columns1': 'Planholder: ONBOARDIQ, INC.',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': nan,
#    'columns5': nan,
#    'columns6': nan,
#    'columns7': nan,
#    'columns8': nan,
#    'columns9': nan,
#    'columns10': '36347F13200'},
#   {'columns1': 'Line Submitted',
#    'columns2': 'Alt',
#    'columns3': 'Tooth',
#    'columns4': 'Date of Submitted Considered',
#    'columns5': 'Covered',
#    'columns6': 'Deductible Coverage Benefit',
#    'columns7': nan,
#    'columns8': nan,
#    'columns9': nan,
#    'columns10': '36347F13200'},
#   {'columns1': 'No. ADA Codes/Description',
#    'columns2': 'Code',
#    'columns3': 'No.',
#    'columns4': 'Service Charge Charge',
#    'columns5': 'Charge',
#    'columns6': 'Amount Percent Amount',
#    'columns7': nan,
#    'columns8': nan,
#    'columns9': nan,
#    'columns10': '36347F13200'},
#   {'columns1': '1 D4355/FM Debridement',
#    'columns2': nan,
#    'columns3': 'FM',
#    'columns4': '06/14/23 128.00 66.00',
#    'columns5': '0.00',
#    'columns6': '90%',
#    'columns7': 0.0,
#    'columns8': nan,
#    'columns9': nan,
#    'columns10': '36347F13200'},
#   {'columns1': nan,
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': 'TOTALS 128.00 66.00',
#    'columns5': '0.00',
#    'columns6': '0.00',
#    'columns7': 0.0,
#    'columns8': nan,
#    'columns9': nan,
#    'columns10': '36347F13200'}]]

# %%
temp_lst = []
for i in range(len(lst)):
    for obj in lst[i]:
        if type(obj.get('columns1')) != float:
            temp_lst.append(obj)

filtered_lst = []
for i in range(len(temp_lst)):
    if not temp_lst[i]['columns1'].startswith('Patient Name') and not temp_lst[i]['columns1'].startswith('Planholder') and not temp_lst[i]['columns1'].startswith('Line Submitted') and not temp_lst[i]['columns1'].startswith('No.'):
        filtered_lst.append(temp_lst[i])
    if not temp_lst[i]['columns1'].startswith('Claim Number') and not temp_lst[i]['columns1'].startswith('Planholder') and not temp_lst[i]['columns1'].startswith('Line Submitted') and not temp_lst[i]['columns1'].startswith('No.'):
        filtered_lst.append(temp_lst[i])    

filtered_lst
# Out:
# [{'columns1': 'Patient Name: BRYCE ROPER',
#   'columns2': nan,
#   'columns3': nan,
#   'columns4': 'Employee Name: BLAKE ROPER',
#   'columns5': nan,
#   'columns6': 'Relationship: SON',
#   'columns7': nan,
#   'columns8': '36343F13200'},
#  {'columns1': '1 D1351/Tooth Sealant',
#   'columns2': nan,
#   'columns3': '02',
#   'columns4': '06/15/23 37.00 27.00',
#   'columns5': '0.00',
#   'columns6': '100%',
#   'columns7': 0.0,
#   'columns8': '36343F13200'},
#  {'columns1': '1 D1351/Tooth Sealant',
#   'columns2': nan,
#   'columns3': '02',
#   'columns4': '06/15/23 37.00 27.00',
#   'columns5': '0.00',
#   'columns6': '100%',
#   'columns7': 0.0,
#   'columns8': '36343F13200'},
#  {'columns1': '2 D1351/Tooth Sealant',
#   'columns2': nan,
#   'columns3': '15',
#   'columns4': '06/15/23 37.00 27.00',
#   'columns5': '0.00',
#   'columns6': '100%',
#   'columns7': 0.0,
#   'columns8': '36343F13200'},
#  {'columns1': '2 D1351/Tooth Sealant',
#   'columns2': nan,
#   'columns3': '15',
#   'columns4': '06/15/23 37.00 27.00',
#   'columns5': '0.00',
#   'columns6': '100%',
#   'columns7': 0.0,
#   'columns8': '36343F13200'},
#  {'columns1': '3 D1351/Tooth Sealant',
#   'columns2': nan,
#   'columns3': '18',
#   'columns4': '06/15/23 37.00 27.00',
#   'columns5': '0.00',
#   'columns6': '100%',
#   'columns7': 0.0,
#   'columns8': '36343F13200'},
#  {'columns1': '3 D1351/Tooth Sealant',
#   'columns2': nan,
#   'columns3': '18',
#   'columns4': '06/15/23 37.00 27.00',
#   'columns5': '0.00',
#   'columns6': '100%',
#   'columns7': 0.0,
#   'columns8': '36343F13200'},
#  {'columns1': '4 D1351/Tooth Sealant',
#   'columns2': nan,
#   'columns3': '31',
#   'columns4': '06/15/23 37.00 27.00',
#   'columns5': '0.00',
#   'columns6': '100%',
#   'columns7': 0.0,
#   'columns8': '36343F13200'},
#  {'columns1': '4 D1351/Tooth Sealant',
#   'columns2': nan,
#   'columns3': '31',
#   'columns4': '06/15/23 37.00 27.00',
#   'columns5': '0.00',
#   'columns6': '100%',
#   'columns7': 0.0,
#   'columns8': '36343F13200'},
#  {'columns1': 'Patient Name: TREYTON ROPER',
#   'columns2': nan,
#   'columns3': nan,
#   'columns4': 'Employee Name: BLAKE ROPER',
#   'columns5': nan,
#   'columns6': 'Relationship: SON',
#   'columns7': nan,
#   'columns8': nan,
#   'columns9': nan,
#   'columns10': '36347F13200'},
#  {'columns1': '1 D4355/FM Debridement',
#   'columns2': nan,
#   'columns3': 'FM',
#   'columns4': '06/14/23 128.00 66.00',
#   'columns5': '0.00',
#   'columns6': '90%',
#   'columns7': 0.0,
#   'columns8': nan,
#   'columns9': nan,
#   'columns10': '36347F13200'},
#  {'columns1': '1 D4355/FM Debridement',
#   'columns2': nan,
#   'columns3': 'FM',
#   'columns4': '06/14/23 128.00 66.00',
#   'columns5': '0.00',
#   'columns6': '90%',
#   'columns7': 0.0,
#   'columns8': nan,
#   'columns9': nan,
#   'columns10': '36347F13200'}]

# %%
def remove_duplicate_dict(data_list):
    unique_dicts = list(set(map(lambda x: tuple(sorted(x.items())), data_list)))
    if len(unique_dicts) < len(data_list):
        return [dict(t) for t in unique_dicts]
    else:
        return data_list

updated_list = remove_duplicate_dict(filtered_lst)


ls = updated_list
for f in ls[:]:
    for k in f.keys():
        if 'Patient' in str(f[k]):
            ls.remove(f)

print("filtered lsit", len(ls))

new_lst = []
for obj in ls:
    
    new_dict = {}
    
    columns2 = str(obj['columns2']).split()
    columns3 = obj['columns3'].split()
    columns4 = obj['columns4'].split()
    lastk = list(obj.keys())
    lastk = lastk[-1]
    print("LASTTT", lastk)
    new_dict.update({'Enrollee_ClaimID': obj[lastk]})
    keylist = list(obj.keys())[:-1]
    print("KETLIST", keylist)
    
    
    if 'columns7' in keylist:
        print("777777")
        columns7 = str(obj['columns7']).split()
        columns6 = obj['columns6'].split()
        columns5 = obj['columns5'].split()
        
        print("Lenght7", len(columns7))
        print("columns7",columns7)
        if len(columns7) == 3:
            new_dict.update({'DeductibleAmount': columns7[0],'CoveragePercent': columns7[1],'BenefitAmount': columns7[2]})
        if len(columns7) == 2:
            new_dict.update({'DeductibleAmount': '','CoveragePercent': columns6[0],'BenefitAmount': columns7[1]})
        if len(columns7) == 1:
            new_dict.update({'BenefitAmount': columns7[0]})    
       
        print("Lenght6", len(columns6))
        print("columns6",columns6)
        if len(columns6) == 3:
            new_dict.update({'DeductibleAmount': columns6[0],'CoveragePercent': columns6[1],'BenefitAmount': columns6[2]})
        if len(columns6) == 2:
            new_dict.update({'DeductibleAmount': '','CoveragePercent': columns6[0],'BenefitAmount': columns6[1]})
        if len(columns6) == 1:
            new_dict.update({'DeductibleAmount': '','CoveragePercent': columns6[0]})    
        
        print("Lenght5", len(columns5))
        print("columns5",columns5)
        if len(columns5) == 3:
            new_dict.update({'SubmittedCharge': columns5[0],'ConsideredCharge': columns5[1],'CoveredCharge': columns5[2]})
        if len(columns5) == 2:
            new_dict.update({'ConsideredCharge': columns5[0],'CoveredCharge': columns5[1]})   
        if len(columns5) == 1:
            new_dict.update({'CoveredCharge': columns5[0]})    

        print("Lenght4", len(columns4))
        print("columns4",columns4)
        if len(columns4) == 3:
            new_dict.update({'DateOfService': columns4[0],'SubmittedCharge': columns4[1],'ConsideredCharge': columns4[2]})
        if len(columns4) == 2:
            new_dict.update({'DateOfService': columns4[0],'SubmittedCharge': columns4[1]})
        if len(columns4) == 1:
            new_dict.update({'DateOfService': columns4[0]})
        
        print("Lenght3", len(columns3))
        print("columns3",columns3)
        if len(columns3) == 1:
            new_dict.update({'ToothNo': columns3[0]})
        
        print("Lenght2", len(columns2))
        print("columns2",columns2)
        if len(columns2) == 1:
            new_dict.update({'AltCode': columns2[0]})   
        new_dict.update({'SubmittedADACodesDescription': obj["columns1"]})   
    
    
    
    
    
#     if 'columns6' in keylist:
#         print("66666666")
#         columns6 = obj['columns6'].split()
#         columns5 = obj['columns5'].split()
#         print("Lenght6", len(columns6))
#         if len(columns6) == 3:
#             new_dict.update({'DeductibleAmount': columns6[0],'CoveragePercent': columns6[1],'BenefitAmount': columns6[2]})
#         if len(columns6) == 2:
#             new_dict.update({'DeductibleAmount': '','CoveragePercent': columns6[0],'BenefitAmount': columns6[1]})
       
#         print("Lenght5", len(columns5))
#         print("columns5",columns5)
#         if len(columns5) == 3:
#             new_dict.update({'SubmittedCharge': columns5[0],'ConsideredCharge': columns5[1],'CoveredCharge': columns5[2]})
#         if len(columns5) == 2:
#             new_dict.update({'ConsideredCharge': columns5[0],'CoveredCharge': columns5[1]})   
#         if len(columns5) == 1:
#             new_dict.update({'CoveredCharge': columns5[0]})    

#         print("Lenght4", len(columns4))
#         print("columns4",columns4)
#         if len(columns4) == 3:
#             new_dict.update({'DateOfService': columns4[0],'SubmittedCharge': columns4[1],'ConsideredCharge': columns4[2]})
#         if len(columns4) == 2:
#             new_dict.update({'DateOfService': columns4[0],'SubmittedCharge': columns4[1]})
#         if len(columns4) == 1:
#             new_dict.update({'DateOfService': columns4[0]})
        
#         print("Lenght3", len(columns3))
#         print("columns3",columns3)
#         if len(columns3) == 1:
#             new_dict.update({'ToothNo': columns3[0]})
        
#         print("Lenght2", len(columns2))
#         print("columns2",columns2)
#         if len(columns2) == 1:
#             new_dict.update({'AltCode': columns2[0]})   
#         new_dict.update({'SubmittedADACodesDescription': obj["columns1"]})   


#     elif 'columns5' in keylist:
        
#         print("555555")
#         print("Lenght5", len(columns5))
#         print("columns5",columns5)
#         columns5 = obj['columns5'].split()
#         if len(columns5) == 3:
#             new_dict.update({'DeductibleAmount': columns5[0],'CoveragePercent': columns5[1],'BenefitAmount': columns5[2]})
#         if len(columns5) == 2:
#             new_dict.update({'DeductibleAmount': '','CoveragePercent': columns5[0],'BenefitAmount': columns5[1]})
        
#         print("Length4", len(columns4))
#         print("columns4",columns4)
#         if len(columns4) == 4:
#             new_dict.update({'DateOfService': columns4[0],'SubmittedCharge': columns4[1],'ConsideredCharge': columns4[2],'CoveredCharge': columns4[3]})
#             print("NEW DICT", new_dict)   
#         if len(columns4) == 3:
#             new_dict.update({'SubmittedCharge': columns4[0],'ConsideredCharge': columns4[1],'CoveredCharge': columns4[2]})
#         if len(columns4) == 2:
#             new_dict.update({'ConsideredCharge': columns4[0],'CoveredCharge': columns4[1]})   
#         if len(columns4) == 1:
#             new_dict.update({'CoveredCharge': columns4[0]})
        
#         print("Length3 ", len(columns3))
#         print("value columns3",columns3)
#         if len(columns3) == 3:
#             new_dict.update({'DateOfService': columns3[0],'SubmittedCharge': columns3[1],'ConsideredCharge': columns3[2]})
#         if len(columns3) == 2:
#             new_dict.update({'SubmittedCharge': columns3[0],'ConsideredCharge': columns3[1]})
#         if len(columns3) == 1:
#             new_dict.update({'ToothNo': columns3[0]})
        
#         print("Length 2 ",len(columns2))
#         print("value columns2",columns2)
#         if len(columns2) == 2:
#             new_dict.update({'ToothNo': columns2[0],'DateOfService': columns2[1]})
#         if len(columns2) == 1:
#             if columns2[0] == 'nan':
#                 pass
#             else:
#                 new_dict.update({'ToothNo': columns2[0]})   
        
#         new_dict.update({'SubmittedADACodesDescription': obj["columns1"],'AltCode': ""})
        
        
   
        
        
#     elif 'columns4' in keylist:
#         print("44444444")
#         print("Length4 ", len(columns4))
#         print("columns4",columns4)
#         if len(columns4) == 3:
#             new_dict.update({'DeductibleAmount': columns4[0],'CoveragePercent': columns4[1],'BenefitAmount': columns4[2]})
#         if len(columns4) == 2:
#             new_dict.update({'DeductibleAmount': '','CoveragePercent': columns4[0],'BenefitAmount': columns4[1]})
        
#         print("Length3 ", len(columns3))
#         print("columns3",columns3)
#         if len(columns3) == 4:
#             new_dict.update({'DateOfService': columns3[0], 'SubmittedCharge': columns3[1],'ConsideredCharge': columns3[2],'CoveredCharge': columns3[3]})
#         if len(columns3) == 3:
#             new_dict.update({'SubmittedCharge': columns3[0],'ConsideredCharge': columns3[1],'CoveredCharge': columns3[2]})
#         if len(columns3) == 2:
#             new_dict.update({'ConsideredCharge': columns3[0],'CoveredCharge': columns3[1]})   
#         if len(columns3) == 1:
#             new_dict.update({'CoveredCharge': columns3[0]})
        
#         print("Length2 ", len(columns2))
#         print("columns2",columns2)
#         if len(columns2) == 2:
#             new_dict.update({'ToothNo': columns2[0],'DateOfService': columns2[1]})
#         if len(columns2) == 1:
#             new_dict.update({'ToothNo': columns2[0]})   
        
#         new_dict.update({'SubmittedADACodesDescription': obj["columns1"],'AltCode': ""})
        
        
        
#     for k in new_dict:
#         if new_dict[k] == 'nan':
#             new_dict[k] = ''
    new_lst.append(new_dict)
# Out:
# filtered lsit 5
# LASTTT columns9
# KETLIST ['columns1', 'columns10', 'columns2', 'columns3', 'columns4', 'columns5', 'columns6', 'columns7', 'columns8']
# 777777
# Lenght7 1
# columns7 ['0.0']
# Lenght6 1
# columns6 ['90%']
# Lenght5 1
# columns5 ['0.00']
# Lenght4 3
# columns4 ['06/14/23', '128.00', '66.00']
# Lenght3 1
# columns3 ['FM']
# Lenght2 1
# columns2 ['nan']
# LASTTT columns8
# KETLIST ['columns1', 'columns2', 'columns3', 'columns4', 'columns5', 'columns6', 'columns7']
# 777777
# Lenght7 1
# columns7 ['0.0']
# Lenght6 1
# columns6 ['100%']
# Lenght5 1
# columns5 ['0.00']
# Lenght4 3
# columns4 ['06/15/23', '37.00', '27.00']
# Lenght3 1
# columns3 ['18']
# Lenght2 1
# columns2 ['nan']
# LASTTT columns8
# KETLIST ['columns1', 'columns2', 'columns3', 'columns4', 'columns5', 'columns6', 'columns7']
# 777777
# Lenght7 1
# columns7 ['0.0']
# Lenght6 1
# columns6 ['100%']
# Lenght5 1
# columns5 ['0.00']
# Lenght4 3
# columns4 ['06/15/23', '37.00', '27.00']
# Lenght3 1
# columns3 ['15']
# Lenght2 1
# columns2 ['nan']
# LASTTT columns8
# KETLIST ['columns1', 'columns2', 'columns3', 'columns4', 'columns5', 'columns6', 'columns7']
# 777777
# Lenght7 1
# columns7 ['0.0']
# Lenght6 1
# columns6 ['100%']
# Lenght5 1
# columns5 ['0.00']
# Lenght4 3
# columns4 ['06/15/23', '37.00', '27.00']
# Lenght3 1
# columns3 ['31']
# Lenght2 1
# columns2 ['nan']
# LASTTT columns8
# KETLIST ['columns1', 'columns2', 'columns3', 'columns4', 'columns5', 'columns6', 'columns7']
# 777777
# Lenght7 1
# columns7 ['0.0']
# Lenght6 1
# columns6 ['100%']
# Lenght5 1
# columns5 ['0.00']
# Lenght4 3
# columns4 ['06/15/23', '37.00', '27.00']
# Lenght3 1
# columns3 ['02']
# Lenght2 1
# columns2 ['nan']

# %%
print(len(new_lst))
new_lst
# Out:
# 5
# [{'Enrollee_ClaimID': nan,
#   'BenefitAmount': '0.0',
#   'DeductibleAmount': '',
#   'CoveragePercent': '90%',
#   'CoveredCharge': '0.00',
#   'DateOfService': '06/14/23',
#   'SubmittedCharge': '128.00',
#   'ConsideredCharge': '66.00',
#   'ToothNo': 'FM',
#   'AltCode': 'nan',
#   'SubmittedADACodesDescription': '1 D4355/FM Debridement'},
#  {'Enrollee_ClaimID': '36343F13200',
#   'BenefitAmount': '0.0',
#   'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'CoveredCharge': '0.00',
#   'DateOfService': '06/15/23',
#   'SubmittedCharge': '37.00',
#   'ConsideredCharge': '27.00',
#   'ToothNo': '18',
#   'AltCode': 'nan',
#   'SubmittedADACodesDescription': '3 D1351/Tooth Sealant'},
#  {'Enrollee_ClaimID': '36343F13200',
#   'BenefitAmount': '0.0',
#   'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'CoveredCharge': '0.00',
#   'DateOfService': '06/15/23',
#   'SubmittedCharge': '37.00',
#   'ConsideredCharge': '27.00',
#   'ToothNo': '15',
#   'AltCode': 'nan',
#   'SubmittedADACodesDescription': '2 D1351/Tooth Sealant'},
#  {'Enrollee_ClaimID': '36343F13200',
#   'BenefitAmount': '0.0',
#   'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'CoveredCharge': '0.00',
#   'DateOfService': '06/15/23',
#   'SubmittedCharge': '37.00',
#   'ConsideredCharge': '27.00',
#   'ToothNo': '31',
#   'AltCode': 'nan',
#   'SubmittedADACodesDescription': '4 D1351/Tooth Sealant'},
#  {'Enrollee_ClaimID': '36343F13200',
#   'BenefitAmount': '0.0',
#   'DeductibleAmount': '',
#   'CoveragePercent': '100%',
#   'CoveredCharge': '0.00',
#   'DateOfService': '06/15/23',
#   'SubmittedCharge': '37.00',
#   'ConsideredCharge': '27.00',
#   'ToothNo': '02',
#   'AltCode': '',
#   'SubmittedADACodesDescription': '1 D1351/Tooth Sealant'}]

# %%
for k in new_dict:
    if new_dict[k] == 'nan':
        new_dict[k] = ''
new_dict
# Out:
# {'Enrollee_ClaimID': '36343F13200',
#  'BenefitAmount': '0.0',
#  'DeductibleAmount': '',
#  'CoveragePercent': '100%',
#  'CoveredCharge': '0.00',
#  'DateOfService': '06/15/23',
#  'SubmittedCharge': '37.00',
#  'ConsideredCharge': '27.00',
#  'ToothNo': '02',
#  'AltCode': '',
#  'SubmittedADACodesDescription': '1 D1351/Tooth Sealant'}

# %%
new = {new_dict[k] : '' if new_dict[k]=='nan' for k in new_dict}
new
# Out:
#   Cell In[9], line 1
#     new = {new_dict[k] : '' if new_dict[k]=='nan' for k in new_dict}
#                          ^
# SyntaxError: expected 'else' after 'if' expression
