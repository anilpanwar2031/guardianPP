# %%
import pdfplumber

file_path = "SZN67RA4OH.pdf"

# %%
keys = ['Procedure', 'DeltaDentalPPO', 'DeltadentalPremier','Nonpardentist','Frequency','Agelimitation','LimitationORNotes']

# %%
tab = []
with pdfplumber.open(file_path) as pdf:
  
    for page in pdf.pages:
        tables = page.extract_tables()
        for i , table in enumerate(tables):
#             print("\n")
#             print("Table", table)
#             print("Table", len(table))
#             print("\n")
            for r in table:
                td = {}
                if len(r) == 7:
                    td['Procedure'] = r[0]
                    td['DeltaDentalPPO'] = r[1]
                    td['DeltadentalPremier'] = r[2]
                    td['Nonpardentist'] = r[3]
                    td['Frequency'] = r[4]
                    td['Agelimitation'] = r[5]
                    td['LimitationORNotes'] = r[6]
                    tab.append(td)

# %%
tab_list = []
index = []
for i, t in enumerate(tab):
    if "Procedure" in t['Procedure']:
        index.append(i+1)
    if "Individual Annual\nDeductible Met\nPPO Network" in t['DeltaDentalPPO']:
        index.append(i-1)

# %%
index
# Out:
# [21, 48]

# %%
tt = tab[26:54]

# %%
print(len(tt))
# Out:
# 28

# %%
tt
# Out:
# [{'Procedure': 'Fluoride',
#   'DeltaDentalPPO': '100%',
#   'DeltadentalPremier': '100%',
#   'Nonpardentist': '80%',
#   'Frequency': '1 per Calendar\nYear',
#   'Agelimitation': '0 to 18',
#   'LimitationORNotes': '1'},
#  {'Procedure': 'Sealants',
#   'DeltaDentalPPO': '80%',
#   'DeltadentalPremier': '80%',
#   'Nonpardentist': '70%',
#   'Frequency': '1 every 60\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '0 to 18',
#   'LimitationORNotes': '3'},
#  {'Procedure': 'Space Maintainer',
#   'DeltaDentalPPO': '100%',
#   'DeltadentalPremier': '100%',
#   'Nonpardentist': '80%',
#   'Frequency': '1 every 60\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '0 to 15',
#   'LimitationORNotes': '1'},
#  {'Procedure': 'Amalgam',
#   'DeltaDentalPPO': '80%',
#   'DeltadentalPremier': '80%',
#   'Nonpardentist': '70%',
#   'Frequency': '1 every 24\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Composite/Resin',
#   'DeltaDentalPPO': '80%',
#   'DeltadentalPremier': '80%',
#   'Nonpardentist': '70%',
#   'Frequency': '1 every 24\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '',
#   'LimitationORNotes': '4'},
#  {'Procedure': 'Root Canals (submit\non completion date)',
#   'DeltaDentalPPO': '80%',
#   'DeltadentalPremier': '80%',
#   'Nonpardentist': '70%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Perio Root Planing',
#   'DeltaDentalPPO': '80%',
#   'DeltadentalPremier': '80%',
#   'Nonpardentist': '70%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Surgical Perio',
#   'DeltaDentalPPO': '80%',
#   'DeltadentalPremier': '80%',
#   'Nonpardentist': '70%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Periodontal\nMaintenance\n(Following active\ntherapy. May be\ncombined with\nroutine cleaning\nfrequency.)',
#   'DeltaDentalPPO': '100%',
#   'DeltadentalPremier': '100%',
#   'Nonpardentist': '80%',
#   'Frequency': '2 per Calendar\nYear',
#   'Agelimitation': '',
#   'LimitationORNotes': '1'},
#  {'Procedure': 'Simple Extractions',
#   'DeltaDentalPPO': '80%',
#   'DeltadentalPremier': '80%',
#   'Nonpardentist': '70%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Surgical Extractions\nImpacted Teeth',
#   'DeltaDentalPPO': '80%',
#   'DeltadentalPremier': '80%',
#   'Nonpardentist': '70%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Crowns (submit on\nseat date)',
#   'DeltaDentalPPO': '50%',
#   'DeltadentalPremier': '50%',
#   'Nonpardentist': '40%',
#   'Frequency': '1 every 60\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '12+',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Bridges (submit on\nseat date) - I',
#   'DeltaDentalPPO': '50%',
#   'DeltadentalPremier': '50%',
#   'Nonpardentist': '40%',
#   'Frequency': '1 every 60\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '16+',
#   'LimitationORNotes': '20'},
#  {'Procedure': 'Bridges (submit on\nseat date) - R',
#   'DeltaDentalPPO': '50%',
#   'DeltadentalPremier': '50%',
#   'Nonpardentist': '40%',
#   'Frequency': '1 every 60\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '16+',
#   'LimitationORNotes': '20'},
#  {'Procedure': 'Partials/Dentures\n(submit on seat date)\n- I',
#   'DeltaDentalPPO': '50%',
#   'DeltadentalPremier': '50%',
#   'Nonpardentist': '40%',
#   'Frequency': '1 every 60\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '16+',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Partials/Dentures\n(submit on seat date)\n- R',
#   'DeltaDentalPPO': '50%',
#   'DeltadentalPremier': '50%',
#   'Nonpardentist': '40%',
#   'Frequency': '1 every 60\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '16+',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Orthodontics',
#   'DeltaDentalPPO': '50%',
#   'DeltadentalPremier': '50%',
#   'Nonpardentist': '40%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': '13'},
#  {'Procedure': 'Non Surgical TMJ',
#   'DeltaDentalPPO': '0%',
#   'DeltadentalPremier': '0%',
#   'Nonpardentist': '0%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Surgical TMJ',
#   'DeltaDentalPPO': '0%',
#   'DeltadentalPremier': '0%',
#   'Nonpardentist': '0%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': ''},
#  {'Procedure': 'General Anesthesia',
#   'DeltaDentalPPO': '80%',
#   'DeltadentalPremier': '80%',
#   'Nonpardentist': '70%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': '11'},
#  {'Procedure': 'Occlusal Guard By\nReport',
#   'DeltaDentalPPO': '0%',
#   'DeltadentalPremier': '0%',
#   'Nonpardentist': '0%',
#   'Frequency': '',
#   'Agelimitation': '',
#   'LimitationORNotes': ''},
#  {'Procedure': 'Implants',
#   'DeltaDentalPPO': '50%',
#   'DeltadentalPremier': '50%',
#   'Nonpardentist': '40%',
#   'Frequency': '1 every 60\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '16+',
#   'LimitationORNotes': '20'},
#  {'Procedure': 'Implant Crowns',
#   'DeltaDentalPPO': '50%',
#   'DeltadentalPremier': '50%',
#   'Nonpardentist': '40%',
#   'Frequency': '1 every 60\nMonths from the\nlast date of\nservice of the\nsame treatment',
#   'Agelimitation': '16+',
#   'LimitationORNotes': '20'},
#  {'Procedure': '',
#   'DeltaDentalPPO': 'Individual Annual\nDeductible Met\nPPO Network',
#   'DeltadentalPremier': 'Individual Annual\nDeductible Met\nPremier Network',
#   'Nonpardentist': 'Individual Annual\nDeductible Met\nNon Par',
#   'Frequency': 'Individual Annual\nMaximum Met\nPPO Network',
#   'Agelimitation': 'Individual Annual\nMaximum Met\nPremier Network',
#   'LimitationORNotes': 'Individual Annual\nMaximum Met Non\nPar'},
#  {'Procedure': 'Regular',
#   'DeltaDentalPPO': '$50.00',
#   'DeltadentalPremier': '$50.00',
#   'Nonpardentist': '$50.00',
#   'Frequency': '$428.60',
#   'Agelimitation': '$428.60',
#   'LimitationORNotes': '$428.60'},
#  {'Procedure': 'Orthodontic',
#   'DeltaDentalPPO': '$0.00',
#   'DeltadentalPremier': '$0.00',
#   'Nonpardentist': '$0.00',
#   'Frequency': '$0.00',
#   'Agelimitation': '$0.00',
#   'LimitationORNotes': '$0.00'},
#  {'Procedure': 'TMJ',
#   'DeltaDentalPPO': '$0.00',
#   'DeltadentalPremier': '$0.00',
#   'Nonpardentist': '$0.00',
#   'Frequency': '$0.00',
#   'Agelimitation': '$0.00',
#   'LimitationORNotes': '$0.00'},
#  {'Procedure': 'Periodontic',
#   'DeltaDentalPPO': '$0.00',
#   'DeltadentalPremier': '$0.00',
#   'Nonpardentist': '$0.00',
#   'Frequency': '$0.00',
#   'Agelimitation': '$0.00',
#   'LimitationORNotes': '$0.00'}]

# %%
# tab = []
# with pdfplumber.open(file_path) as pdf:
  
#     for page in pdf.pages:
#         tables = page.extract_tables()
#         for i , table in enumerate(tables):
#             print("\n")
# #             print("Table", table)
# #             print("Table", len(table))
#             print("\n")
#             for r in table:
#                 td = {}
#                 print("LR", len(r))
#                 print("Row", r)
# #                 td['Procedure'] = r[0]
# #                 td['DeltaDentalPPO'] = r[1]
# #                 td['DeltadentalPremier'] = r[2]
# #                 td['Nonpardentist'] = r[3]
# #                 td['Frequency'] = r[4]
# #                 td['Agelimitation'] = r[5]
# #                 td['LimitationORNotes'] = r[6]
#                 tab.append(td)
