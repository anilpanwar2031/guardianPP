# %%
import tabula
import pdfplumber
import pandas as pd
import numpy as np

# %%
pdf_path = "guardian2.pdf"
# pdf_path = "pdf//5.pdf"

# %%
def extract_text_coordinates(pdf_path):
    text_list = []
    with pdfplumber.open(pdf_path) as pdf:
        # Iterate through each page of the PDF
        for page_number in range(len(pdf.pages)):
            page = pdf.pages[page_number]
            page_number = page_number + 1
            # Extract the text content and its coordinates
            for element in page.extract_words(x_tolerance=1, y_tolerance=1, keep_blank_chars=True):
                text_dict = {}
                text = element["text"]
                x, y = element["x0"], element["top"]
                
                text_cord = f"Page {page_number + 1}: Text: {text} Coordinates: X={x}, Y={y}"
                text_dict.update({'page':page_number, 'text':text,'cordx':x,'cordy':y})
                text_list.append(text_dict)
    return text_list

text_list = extract_text_coordinates(pdf_path)

# %%
text_list
# Out:
# [{'page': 1,
#   'text': 'P627402800G',
#   'cordx': 110.4,
#   'cordy': 5.2835999999999785},
#  {'page': 1,
#   'text': 'P627402800G',
#   'cordx': 31.6801,
#   'cordy': 12.72359999999992},
#  {'page': 1,
#   'text': 'PO BOX 981572',
#   'cordx': 94.6801,
#   'cordy': 28.301400000000058},
#  {'page': 1,
#   'text': 'EL PASO, TX  79998-1572',
#   'cordx': 94.6801,
#   'cordy': 38.5014000000001},
#  {'page': 1,
#   'text': ' 190127   ',
#   'cordx': 271.92023408,
#   'cordy': 69.48339999999996},
#  {'page': 1, 'text': 'If you have any', 'cordx': 294.84, 'cordy': 74.8614},
#  {'page': 1,
#   'text': '(800) 541-7846',
#   'cordx': 380.40012142879993,
#   'cordy': 75.58140000000003},
#  {'page': 1,
#   'text': 'Electronic Service Requested',
#   'cordx': 94.6801,
#   'cordy': 80.02130000000011},
#  {'page': 1,
#   'text': 'questions contact:',
#   'cordx': 294.84,
#   'cordy': 86.02120000000002},
#  {'page': 1,
#   'text': 'WWW.GUARDIANANYTIME.COM',
#   'cordx': 380.40012142879993,
#   'cordy': 86.02120000000002},
#  {'page': 1,
#   'text': 'Provider:',
#   'cordx': 294.8399999999999,
#   'cordy': 101.8614},
#  {'page': 1,
#   'text': 'BRADLEY J SMITH',
#   'cordx': 382.6802169127999,
#   'cordy': 100.90124400000002},
#  {'page': 1,
#   'text': 'ALL FOR AADC 840',
#   'cordx': 170.75986395799998,
#   'cordy': 109.34399999999994},
#  {'page': 1,
#   'text': 'Date:',
#   'cordx': 294.8399999999999,
#   'cordy': 111.58134400000006},
#  {'page': 1,
#   'text': '05/16/23',
#   'cordx': 382.6802169127999,
#   'cordy': 111.46142200000008},
#  {'page': 1,
#   'text': '30298 0.5738 AB 0.504',
#   'cordx': 49.9199,
#   'cordy': 118.34399999999994},
#  {'page': 1, 'text': 'Payee:', 'cordx': 294.84, 'cordy': 121.30140000000006},
#  {'page': 1,
#   'text': 'UT BCDO SPECIALTY DENTAL SER',
#   'cordx': 382.6802169128,
#   'cordy': 120.46152000000006},
#  {'page': 1,
#   'text': 'FDFFATATTDADFAFTTDAFFTDDADDATFFAFFAFDFDFATFTDFFTFTFADFDFTFFFFADFF',
#   'cordx': 49.8,
#   'cordy': 125.8667999999999},
#  {'page': 1,
#   'text': 'Check No.:',
#   'cordx': 294.84,
#   'cordy': 131.02132000000006},
#  {'page': 1,
#   'text': '187889273',
#   'cordx': 382.6802169128,
#   'cordy': 130.90132000000006},
#  {'page': 1,
#   'text': 'Payment Amount:',
#   'cordx': 294.84000000000003,
#   'cordy': 140.86148000000003},
#  {'page': 1,
#   'text': '$472.00',
#   'cordx': 382.6802169128,
#   'cordy': 139.90132400000005},
#  {'page': 1,
#   'text': 'UT BCDO SPECIALTY DENTAL SERVI',
#   'cordx': 49.68010000000001,
#   'cordy': 144.57514000000003},
#  {'page': 1,
#   'text': '511',
#   'cordx': 247.319909575,
#   'cordy': 147.28869999999995},
#  {'page': 1,
#   'text': '8822 S REDWOOD RD STE 201',
#   'cordx': 49.68010000000001,
#   'cordy': 151.29506000000003},
#  {'page': 1,
#   'text': 'Expedite cash flow with e-payments. Sign up today!',
#   'cordx': 302.28,
#   'cordy': 152.46000000000004},
#  {'page': 1,
#   'text': 'WEST JORDAN, UT  84088-9336',
#   'cordx': 49.6801,
#   'cordy': 158.49504000000002},
#  {'page': 1,
#   'text': 'Guardian has contracted with Change Healthcare, a leading provider of ',
#   'cordx': 292.68,
#   'cordy': 167.65499999999997},
#  {'page': 1,
#   'text': 'revenue and payment cycle solutions, to deliver Electronic Funds Transfer ',
#   'cordx': 292.68,
#   'cordy': 177.85500000000002},
#  {'page': 1,
#   'text': '(EFT) services! Sign-up today by going to www.changehealthcare.com/support',
#   'cordx': 292.68,
#   'cordy': 188.05500000000006},
#  {'page': 1,
#   'text': '/customer-resources/enrollment-services for more information. Enrollment for ',
#   'cordx': 292.68,
#   'cordy': 198.255},
#  {'page': 1,
#   'text': 'this service is offered to you at no additional cost and is available online or by ',
#   'cordx': 292.680144546,
#   'cordy': 208.45500000000004},
#  {'page': 1,
#   'text': 'calling 1.866.777.0713 and selecting Option 1.',
#   'cordx': 292.680144546,
#   'cordy': 218.6550000000001},
#  {'page': 1,
#   'text': 'PROVIDER EXPLANATION OF BENEFITS - THIS IS NOT A BILL',
#   'cordx': 100.8,
#   'cordy': 247.89060000000006},
#  {'page': 1,
#   'text': 'Important!  Please examine this statement for accuracy.  Save this statement for tax purposes.',
#   'cordx': 41.039820415799994,
#   'cordy': 266.17870000000005},
#  {'page': 1,
#   'text': 'Patient Account No.:120371633',
#   'cordx': 225.83943376399998,
#   'cordy': 282.34128},
#  {'page': 1,
#   'text': 'Claim Number:',
#   'cordx': 18.8398,
#   'cordy': 284.02139999999997},
#  {'page': 1, 'text': '27129F13500', 'cordx': 93.119811492, 'cordy': 283.90148},
#  {'page': 1,
#   'text': 'Plan Number:00042176',
#   'cordx': 465.83932013599997,
#   'cordy': 284.620998},
#  {'page': 1,
#   'text': 'Patient Name:',
#   'cordx': 18.8398,
#   'cordy': 293.02139999999997},
#  {'page': 1,
#   'text': 'MARILYN LARKIN',
#   'cordx': 93.119811492,
#   'cordy': 292.90148},
#  {'page': 1,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 293.02137999999997},
#  {'page': 1,
#   'text': 'DANIEL LARKIN',
#   'cordx': 315.119469344,
#   'cordy': 292.90108},
#  {'page': 1,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 295.18111999999996},
#  {'page': 1, 'text': 'DAUGHTER', 'cordx': 526.6794936904, 'cordy': 295.061198},
#  {'page': 1,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 303.46119799999997},
#  {'page': 1,
#   'text': 'SPEED OF LIGHT OPS, LLC',
#   'cordx': 93.119811492,
#   'cordy': 303.34128},
#  {'page': 1, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 314.5686},
#  {'page': 1,
#   'text': 'Submitted',
#   'cordx': 72.3602,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Alt',
#   'cordx': 155.16029745327495,
#   'cordy': 313.84860000000003},
#  {'page': 1, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Date of',
#   'cordx': 224.64004397875,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 313.84860000000003},
#  {'page': 1,
#   'text': 'Coverage',
#   'cordx': 490.680086151525,
#   'cordy': 313.84860000000003},
#  {'page': 1, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 313.84860000000003},
#  {'page': 1, 'text': 'No.', 'cordx': 21.719875162250002, 'cordy': 323.68852},
#  {'page': 1,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Code',
#   'cordx': 151.56030081277495,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'No.',
#   'cordx': 186.96031734874998,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 279.120124551525,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Amount',
#   'cordx': 442.320378138025,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Percent',
#   'cordx': 493.919927428275,
#   'cordy': 322.96891000000005},
#  {'page': 1,
#   'text': 'Amount',
#   'cordx': 547.1998391022499,
#   'cordy': 322.96891000000005},
#  {'page': 1, 'text': '1', 'cordx': 24.2398, 'cordy': 335.3286},
#  {'page': 1,
#   'text': 'D0120/Periodic Eval',
#   'cordx': 39.83979369292,
#   'cordy': 335.3286},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 335.3286},
#  {'page': 1, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 334.608678},
#  {'page': 1, 'text': '39.00', 'cordx': 302.0403026225, 'cordy': 334.608678},
#  {'page': 1, 'text': '23.00', 'cordx': 359.1601348725, 'cordy': 335.3286},
#  {'page': 1, 'text': '23.00', 'cordx': 409.439859725, 'cordy': 335.3286},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 335.3286},
#  {'page': 1, 'text': '23.00', 'cordx': 571.2001705475, 'cordy': 336.168838},
#  {'page': 1, 'text': '2', 'cordx': 24.2398, 'cordy': 345.0486},
#  {'page': 1,
#   'text': 'D1206/Fluoride Varn',
#   'cordx': 39.83979369292,
#   'cordy': 345.0486},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 345.0486},
#  {'page': 1, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 344.208756},
#  {'page': 1, 'text': '36.00', 'cordx': 302.0403026225, 'cordy': 344.208756},
#  {'page': 1, 'text': '15.00', 'cordx': 359.1601348725, 'cordy': 345.0486},
#  {'page': 1, 'text': '15.00', 'cordx': 409.439859725, 'cordy': 345.0486},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 345.0486},
#  {'page': 1, 'text': '15.00', 'cordx': 571.2001705475, 'cordy': 345.768916},
#  {'page': 1,
#   'text': 'TOTALS',
#   'cordx': 223.07999323199996,
#   'cordy': 354.97478},
#  {'page': 1, 'text': '75.00', 'cordx': 301.44, 'cordy': 354.6486},
#  {'page': 1, 'text': '38.00', 'cordx': 359.16, 'cordy': 354.6486},
#  {'page': 1, 'text': '38.00', 'cordx': 409.43973523248, 'cordy': 354.6486},
#  {'page': 1, 'text': '0.00', 'cordx': 499.080260925, 'cordy': 354.6485},
#  {'page': 1, 'text': '38.00', 'cordx': 571.2, 'cordy': 354.6486},
#  {'page': 1, 'text': ' ', 'cordx': 22.6801, 'cordy': 365.9286},
#  {'page': 1,
#   'text': 'BENEFIT SUMMARY',
#   'cordx': 444.59999176229996,
#   'cordy': 368.5348},
#  {'page': 1,
#   'text': 'TOTAL BENEFIT PAYABLE.........',
#   'cordx': 389.4,
#   'cordy': 379.695},
#  {'page': 1, 'text': '$38.00', 'cordx': 565.92, 'cordy': 379.695},
#  {'page': 1,
#   'text': 'HIGHER ALLOWABLE..................',
#   'cordx': 389.3999001933,
#   'cordy': 390.254678},
#  {'page': 1, 'text': '$38.00', 'cordx': 565.9200259473, 'cordy': 390.9746},
#  {'page': 1,
#   'text': 'PAID BY OTHER INSURANCE.....',
#   'cordx': 389.39987424599997,
#   'cordy': 399.9747},
#  {'page': 1, 'text': '$0.00', 'cordx': 570.480168123, 'cordy': 402.25478},
#  {'page': 1,
#   'text': 'ADJUSTMENTS...............................',
#   'cordx': 389.39987424599997,
#   'cordy': 411.25478},
#  {'page': 1, 'text': '$0.00', 'cordx': 570.47280238854, 'cordy': 411.25478},
#  {'page': 1,
#   'text': 'TOTAL BENEFIT PAID..................',
#   'cordx': 389.39987424599997,
#   'cordy': 422.53488},
#  {'page': 1, 'text': '$ 38.00', 'cordx': 563.63578394112, 'cordy': 422.53488},
#  {'page': 1,
#   'text': "PATIENT'S RESPONSIBILITY.....",
#   'cordx': 389.39987424599997,
#   'cordy': 433.69468},
#  {'page': 1, 'text': '$0.00', 'cordx': 570.46902969528, 'cordy': 433.69468},
#  {'page': 1,
#   'text': 'Remarks for claim # 27129F13500:',
#   'cordx': 18.1199,
#   'cordy': 459.255},
#  {'page': 1,
#   'text': 'REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE',
#   'cordx': 18.1199,
#   'cordy': 470.41519999999997},
#  {'page': 1,
#   'text': 'Patient Account No.:120371632',
#   'cordx': 225.83943376399998,
#   'cordy': 493.54118},
#  {'page': 1, 'text': 'Claim Number:', 'cordx': 18.8398, 'cordy': 495.1014},
#  {'page': 1,
#   'text': '27128F13500',
#   'cordx': 93.119811492,
#   'cordy': 494.98148000000003},
#  {'page': 1,
#   'text': 'Plan Number:00042176',
#   'cordx': 465.83932013599997,
#   'cordy': 495.820428},
#  {'page': 1, 'text': 'Patient Name:', 'cordx': 18.8398, 'cordy': 504.1014},
#  {'page': 1,
#   'text': 'ANDREW LARKIN',
#   'cordx': 93.119811492,
#   'cordy': 503.98148000000003},
#  {'page': 1,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 504.10138},
#  {'page': 1,
#   'text': 'DANIEL LARKIN',
#   'cordx': 315.119469344,
#   'cordy': 503.98098},
#  {'page': 1,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 506.38054999999997},
#  {'page': 1, 'text': 'SON', 'cordx': 526.6794936904, 'cordy': 506.260628},
#  {'page': 1,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 514.660628},
#  {'page': 1,
#   'text': 'SPEED OF LIGHT OPS, LLC',
#   'cordx': 93.119811492,
#   'cordy': 514.54128},
#  {'page': 1, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 525.7686},
#  {'page': 1, 'text': 'Submitted', 'cordx': 72.3602, 'cordy': 524.9286},
#  {'page': 1, 'text': 'Alt', 'cordx': 155.16029745327495, 'cordy': 524.9286},
#  {'page': 1, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 524.9286},
#  {'page': 1, 'text': 'Date of', 'cordx': 224.64004397875, 'cordy': 524.9286},
#  {'page': 1,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 524.9286},
#  {'page': 1,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 524.9286},
#  {'page': 1,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 524.9286},
#  {'page': 1,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 524.9286},
#  {'page': 1, 'text': 'Coverage', 'cordx': 490.680086151525, 'cordy': 524.9286},
#  {'page': 1, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 524.9286},
#  {'page': 1, 'text': 'No.', 'cordx': 21.719875162250002, 'cordy': 534.88852},
#  {'page': 1,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 534.04852},
#  {'page': 1, 'text': 'Code', 'cordx': 151.56030081277495, 'cordy': 534.04852},
#  {'page': 1, 'text': 'No.', 'cordx': 186.96031734874998, 'cordy': 534.04852},
#  {'page': 1,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 534.04852},
#  {'page': 1, 'text': 'Charge', 'cordx': 279.120124551525, 'cordy': 534.04852},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 534.04852},
#  {'page': 1,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 534.04852},
#  {'page': 1, 'text': 'Amount', 'cordx': 442.320378138025, 'cordy': 534.04852},
#  {'page': 1, 'text': 'Percent', 'cordx': 493.919927428275, 'cordy': 534.04852},
#  {'page': 1, 'text': 'Amount', 'cordx': 547.1998391022499, 'cordy': 534.04852},
#  {'page': 1, 'text': '1', 'cordx': 24.2398, 'cordy': 546.5286},
#  {'page': 1,
#   'text': 'D0120/Periodic Eval',
#   'cordx': 39.83979369292,
#   'cordy': 546.5286},
#  {'page': 1, 'text': 'FM', 'cordx': 188.04, 'cordy': 546.5286},
#  {'page': 1, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 545.808678},
#  {'page': 1, 'text': '39.00', 'cordx': 302.0403026225, 'cordy': 545.808678},
#  {'page': 1, 'text': '23.00', 'cordx': 359.1601348725, 'cordy': 546.5286},
#  {'page': 1, 'text': '23.00', 'cordx': 409.439859725, 'cordy': 546.5286},
#  {'page': 1, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 546.5286},
#  {'page': 1, 'text': '23.00', 'cordx': 571.2001705475, 'cordy': 547.248518},
#  {'page': 1, 'text': '10 Hudson Yards', 'cordx': 342.12, 'cordy': 595.095},
#  {'page': 1,
#   'text': 'CHECK NO: 187889273',
#   'cordx': 445.68,
#   'cordy': 596.8614},
#  {'page': 1, 'text': 'New York, NY 10001', 'cordx': 342.12, 'cordy': 604.095},
#  {'page': 1,
#   'text': 'CHECK DATE: 05/16/23',
#   'cordx': 445.68,
#   'cordy': 610.3014000000001},
#  {'page': 1, 'text': 'AMOUNT', 'cordx': 488.4000390352, 'cordy': 625.3015},
#  {'page': 1, 'text': '51-44', 'cordx': 427.2, 'cordy': 626.49},
#  {'page': 1, 'text': '119', 'cordx': 429.7199212548, 'cordy': 636.9298},
#  {'page': 1, 'text': '****$472.00', 'cordx': 459.12, 'cordy': 638.0214},
#  {'page': 1, 'text': 'PAY', 'cordx': 49.91950020000007, 'cordy': 649.3012},
#  {'page': 1,
#   'text': 'Four Hundred Seventy Two Dollars',
#   'cordx': 74.39782837705638,
#   'cordy': 649.3012},
#  {'page': 1,
#   'text': 'Void unless presented ',
#   'cordx': 470.76,
#   'cordy': 653.6886},
#  {'page': 1,
#   'text': 'within 180 days',
#   'cordx': 482.3998500725,
#   'cordy': 662.80852},
#  {'page': 1, 'text': 'TO THE', 'cordx': 49.9199, 'cordy': 666.5814},
#  {'page': 1,
#   'text': 'UT BCDO SPECIALTY DENTAL SERVI',
#   'cordx': 114.119883328,
#   'cordy': 668.86151},
#  {'page': 1, 'text': 'ORDER OF', 'cordx': 49.9199, 'cordy': 677.7412},
#  {'page': 1,
#   'text': 'BANK OF AMERICA',
#   'cordx': 36.8398,
#   'cordy': 705.2099000000001},
#  {'page': 1,
#   'text': '150 WINDSOR STREET, HARTFORD, CT 06120',
#   'cordx': 36.8398,
#   'cordy': 712.04974},
#  {'page': 1,
#   'text': 'C187889273C',
#   'cordx': 94.91999359245003,
#   'cordy': 763.9888},
#  {'page': 1,
#   'text': 'A011900445A',
#   'cordx': 202.92002520884995,
#   'cordy': 763.9888},
#  {'page': 1, 'text': '40355C', 'cordx': 355.92000346094994, 'cordy': 763.9888},
#  {'page': 1,
#   'text': '       F 2 FO 1           89203 VNE',
#   'cordx': 14.403799999999999,
#   'cordy': 9.182313641940482},
#  {'page': 3,
#   'text': 'P627402800G',
#   'cordx': 110.4,
#   'cordy': 5.2835999999999785},
#  {'page': 3,
#   'text': 'P627402800G',
#   'cordx': 31.6801,
#   'cordy': 12.72359999999992},
#  {'page': 3,
#   'text': 'PO BOX 981572',
#   'cordx': 102.12018156879992,
#   'cordy': 37.30140000000017},
#  {'page': 3,
#   'text': 'EL PASO TX 79998-1572',
#   'cordx': 102.12018156879992,
#   'cordy': 46.901400000000194},
#  {'page': 3,
#   'text': 'If you have any',
#   'cordx': 294.84,
#   'cordy': 65.02140000000009},
#  {'page': 3,
#   'text': '(800) 541-7846',
#   'cordx': 380.40012142879993,
#   'cordy': 65.86170000000016},
#  {'page': 3,
#   'text': '    ',
#   'cordx': 271.92023408,
#   'cordy': 69.48339999999996},
#  {'page': 3,
#   'text': 'questions contact:',
#   'cordx': 294.84,
#   'cordy': 76.18160000000012},
#  {'page': 3,
#   'text': 'WWW.GUARDIANANYTIME.COM',
#   'cordx': 380.40012142879993,
#   'cordy': 76.30150000000015},
#  {'page': 3,
#   'text': 'BRADLEY J SMITH',
#   'cordx': 382.6802169127999,
#   'cordy': 93.4616000000002},
#  {'page': 3,
#   'text': 'Provider:',
#   'cordx': 294.8399999999999,
#   'cordy': 95.0214000000002},
#  {'page': 3,
#   'text': 'Date:',
#   'cordx': 294.8399999999999,
#   'cordy': 104.0214000000002},
#  {'page': 3,
#   'text': '05/16/23',
#   'cordx': 382.6802169127999,
#   'cordy': 103.9014000000002},
#  {'page': 3,
#   'text': 'UT BCDO SPECIALTY DENTAL SER',
#   'cordx': 382.6802169128,
#   'cordy': 113.74162000000001},
#  {'page': 3, 'text': 'Payee:', 'cordx': 294.84, 'cordy': 115.30140000000006},
#  {'page': 3,
#   'text': 'Check No.:',
#   'cordx': 294.84,
#   'cordy': 125.02132000000006},
#  {'page': 3,
#   'text': '187889273',
#   'cordx': 382.6802169128,
#   'cordy': 124.90142000000003},
#  {'page': 3,
#   'text': 'Payment Amount:',
#   'cordx': 294.84,
#   'cordy': 134.02132000000006},
#  {'page': 3,
#   'text': '$472.00',
#   'cordx': 382.6802169128,
#   'cordy': 133.90142000000003},
#  {'page': 3,
#   'text': 'Patient Account No.:120371632',
#   'cordx': 225.83943376399998,
#   'cordy': 149.7411800000001},
#  {'page': 3,
#   'text': 'Claim Number:',
#   'cordx': 18.8398,
#   'cordy': 151.30140000000006},
#  {'page': 3,
#   'text': '27128F13500',
#   'cordx': 93.119811492,
#   'cordy': 151.18148000000008},
#  {'page': 3,
#   'text': 'Plan Number:00042176',
#   'cordx': 465.83932013599997,
#   'cordy': 151.9008980000001},
#  {'page': 3,
#   'text': 'Patient Name:',
#   'cordx': 18.8398,
#   'cordy': 160.30140000000006},
#  {'page': 3,
#   'text': 'ANDREW LARKIN',
#   'cordx': 93.119811492,
#   'cordy': 160.18148000000008},
#  {'page': 3,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 160.3013800000001},
#  {'page': 3,
#   'text': 'DANIEL LARKIN',
#   'cordx': 315.119469344,
#   'cordy': 160.1809800000001},
#  {'page': 3,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 162.58102000000008},
#  {'page': 3,
#   'text': 'SON',
#   'cordx': 526.6794936904,
#   'cordy': 162.4610980000001},
#  {'page': 3,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 170.86109800000008},
#  {'page': 3,
#   'text': 'SPEED OF LIGHT OPS, LLC',
#   'cordx': 93.119811492,
#   'cordy': 170.74128000000007},
#  {'page': 3, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 181.84859999999992},
#  {'page': 3, 'text': 'Submitted', 'cordx': 72.3602, 'cordy': 181.1286},
#  {'page': 3, 'text': 'Alt', 'cordx': 155.16029745327495, 'cordy': 181.1286},
#  {'page': 3, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 181.1286},
#  {'page': 3, 'text': 'Date of', 'cordx': 224.64004397875, 'cordy': 181.1286},
#  {'page': 3,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 181.1286},
#  {'page': 3,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 181.1286},
#  {'page': 3,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 181.1286},
#  {'page': 3,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 181.1286},
#  {'page': 3, 'text': 'Coverage', 'cordx': 490.680086151525, 'cordy': 181.1286},
#  {'page': 3, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 181.1286},
#  {'page': 3,
#   'text': 'No.',
#   'cordx': 21.719875162250002,
#   'cordy': 190.96890999999994},
#  {'page': 3,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Code',
#   'cordx': 151.56030081277495,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'No.',
#   'cordx': 186.96031734874998,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 279.120124551525,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Amount',
#   'cordx': 442.320378138025,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Percent',
#   'cordx': 493.919927428275,
#   'cordy': 190.24851999999998},
#  {'page': 3,
#   'text': 'Amount',
#   'cordx': 547.1998391022499,
#   'cordy': 190.24851999999998},
#  {'page': 3, 'text': '2', 'cordx': 24.2398, 'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': 'D0240/Occlusal Image',
#   'cordx': 39.83979369292,
#   'cordy': 202.72859999999991},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': '05/11/23',
#   'cordx': 224.8801224475,
#   'cordy': 202.00867799999992},
#  {'page': 3,
#   'text': '27.00',
#   'cordx': 302.0403026225,
#   'cordy': 202.00867799999992},
#  {'page': 3,
#   'text': '16.00',
#   'cordx': 359.1601348725,
#   'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': '16.00',
#   'cordx': 409.439859725,
#   'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 202.72859999999991},
#  {'page': 3,
#   'text': '16.00',
#   'cordx': 571.2001705475,
#   'cordy': 203.44851799999992},
#  {'page': 3, 'text': '3', 'cordx': 24.2398, 'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': 'D0240/Occlusal Image',
#   'cordx': 39.83979369292,
#   'cordy': 212.32859999999994},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': '05/11/23',
#   'cordx': 224.8801224475,
#   'cordy': 211.60867799999994},
#  {'page': 3,
#   'text': '27.00',
#   'cordx': 302.0403026225,
#   'cordy': 211.60867799999994},
#  {'page': 3,
#   'text': '16.00',
#   'cordx': 359.1601348725,
#   'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': '16.00',
#   'cordx': 409.439859725,
#   'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 212.32859999999994},
#  {'page': 3,
#   'text': '16.00',
#   'cordx': 571.2001705475,
#   'cordy': 213.04851799999994},
#  {'page': 3, 'text': '4', 'cordx': 24.2398, 'cordy': 222.04859999999996},
#  {'page': 3,
#   'text': 'D0272/Bitewing - 2',
#   'cordx': 39.83979369292,
#   'cordy': 222.04859999999996},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 222.04859999999996},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 221.208756},
#  {'page': 3, 'text': '36.00', 'cordx': 302.0403026225, 'cordy': 221.208756},
#  {'page': 3,
#   'text': '22.00',
#   'cordx': 359.1601348725,
#   'cordy': 222.04859999999996},
#  {'page': 3,
#   'text': '22.00',
#   'cordx': 409.439859725,
#   'cordy': 222.04859999999996},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 222.04859999999996},
#  {'page': 3, 'text': '22.00', 'cordx': 571.2001705475, 'cordy': 222.768916},
#  {'page': 3, 'text': '5', 'cordx': 24.2398, 'cordy': 231.6486},
#  {'page': 3,
#   'text': 'D1120/Child Cleaning',
#   'cordx': 39.83979369292,
#   'cordy': 231.6486},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 231.6486},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 230.928678},
#  {'page': 3, 'text': '52.00', 'cordx': 302.0403026225, 'cordy': 230.928678},
#  {'page': 3, 'text': '35.00', 'cordx': 359.1601348725, 'cordy': 231.6486},
#  {'page': 3, 'text': '35.00', 'cordx': 409.439859725, 'cordy': 231.6486},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 231.6486},
#  {'page': 3,
#   'text': '35.00',
#   'cordx': 571.2001705475,
#   'cordy': 232.36890800000003},
#  {'page': 3, 'text': '6', 'cordx': 24.2398, 'cordy': 241.2485999999999},
#  {'page': 3,
#   'text': 'D1206/Fluoride Varn',
#   'cordx': 39.83979369292,
#   'cordy': 241.2485999999999},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 241.2485999999999},
#  {'page': 3,
#   'text': '05/11/23',
#   'cordx': 224.8801224475,
#   'cordy': 240.5286779999999},
#  {'page': 3,
#   'text': '36.00',
#   'cordx': 302.0403026225,
#   'cordy': 240.5286779999999},
#  {'page': 3,
#   'text': '15.00',
#   'cordx': 359.1601348725,
#   'cordy': 241.2485999999999},
#  {'page': 3,
#   'text': '15.00',
#   'cordx': 409.439859725,
#   'cordy': 241.2485999999999},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 241.2485999999999},
#  {'page': 3,
#   'text': '15.00',
#   'cordx': 571.2001705475,
#   'cordy': 241.96890799999994},
#  {'page': 3,
#   'text': 'TOTALS',
#   'cordx': 223.08016135499994,
#   'cordy': 251.17487999999992},
#  {'page': 3, 'text': '217.00', 'cordx': 297.36, 'cordy': 250.84859999999992},
#  {'page': 3, 'text': '127.00', 'cordx': 355.08, 'cordy': 250.84859999999992},
#  {'page': 3,
#   'text': '127.00',
#   'cordx': 405.36005621339996,
#   'cordy': 250.84859999999992},
#  {'page': 3,
#   'text': '0.00',
#   'cordx': 499.080260925,
#   'cordy': 250.84850000000006},
#  {'page': 3, 'text': '127.00', 'cordx': 567.12, 'cordy': 250.84859999999992},
#  {'page': 3, 'text': ' ', 'cordx': 22.6801, 'cordy': 262.1286},
#  {'page': 3,
#   'text': 'BENEFIT SUMMARY',
#   'cordx': 444.59999176229996,
#   'cordy': 264.7348999999999},
#  {'page': 3,
#   'text': 'TOTAL BENEFIT PAYABLE.........',
#   'cordx': 389.4,
#   'cordy': 276.015},
#  {'page': 3, 'text': '$127.00', 'cordx': 561.36, 'cordy': 276.015},
#  {'page': 3,
#   'text': 'HIGHER ALLOWABLE..................',
#   'cordx': 389.39990019329997,
#   'cordy': 286.454778},
#  {'page': 3, 'text': '$127.00', 'cordx': 561.3598578243, 'cordy': 287.1747},
#  {'page': 3,
#   'text': 'PAID BY OTHER INSURANCE.....',
#   'cordx': 389.400042369,
#   'cordy': 296.1748},
#  {'page': 3, 'text': '$0.00', 'cordx': 570.480336246, 'cordy': 298.45488},
#  {'page': 3,
#   'text': 'ADJUSTMENTS...............................',
#   'cordx': 389.40004236899995,
#   'cordy': 307.45488},
#  {'page': 3, 'text': '$0.00', 'cordx': 570.47297051154, 'cordy': 307.45488},
#  {'page': 3,
#   'text': 'TOTAL BENEFIT PAID..................',
#   'cordx': 389.40004236899995,
#   'cordy': 318.73498},
#  {'page': 3,
#   'text': '$ 127.00',
#   'cordx': 559.0761133032299,
#   'cordy': 318.73498},
#  {'page': 3,
#   'text': "PATIENT'S RESPONSIBILITY.....",
#   'cordx': 389.40004236899995,
#   'cordy': 330.01508},
#  {'page': 3, 'text': '$0.00', 'cordx': 570.46919781828, 'cordy': 330.01508},
#  {'page': 3,
#   'text': 'Remarks for claim # 27128F13500:',
#   'cordx': 18.1199,
#   'cordy': 355.575},
#  {'page': 3,
#   'text': 'REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE',
#   'cordx': 18.1199,
#   'cordy': 366.6152},
#  {'page': 3,
#   'text': 'Patient Account No.:120371630',
#   'cordx': 225.83943376399998,
#   'cordy': 389.74168},
#  {'page': 3, 'text': 'Claim Number:', 'cordx': 18.8398, 'cordy': 391.4214},
#  {'page': 3, 'text': '27126F13500', 'cordx': 93.119811492, 'cordy': 391.30148},
#  {'page': 3,
#   'text': 'Plan Number:00042176',
#   'cordx': 465.83932013599997,
#   'cordy': 392.021388},
#  {'page': 3, 'text': 'Patient Name:', 'cordx': 18.8398, 'cordy': 400.4214},
#  {'page': 3,
#   'text': 'COLLIN LARKIN',
#   'cordx': 93.119811492,
#   'cordy': 400.30148},
#  {'page': 3,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 400.42138},
#  {'page': 3,
#   'text': 'DANIEL LARKIN',
#   'cordx': 315.119469344,
#   'cordy': 400.30147999999997},
#  {'page': 3,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 402.70151},
#  {'page': 3, 'text': 'SON', 'cordx': 526.6794936904, 'cordy': 402.581588},
#  {'page': 3,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 410.861588},
#  {'page': 3,
#   'text': 'SPEED OF LIGHT OPS, LLC',
#   'cordx': 93.119811492,
#   'cordy': 410.74128},
#  {'page': 3, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 421.9686},
#  {'page': 3, 'text': 'Submitted', 'cordx': 72.3602, 'cordy': 421.2486},
#  {'page': 3, 'text': 'Alt', 'cordx': 155.16029745327495, 'cordy': 421.2486},
#  {'page': 3, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 421.2486},
#  {'page': 3, 'text': 'Date of', 'cordx': 224.64004397875, 'cordy': 421.2486},
#  {'page': 3,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 421.2486},
#  {'page': 3,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 421.2486},
#  {'page': 3,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 421.2486},
#  {'page': 3,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 421.2486},
#  {'page': 3, 'text': 'Coverage', 'cordx': 490.680086151525, 'cordy': 421.2486},
#  {'page': 3, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 421.2486},
#  {'page': 3,
#   'text': 'No.',
#   'cordx': 21.719875162250002,
#   'cordy': 431.08851999999996},
#  {'page': 3,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 430.36891},
#  {'page': 3, 'text': 'Code', 'cordx': 151.56030081277495, 'cordy': 430.36891},
#  {'page': 3, 'text': 'No.', 'cordx': 186.96031734874998, 'cordy': 430.36891},
#  {'page': 3,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 430.36891},
#  {'page': 3, 'text': 'Charge', 'cordx': 279.120124551525, 'cordy': 430.36891},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 430.36891},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 430.36891},
#  {'page': 3, 'text': 'Amount', 'cordx': 442.320378138025, 'cordy': 430.36891},
#  {'page': 3, 'text': 'Percent', 'cordx': 493.919927428275, 'cordy': 430.36891},
#  {'page': 3, 'text': 'Amount', 'cordx': 547.1998391022499, 'cordy': 430.36891},
#  {'page': 3, 'text': '1', 'cordx': 24.2398, 'cordy': 442.84860000000003},
#  {'page': 3,
#   'text': 'D0120/Periodic Eval',
#   'cordx': 39.83979369292,
#   'cordy': 442.84860000000003},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 442.84860000000003},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 442.008756},
#  {'page': 3, 'text': '39.00', 'cordx': 302.0403026225, 'cordy': 442.008756},
#  {'page': 3,
#   'text': '23.00',
#   'cordx': 359.1601348725,
#   'cordy': 442.84860000000003},
#  {'page': 3,
#   'text': '23.00',
#   'cordx': 409.439859725,
#   'cordy': 442.84860000000003},
#  {'page': 3,
#   'text': '100%',
#   'cordx': 496.80066582250004,
#   'cordy': 442.84860000000003},
#  {'page': 3, 'text': '23.00', 'cordx': 571.2001705475, 'cordy': 443.568916},
#  {'page': 3, 'text': '2', 'cordx': 24.2398, 'cordy': 452.4486},
#  {'page': 3,
#   'text': 'D0240/Occlusal Image',
#   'cordx': 39.83979369292,
#   'cordy': 452.4486},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 452.4486},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 451.728678},
#  {'page': 3, 'text': '27.00', 'cordx': 302.0403026225, 'cordy': 451.728678},
#  {'page': 3, 'text': '16.00', 'cordx': 359.1601348725, 'cordy': 452.4486},
#  {'page': 3, 'text': '16.00', 'cordx': 409.439859725, 'cordy': 452.4486},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 452.4486},
#  {'page': 3, 'text': '16.00', 'cordx': 571.2001705475, 'cordy': 453.168908},
#  {'page': 3, 'text': '3', 'cordx': 24.2398, 'cordy': 462.0486},
#  {'page': 3,
#   'text': 'D0240/Occlusal Image',
#   'cordx': 39.83979369292,
#   'cordy': 462.0486},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 462.0486},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 461.328678},
#  {'page': 3, 'text': '27.00', 'cordx': 302.0403026225, 'cordy': 461.328678},
#  {'page': 3, 'text': '16.00', 'cordx': 359.1601348725, 'cordy': 462.0486},
#  {'page': 3, 'text': '16.00', 'cordx': 409.439859725, 'cordy': 462.0486},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 462.0486},
#  {'page': 3, 'text': '16.00', 'cordx': 571.2001705475, 'cordy': 462.888838},
#  {'page': 3, 'text': '4', 'cordx': 24.2398, 'cordy': 471.7686},
#  {'page': 3,
#   'text': 'D0272/Bitewing - 2',
#   'cordx': 39.83979369292,
#   'cordy': 471.7686},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 471.7686},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 470.928366},
#  {'page': 3, 'text': '36.00', 'cordx': 302.0403026225, 'cordy': 470.928366},
#  {'page': 3, 'text': '22.00', 'cordx': 359.1601348725, 'cordy': 471.7686},
#  {'page': 3, 'text': '22.00', 'cordx': 409.439859725, 'cordy': 471.7686},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 471.7686},
#  {'page': 3, 'text': '22.00', 'cordx': 571.2001705475, 'cordy': 472.488526},
#  {'page': 3, 'text': '5', 'cordx': 24.2398, 'cordy': 481.3686},
#  {'page': 3,
#   'text': 'D1120/Child Cleaning',
#   'cordx': 39.83979369292,
#   'cordy': 481.3686},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 481.3686},
#  {'page': 3,
#   'text': '05/11/23',
#   'cordx': 224.8801224475,
#   'cordy': 480.64828700000004},
#  {'page': 3,
#   'text': '52.00',
#   'cordx': 302.0403026225,
#   'cordy': 480.64828700000004},
#  {'page': 3, 'text': '35.00', 'cordx': 359.1601348725, 'cordy': 481.3686},
#  {'page': 3, 'text': '35.00', 'cordx': 409.439859725, 'cordy': 481.3686},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 481.3686},
#  {'page': 3, 'text': '35.00', 'cordx': 571.2001705475, 'cordy': 482.088517},
#  {'page': 3, 'text': '6', 'cordx': 24.2398, 'cordy': 490.9686},
#  {'page': 3,
#   'text': 'D1206/Fluoride Varn',
#   'cordx': 39.83979369292,
#   'cordy': 490.9686},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 490.9686},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 490.248287},
#  {'page': 3, 'text': '36.00', 'cordx': 302.0403026225, 'cordy': 490.248287},
#  {'page': 3, 'text': '15.00', 'cordx': 359.1601348725, 'cordy': 490.9686},
#  {'page': 3, 'text': '15.00', 'cordx': 409.439859725, 'cordy': 490.9686},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 490.9686},
#  {'page': 3, 'text': '15.00', 'cordx': 571.2001705475, 'cordy': 491.808447},
#  {'page': 3,
#   'text': 'TOTALS',
#   'cordx': 223.08016135499994,
#   'cordy': 501.01517000000007},
#  {'page': 3, 'text': '217.00', 'cordx': 297.36, 'cordy': 500.6886},
#  {'page': 3, 'text': '127.00', 'cordx': 355.08, 'cordy': 500.6886},
#  {'page': 3, 'text': '127.00', 'cordx': 405.36005621339996, 'cordy': 500.6886},
#  {'page': 3, 'text': '0.00', 'cordx': 499.080260925, 'cordy': 500.6888},
#  {'page': 3, 'text': '127.00', 'cordx': 567.12, 'cordy': 500.6886},
#  {'page': 3, 'text': ' ', 'cordx': 22.6801, 'cordy': 511.84860000000003},
#  {'page': 3,
#   'text': 'BENEFIT SUMMARY',
#   'cordx': 444.59999176229996,
#   'cordy': 514.4549},
#  {'page': 3,
#   'text': 'TOTAL BENEFIT PAYABLE.........',
#   'cordx': 389.4,
#   'cordy': 525.735},
#  {'page': 3, 'text': '$127.00', 'cordx': 561.36, 'cordy': 525.735},
#  {'page': 3,
#   'text': 'HIGHER ALLOWABLE..................',
#   'cordx': 389.39990019329997,
#   'cordy': 536.1748660000001},
#  {'page': 3,
#   'text': '$127.00',
#   'cordx': 561.3598578243,
#   'cordy': 537.0151000000001},
#  {'page': 3,
#   'text': 'PAID BY OTHER INSURANCE.....',
#   'cordx': 389.400042369,
#   'cordy': 546.0151000000001},
#  {'page': 3, 'text': '$0.00', 'cordx': 570.480336246, 'cordy': 548.17487},
#  {'page': 3,
#   'text': 'ADJUSTMENTS...............................',
#   'cordx': 389.40004236899995,
#   'cordy': 557.17487},
#  {'page': 3, 'text': '$0.00', 'cordx': 570.47297051154, 'cordy': 557.17487},
#  {'page': 3,
#   'text': 'TOTAL BENEFIT PAID..................',
#   'cordx': 389.40004236899995,
#   'cordy': 568.45497},
#  {'page': 3,
#   'text': '$ 127.00',
#   'cordx': 559.0761133032299,
#   'cordy': 568.45497},
#  {'page': 3,
#   'text': "PATIENT'S RESPONSIBILITY.....",
#   'cordx': 389.40004236899995,
#   'cordy': 579.7350700000001},
#  {'page': 3,
#   'text': '$0.00',
#   'cordx': 570.46919781828,
#   'cordy': 579.7350700000001},
#  {'page': 3,
#   'text': 'Remarks for claim # 27126F13500:',
#   'cordx': 18.1199,
#   'cordy': 605.2950000000001},
#  {'page': 3,
#   'text': 'REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE',
#   'cordx': 18.1199,
#   'cordy': 616.3352},
#  {'page': 3,
#   'text': 'Patient Account No.:120371631',
#   'cordx': 225.83943376399998,
#   'cordy': 639.58158},
#  {'page': 3, 'text': 'Claim Number:', 'cordx': 18.8398, 'cordy': 641.1414},
#  {'page': 3, 'text': '27127F13500', 'cordx': 93.119811492, 'cordy': 641.02148},
#  {'page': 3,
#   'text': 'Plan Number:00042176',
#   'cordx': 465.83932013599997,
#   'cordy': 641.7412879999999},
#  {'page': 3, 'text': 'Patient Name:', 'cordx': 18.8398, 'cordy': 650.1414},
#  {'page': 3,
#   'text': 'FOSTER LARKIN',
#   'cordx': 93.119811492,
#   'cordy': 650.02148},
#  {'page': 3,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 650.14138},
#  {'page': 3,
#   'text': 'DANIEL LARKIN',
#   'cordx': 315.119469344,
#   'cordy': 650.0213799999999},
#  {'page': 3,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 652.4214099999999},
#  {'page': 3, 'text': 'SON', 'cordx': 526.6794936904, 'cordy': 652.301488},
#  {'page': 3,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 660.7014879999999},
#  {'page': 3,
#   'text': 'SPEED OF LIGHT OPS, LLC',
#   'cordx': 93.119811492,
#   'cordy': 660.58168},
#  {'page': 3, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 671.6886},
#  {'page': 3, 'text': 'Submitted', 'cordx': 72.3602, 'cordy': 670.9686},
#  {'page': 3, 'text': 'Alt', 'cordx': 155.16029745327495, 'cordy': 670.9686},
#  {'page': 3, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 670.9686},
#  {'page': 3, 'text': 'Date of', 'cordx': 224.64004397875, 'cordy': 670.9686},
#  {'page': 3,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 670.9686},
#  {'page': 3,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 670.9686},
#  {'page': 3,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 670.9686},
#  {'page': 3,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 670.9686},
#  {'page': 3, 'text': 'Coverage', 'cordx': 490.680086151525, 'cordy': 670.9686},
#  {'page': 3, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 670.9686},
#  {'page': 3, 'text': 'No.', 'cordx': 21.719875162250002, 'cordy': 680.80852},
#  {'page': 3,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 680.08852},
#  {'page': 3, 'text': 'Code', 'cordx': 151.56030081277495, 'cordy': 680.08852},
#  {'page': 3, 'text': 'No.', 'cordx': 186.96031734874998, 'cordy': 680.08852},
#  {'page': 3,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 680.08852},
#  {'page': 3, 'text': 'Charge', 'cordx': 279.120124551525, 'cordy': 680.08852},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 680.08852},
#  {'page': 3,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 680.08852},
#  {'page': 3, 'text': 'Amount', 'cordx': 442.320378138025, 'cordy': 680.08852},
#  {'page': 3, 'text': 'Percent', 'cordx': 493.919927428275, 'cordy': 680.08852},
#  {'page': 3, 'text': 'Amount', 'cordx': 547.1998391022499, 'cordy': 680.08852},
#  {'page': 3, 'text': '1', 'cordx': 24.2398, 'cordy': 692.5687},
#  {'page': 3,
#   'text': 'D0120/Periodic Eval',
#   'cordx': 39.83979369292,
#   'cordy': 692.5687},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 692.5687},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 691.848387},
#  {'page': 3, 'text': '39.00', 'cordx': 302.0403026225, 'cordy': 691.848387},
#  {'page': 3, 'text': '23.00', 'cordx': 359.1601348725, 'cordy': 692.5687},
#  {'page': 3, 'text': '23.00', 'cordx': 409.439859725, 'cordy': 692.5687},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 692.5687},
#  {'page': 3,
#   'text': '23.00',
#   'cordx': 571.2001705475,
#   'cordy': 693.2886169999999},
#  {'page': 3, 'text': '2', 'cordx': 24.2398, 'cordy': 702.1687},
#  {'page': 3,
#   'text': 'D0272/Bitewing - 2',
#   'cordx': 39.83979369292,
#   'cordy': 702.1687},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 702.1687},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 701.448387},
#  {'page': 3, 'text': '36.00', 'cordx': 302.0403026225, 'cordy': 701.448387},
#  {'page': 3, 'text': '22.00', 'cordx': 359.1601348725, 'cordy': 702.1687},
#  {'page': 3, 'text': '22.00', 'cordx': 409.439859725, 'cordy': 702.1687},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 702.1687},
#  {'page': 3, 'text': '22.00', 'cordx': 571.2001705475, 'cordy': 702.888617},
#  {'page': 3, 'text': '3', 'cordx': 24.2398, 'cordy': 711.7687},
#  {'page': 3,
#   'text': 'D1120/Child Cleaning',
#   'cordx': 39.83979369292,
#   'cordy': 711.7687},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 711.7687},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 711.048387},
#  {'page': 3, 'text': '52.00', 'cordx': 302.0403026225, 'cordy': 711.048387},
#  {'page': 3, 'text': '35.00', 'cordx': 359.1601348725, 'cordy': 711.7687},
#  {'page': 3, 'text': '35.00', 'cordx': 409.439859725, 'cordy': 711.7687},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 711.7687},
#  {'page': 3, 'text': '35.00', 'cordx': 571.2001705475, 'cordy': 712.608547},
#  {'page': 3, 'text': '4', 'cordx': 24.2398, 'cordy': 721.4886},
#  {'page': 3,
#   'text': 'D1206/Fluoride Varn',
#   'cordx': 39.83979369292,
#   'cordy': 721.4886},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 721.4886},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 720.648366},
#  {'page': 3, 'text': '36.00', 'cordx': 302.0403026225, 'cordy': 720.648366},
#  {'page': 3, 'text': '15.00', 'cordx': 359.1601348725, 'cordy': 721.4886},
#  {'page': 3, 'text': '15.00', 'cordx': 409.439859725, 'cordy': 721.4886},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 721.4886},
#  {'page': 3, 'text': '15.00', 'cordx': 571.2001705475, 'cordy': 722.208526},
#  {'page': 3, 'text': '5', 'cordx': 24.2398, 'cordy': 731.0886},
#  {'page': 3,
#   'text': 'D0330/Panoramic',
#   'cordx': 39.83979369292,
#   'cordy': 731.0886},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 731.0886},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 730.368678},
#  {'page': 3, 'text': '82.00', 'cordx': 302.0403026225, 'cordy': 730.368678},
#  {'page': 3, 'text': '53.00', 'cordx': 359.1601348725, 'cordy': 731.0886},
#  {'page': 3, 'text': '53.00', 'cordx': 409.439859725, 'cordy': 731.0886},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 731.0886},
#  {'page': 3, 'text': '53.00', 'cordx': 571.2001705475, 'cordy': 731.808518},
#  {'page': 3, 'text': '6', 'cordx': 24.2398, 'cordy': 740.6886},
#  {'page': 3,
#   'text': 'D0240/Occlusal Image',
#   'cordx': 39.83979369292,
#   'cordy': 740.6886},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 740.6886},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 739.968678},
#  {'page': 3, 'text': '27.00', 'cordx': 302.0403026225, 'cordy': 739.968678},
#  {'page': 3, 'text': '16.00', 'cordx': 359.1601348725, 'cordy': 740.6886},
#  {'page': 3, 'text': '16.00', 'cordx': 409.439859725, 'cordy': 740.6886},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 740.6886},
#  {'page': 3, 'text': '16.00', 'cordx': 571.2001705475, 'cordy': 741.528448},
#  {'page': 3, 'text': '7', 'cordx': 24.2398, 'cordy': 750.4085},
#  {'page': 3,
#   'text': 'D0240/Occlusal Image',
#   'cordx': 39.83979369292,
#   'cordy': 750.4085},
#  {'page': 3, 'text': 'FM', 'cordx': 188.04, 'cordy': 750.4085},
#  {'page': 3, 'text': '05/11/23', 'cordx': 224.8801224475, 'cordy': 749.568656},
#  {'page': 3, 'text': '27.00', 'cordx': 302.0403026225, 'cordy': 749.568656},
#  {'page': 3, 'text': '16.00', 'cordx': 359.1601348725, 'cordy': 750.4085},
#  {'page': 3, 'text': '16.00', 'cordx': 409.439859725, 'cordy': 750.4085},
#  {'page': 3, 'text': '100%', 'cordx': 496.80066582250004, 'cordy': 750.4085},
#  {'page': 3, 'text': '16.00', 'cordx': 571.2001705475, 'cordy': 751.128426},
#  {'page': 3,
#   'text': '       721091F 2 FO 2           89203 VNE',
#   'cordx': 14.403799999999999,
#   'cordy': 9.182384986079},
#  {'page': 4,
#   'text': 'P627402800G',
#   'cordx': 110.4,
#   'cordy': 5.2835999999999785},
#  {'page': 4,
#   'text': 'P627402800G',
#   'cordx': 31.6801,
#   'cordy': 12.72359999999992},
#  {'page': 4,
#   'text': 'PO BOX 981572',
#   'cordx': 102.12018156879992,
#   'cordy': 37.30140000000017},
#  {'page': 4,
#   'text': 'EL PASO TX 79998-1572',
#   'cordx': 102.12018156879992,
#   'cordy': 46.901400000000194},
#  {'page': 4,
#   'text': 'If you have any',
#   'cordx': 294.84,
#   'cordy': 65.02140000000009},
#  {'page': 4,
#   'text': '(800) 541-7846',
#   'cordx': 380.40012142879993,
#   'cordy': 65.86170000000016},
#  {'page': 4,
#   'text': '    ',
#   'cordx': 271.92023408,
#   'cordy': 69.48339999999996},
#  {'page': 4,
#   'text': 'questions contact:',
#   'cordx': 294.84,
#   'cordy': 76.18160000000012},
#  {'page': 4,
#   'text': 'WWW.GUARDIANANYTIME.COM',
#   'cordx': 380.40012142879993,
#   'cordy': 76.30150000000015},
#  {'page': 4,
#   'text': 'BRADLEY J SMITH',
#   'cordx': 382.6802169127999,
#   'cordy': 93.4616000000002},
#  {'page': 4,
#   'text': 'Provider:',
#   'cordx': 294.8399999999999,
#   'cordy': 95.0214000000002},
#  {'page': 4,
#   'text': 'Date:',
#   'cordx': 294.8399999999999,
#   'cordy': 104.0214000000002},
#  {'page': 4,
#   'text': '05/16/23',
#   'cordx': 382.6802169127999,
#   'cordy': 103.9014000000002},
#  {'page': 4,
#   'text': 'UT BCDO SPECIALTY DENTAL SER',
#   'cordx': 382.6802169128,
#   'cordy': 113.74162000000001},
#  {'page': 4, 'text': 'Payee:', 'cordx': 294.84, 'cordy': 115.30140000000006},
#  {'page': 4,
#   'text': 'Check No.:',
#   'cordx': 294.84,
#   'cordy': 125.02132000000006},
#  {'page': 4,
#   'text': '187889273',
#   'cordx': 382.6802169128,
#   'cordy': 124.90142000000003},
#  {'page': 4,
#   'text': 'Payment Amount:',
#   'cordx': 294.84,
#   'cordy': 134.02132000000006},
#  {'page': 4,
#   'text': '$472.00',
#   'cordx': 382.6802169128,
#   'cordy': 133.90142000000003},
#  {'page': 4,
#   'text': 'Patient Account No.:120371631',
#   'cordx': 225.83943376399998,
#   'cordy': 149.7411800000001},
#  {'page': 4,
#   'text': 'Claim Number:',
#   'cordx': 18.8398,
#   'cordy': 151.30140000000006},
#  {'page': 4,
#   'text': '27127F13500',
#   'cordx': 93.119811492,
#   'cordy': 151.18148000000008},
#  {'page': 4,
#   'text': 'Plan Number:00042176',
#   'cordx': 465.83932013599997,
#   'cordy': 151.9008980000001},
#  {'page': 4,
#   'text': 'Patient Name:',
#   'cordx': 18.8398,
#   'cordy': 160.30140000000006},
#  {'page': 4,
#   'text': 'FOSTER LARKIN',
#   'cordx': 93.119811492,
#   'cordy': 160.18148000000008},
#  {'page': 4,
#   'text': 'Employee Name:',
#   'cordx': 225.83943376399998,
#   'cordy': 160.3013800000001},
#  {'page': 4,
#   'text': 'DANIEL LARKIN',
#   'cordx': 315.119469344,
#   'cordy': 160.1809800000001},
#  {'page': 4,
#   'text': 'Relationship:',
#   'cordx': 465.83932013599997,
#   'cordy': 162.58102000000008},
#  {'page': 4,
#   'text': 'SON',
#   'cordx': 526.6794936904,
#   'cordy': 162.4610980000001},
#  {'page': 4,
#   'text': 'Planholder:',
#   'cordx': 18.119890666400067,
#   'cordy': 170.86109800000008},
#  {'page': 4,
#   'text': 'SPEED OF LIGHT OPS, LLC',
#   'cordx': 93.119811492,
#   'cordy': 170.74128000000007},
#  {'page': 4, 'text': 'Line ', 'cordx': 18.8398, 'cordy': 181.84859999999992},
#  {'page': 4, 'text': 'Submitted', 'cordx': 72.3602, 'cordy': 181.1286},
#  {'page': 4, 'text': 'Alt', 'cordx': 155.16029745327495, 'cordy': 181.1286},
#  {'page': 4, 'text': 'Tooth', 'cordx': 182.64, 'cordy': 181.1286},
#  {'page': 4, 'text': 'Date of', 'cordx': 224.64004397875, 'cordy': 181.1286},
#  {'page': 4,
#   'text': 'Submitted',
#   'cordx': 274.200203665775,
#   'cordy': 181.1286},
#  {'page': 4,
#   'text': 'Considered',
#   'cordx': 329.28052953777495,
#   'cordy': 181.1286},
#  {'page': 4,
#   'text': 'Covered',
#   'cordx': 390.48053231077495,
#   'cordy': 181.1286},
#  {'page': 4,
#   'text': 'Deductible',
#   'cordx': 437.64029467477496,
#   'cordy': 181.1286},
#  {'page': 4, 'text': 'Coverage', 'cordx': 490.680086151525, 'cordy': 181.1286},
#  {'page': 4, 'text': 'Benefit', 'cordx': 548.76, 'cordy': 181.1286},
#  {'page': 4,
#   'text': 'No.',
#   'cordx': 21.719875162250002,
#   'cordy': 190.96890999999994},
#  {'page': 4,
#   'text': 'ADA Codes/Description',
#   'cordx': 48.839863972500005,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'Code',
#   'cordx': 151.56030081277495,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'No.',
#   'cordx': 186.96031734874998,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'Service',
#   'cordx': 224.52012227327498,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'Charge',
#   'cordx': 279.120124551525,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'Charge',
#   'cordx': 336.12037743577497,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'Charge',
#   'cordx': 392.16061191977496,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'Amount',
#   'cordx': 442.320378138025,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'Percent',
#   'cordx': 493.919927428275,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'Amount',
#   'cordx': 547.1998391022499,
#   'cordy': 190.24851999999998},
#  {'page': 4,
#   'text': 'TOTALS',
#   'cordx': 223.08016135499994,
#   'cordy': 203.05517999999995},
#  {'page': 4, 'text': '299.00', 'cordx': 297.36, 'cordy': 202.72859999999991},
#  {'page': 4, 'text': '180.00', 'cordx': 355.08, 'cordy': 202.72859999999991},
#  {'page': 4,
#   'text': '180.00',
#   'cordx': 405.36005621339996,
#   'cordy': 202.72859999999991},
#  {'page': 4,
#   'text': '0.00',
#   'cordx': 499.080260925,
#   'cordy': 202.72850000000005},
#  {'page': 4, 'text': '180.00', 'cordx': 567.12, 'cordy': 202.72859999999991},
#  {'page': 4, 'text': ' ', 'cordx': 22.6801, 'cordy': 214.0086},
#  {'page': 4,
#   'text': 'BENEFIT SUMMARY',
#   'cordx': 444.59999176229996,
#   'cordy': 216.49490000000003},
#  {'page': 4,
#   'text': 'TOTAL BENEFIT PAYABLE.........',
#   'cordx': 389.4,
#   'cordy': 227.77499999999998},
#  {'page': 4, 'text': '$180.00', 'cordx': 561.36, 'cordy': 227.77499999999998},
#  {'page': 4,
#   'text': 'HIGHER ALLOWABLE..................',
#   'cordx': 389.39990019329997,
#   'cordy': 238.33517800000004},
#  {'page': 4,
#   'text': '$180.00',
#   'cordx': 561.3598578243,
#   'cordy': 239.05510000000004},
#  {'page': 4,
#   'text': 'PAID BY OTHER INSURANCE.....',
#   'cordx': 389.400042369,
#   'cordy': 248.05509999999992},
#  {'page': 4,
#   'text': '$0.00',
#   'cordx': 570.480336246,
#   'cordy': 250.33517999999992},
#  {'page': 4,
#   'text': 'ADJUSTMENTS...............................',
#   'cordx': 389.40004236899995,
#   'cordy': 259.3351799999999},
#  {'page': 4,
#   'text': '$0.00',
#   'cordx': 570.47297051154,
#   'cordy': 259.3351799999999},
#  {'page': 4,
#   'text': 'TOTAL BENEFIT PAID..................',
#   'cordx': 389.40004236899995,
#   'cordy': 270.49497999999994},
#  {'page': 4,
#   'text': '$ 180.00',
#   'cordx': 559.0761133032299,
#   'cordy': 270.49497999999994},
#  {'page': 4,
#   'text': "PATIENT'S RESPONSIBILITY.....",
#   'cordx': 389.40004236899995,
#   'cordy': 281.77508},
#  {'page': 4, 'text': '$0.00', 'cordx': 570.46919781828, 'cordy': 281.77508},
#  {'page': 4,
#   'text': 'Remarks for claim # 27127F13500:',
#   'cordx': 18.1199,
#   'cordy': 307.335},
#  {'page': 4,
#   'text': 'REIMBURSEMENT HAS BEEN DETERMINED USING A STRATOSE/TDA FEE SCHEDULE',
#   'cordx': 18.1199,
#   'cordy': 318.4948},
#  {'page': 4, 'text': 'Comments:', 'cordx': 18.1199, 'cordy': 342.4948},
#  {'page': 4,
#   'text': 'Current Dental Terminology © 2021 American Dental Association.  All rights reserved.',
#   'cordx': 18.1199,
#   'cordy': 351.25496},
#  {'page': 4,
#   'text': 'Log on to www.GuardianAnytime.com  for instant access to clinical policy guidelines and benefits information for Guardian members. Verify eligibility, view',
#   'cordx': 18.12017438699999,
#   'cordy': 363.255},
#  {'page': 4,
#   'text': 'benefits, check claim status and more!',
#   'cordx': 18.12017438699999,
#   'cordy': 372.255},
#  {'page': 4,
#   'text': '       721091B 2 FO 2           89203 VNE',
#   'cordx': 14.403799999999999,
#   'cordy': 9.182384986079}]

# %%
dfs = []
x2 = 0
y2 = 0
for text_d in text_list:
    x = text_d['cordx']
    y = text_d['cordy']
    if x2<x:
        x2 = text_d['cordx']
    if y2<y:
        y2 = text_d['cordy']    
x2 = x2+20
y2 = y2+20
print("YYYY", y2)
for i in range(len(text_list)):
    x1 = y1 = ''
    if 'Line' in text_list[i]['text']:
        print("Line", text_list[i]['text'])
        x1 = text_list[i]['cordx']
        y1 = text_list[i]['cordy']
        page_number = text_list[i]['page']
        for j in range(i,len(text_list)):
            
            if page_number == text_list[j]['page']:
                if 'BENEFIT SUMMARY' in text_list[j]['text']:
                    print("Bene", text_list[j]['text'])
                    print("PAG", text_list[j]['page'] )
                    page = int(text_list[j]['page'])
                    y2 = text_list[j]['cordy']
                    print(f"x1 = {x1}, y1 = {y1}, x2 = {x2}, y2 = {y2}")
                    tabula_dfs = tabula.read_pdf(pdf_path, guess=False, pages=page , stream=True, encoding="utf-8",
                                     area=(y1, x1, y2, x2), multiple_tables=True)
                    df_filled = tabula_dfs[0].fillna('')
                    dfs.append(df_filled[1:])
                    break
            
            if page_number == text_list[j]['page']:
                if '10 Hudson Yards' in text_list[j]['text']:
                    print("10 Hudson", text_list[j]['text'])
                    print("PAG", text_list[j]['page'] )
                    page = int(text_list[j]['page'])
                    y2 = text_list[j]['cordy']
                    print(f"x1 = {x1}, y1 = {y1}, x2 = {x2}, y2 = {y2}")
                    tabula_dfs = tabula.read_pdf(pdf_path, guess=False, pages=page , stream=True, encoding="utf-8",
                                     area=(y1, x1, y2, x2), multiple_tables=True)
                    df_filled = tabula_dfs[0].fillna('')
                    dfs.append(df_filled[1:])
                    break
                
            
            if page_number == text_list[j]['page']:
#                 if 'BENEFIT SUMMARY' not in text_list[j]['text'] and '10 Hudson Yards' not in text_list[j]['text']:
                if 'VNE' in text_list[j]['text']:
                    y2 = 780
                    page = int(text_list[j]['page'])
                    print(f"x1 = {x1}, y1 = {y1}, x2 = {x2}, y2 = {y2}")
                    tabula_dfs = tabula.read_pdf(pdf_path, guess=False, pages=page , stream=True, encoding="utf-8",
                                     area=(y1, x1, y2, x2), multiple_tables=True)
                    df_filled = tabula_dfs[0].fillna('')
                    dfs.append(df_filled[1:])
                    break
# Out:
# YYYY 783.9888
# Line Line
# Bene BENEFIT SUMMARY
# PAG 1
# x1 = 18.8398, y1 = 314.5686, x2 = 591.2001705475, y2 = 368.5348
# Got stderr: Jul 11, 2023 5:08:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Line Line
# 10 Hudson 10 Hudson Yards
# PAG 1
# x1 = 18.8398, y1 = 525.7686, x2 = 591.2001705475, y2 = 595.095
# Got stderr: Jul 11, 2023 5:08:13 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:13 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:13 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:13 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:13 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:13 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:13 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Line Line
# Bene BENEFIT SUMMARY
# PAG 3
# x1 = 18.8398, y1 = 181.84859999999992, x2 = 591.2001705475, y2 = 264.7348999999999
# Got stderr: Jul 11, 2023 5:08:13 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:14 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Line Line
# Bene BENEFIT SUMMARY
# PAG 3
# x1 = 18.8398, y1 = 421.9686, x2 = 591.2001705475, y2 = 514.4549
# Got stderr: Jul 11, 2023 5:08:14 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:14 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Line Line
# x1 = 18.8398, y1 = 671.6886, x2 = 591.2001705475, y2 = 780
# Got stderr: Jul 11, 2023 5:08:15 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:15 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Line Line
# Bene BENEFIT SUMMARY
# PAG 4
# x1 = 18.8398, y1 = 181.84859999999992, x2 = 591.2001705475, y2 = 216.49490000000003
# Got stderr: Jul 11, 2023 5:08:15 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jul 11, 2023 5:08:16 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn

# %%
print(len(dfs))
dfs[0]
# Out:
# 6
#   Line              Submitted   Alt Tooth   Date of Submitted.1 Considered  \
# 0  No.  ADA Codes/Description  Code   No.   Service      Charge     Charge
# 1    1    D0120/Periodic Eval          FM  05/11/23       39.00      23.00
# 2    2    D1206/Fluoride Varn          FM  05/11/23       36.00      15.00
# 3                                            TOTALS       75.00      38.00
#
#   Covered Deductible Coverage Benefit
# 0  Charge     Amount  Percent  Amount
# 1   23.00                100%   23.00
# 2   15.00                100%   15.00
# 3   38.00                0.00   38.00

# %%
dfs[1]
# Out:
#   Line              Submitted   Alt Tooth   Date of Submitted.1 Considered  \
# 0  No.  ADA Codes/Description  Code   No.   Service      Charge     Charge
# 1    1    D0120/Periodic Eval          FM  05/11/23       39.00      23.00
#
#   Covered Deductible Coverage Benefit
# 0  Charge     Amount  Percent  Amount
# 1   23.00                100%   23.00

# %%
dfs[2]
# Out:
#   Line              Submitted   Alt Tooth   Date of Submitted.1 Considered  \
# 0  No.  ADA Codes/Description  Code   No.   Service      Charge     Charge
# 1    2   D0240/Occlusal Image          FM  05/11/23       27.00      16.00
# 2    3   D0240/Occlusal Image          FM  05/11/23       27.00      16.00
# 3    4     D0272/Bitewing - 2          FM  05/11/23       36.00      22.00
# 4    5   D1120/Child Cleaning          FM  05/11/23       52.00      35.00
# 5    6    D1206/Fluoride Varn          FM  05/11/23       36.00      15.00
# 6                                            TOTALS      217.00     127.00
#
#   Covered Deductible Coverage Benefit
# 0  Charge     Amount  Percent  Amount
# 1   16.00                100%   16.00
# 2   16.00                100%   16.00
# 3   22.00                100%   22.00
# 4   35.00                100%   35.00
# 5   15.00                100%   15.00
# 6  127.00                0.00  127.00

# %%
dfs[3]
# Out:
#   Line              Submitted   Alt Tooth   Date of Submitted.1 Considered  \
# 0  No.  ADA Codes/Description  Code   No.   Service      Charge     Charge
# 1    1    D0120/Periodic Eval          FM  05/11/23       39.00      23.00
# 2    2   D0240/Occlusal Image          FM  05/11/23       27.00      16.00
# 3    3   D0240/Occlusal Image          FM  05/11/23       27.00      16.00
# 4    4     D0272/Bitewing - 2          FM  05/11/23       36.00      22.00
# 5    5   D1120/Child Cleaning          FM  05/11/23       52.00      35.00
# 6    6    D1206/Fluoride Varn          FM  05/11/23       36.00      15.00
# 7                                            TOTALS      217.00     127.00
#
#   Covered Deductible Coverage Benefit
# 0  Charge     Amount  Percent  Amount
# 1   23.00                100%   23.00
# 2   16.00                100%   16.00
# 3   16.00                100%   16.00
# 4   22.00                100%   22.00
# 5   35.00                100%   35.00
# 6   15.00                100%   15.00
# 7  127.00                0.00  127.00

# %%
dfs[4]
# Out:
#   Line              Submitted   Alt Tooth   Date of Submitted.1 Considered  \
# 0  No.  ADA Codes/Description  Code   No.   Service      Charge     Charge
# 1    1    D0120/Periodic Eval          FM  05/11/23       39.00      23.00
# 2    2     D0272/Bitewing - 2          FM  05/11/23       36.00      22.00
# 3    3   D1120/Child Cleaning          FM  05/11/23       52.00      35.00
# 4    4    D1206/Fluoride Varn          FM  05/11/23       36.00      15.00
# 5    5        D0330/Panoramic          FM  05/11/23       82.00      53.00
# 6    6   D0240/Occlusal Image          FM  05/11/23       27.00      16.00
# 7    7   D0240/Occlusal Image          FM  05/11/23       27.00      16.00
#
#   Covered Deductible Coverage Benefit
# 0  Charge     Amount  Percent  Amount
# 1   23.00                100%   23.00
# 2   22.00                100%   22.00
# 3   35.00                100%   35.00
# 4   15.00                100%   15.00
# 5   53.00                100%   53.00
# 6   16.00                100%   16.00
# 7   16.00                100%   16.00

# %%
dfs[5]
# Out:
#   Line              Submitted   Alt Tooth  Date of Submitted.1 Considered  \
# 0  No.  ADA Codes/Description  Code   No.  Service      Charge     Charge
# 1                                           TOTALS      299.00     180.00
#
#   Covered Deductible Coverage Benefit
# 0  Charge     Amount  Percent  Amount
# 1  180.00                0.00  180.00

# %%
search_string = 'TOTALS'
final = []
stack_list = []
for d in dfs:
    last_row = d.iloc[-1]
    col = last_row[4]
    
    print(col)
    print(type(col))
    if 'TOTALS' in col:
        print("In the if")
        if stack_list:
            new_df = pd.concat(stack_list + [d] , axis=0)
            final.append(new_df)
            stack_list = []
        else:
            final.append(d)    
    else:
        stack_list.append(d)

        
        
#  if is_date_format is False:
#                 if stack_list:
#                     new_df = pd.concat(stack_list + [df] , axis=0)
#                     final_list.append(new_df)
#                     stack_list = []
#                 else:
#                     final_list.append(df)
#             else:
#                 stack_list.append(df)
# Out:
# TOTALS
# <class 'str'>
# In the if
# 05/11/23
# <class 'str'>
# TOTALS
# <class 'str'>
# In the if
# TOTALS
# <class 'str'>
# In the if
# 05/11/23
# <class 'str'>
# TOTALS
# <class 'str'>
# In the if

# %%
print(len(final))
# Out:
# 4

# %%
final[1]
# Out:
#   Line              Submitted   Alt Tooth   Date of Submitted.1 Considered  \
# 0  No.  ADA Codes/Description  Code   No.   Service      Charge     Charge
# 1    1    D0120/Periodic Eval          FM  05/11/23       39.00      23.00
# 0  No.  ADA Codes/Description  Code   No.   Service      Charge     Charge
# 1    2   D0240/Occlusal Image          FM  05/11/23       27.00      16.00
# 2    3   D0240/Occlusal Image          FM  05/11/23       27.00      16.00
# 3    4     D0272/Bitewing - 2          FM  05/11/23       36.00      22.00
# 4    5   D1120/Child Cleaning          FM  05/11/23       52.00      35.00
# 5    6    D1206/Fluoride Varn          FM  05/11/23       36.00      15.00
# 6                                            TOTALS      217.00     127.00
#
#   Covered Deductible Coverage Benefit
# 0  Charge     Amount  Percent  Amount
# 1   23.00                100%   23.00
# 0  Charge     Amount  Percent  Amount
# 1   16.00                100%   16.00
# 2   16.00                100%   16.00
# 3   22.00                100%   22.00
# 4   35.00                100%   35.00
# 5   15.00                100%   15.00
# 6  127.00                0.00  127.00

# %%
tdfs =[]

for df in dfs:
    df = df[~df.apply(lambda row: row.astype(str).str.contains('TOTALS', case=False)).any(axis=1)]
    df.rename(columns={'Date of': 'Date'}, inplace=True)
    df.fillna('', inplace=True)
    df.drop('Line', axis=1, inplace=True)
    tdfs.append(df)

# %%
new_dict = []
for td in tdfs:
    tab = td.to_dict(orient='records')
    for i in range(len(tab)):
        new_dict.append(tab[i])
    
#     new_dict.append(td.to_dict(orient='records'))

# %%
nd = new_dict
nd
# Out:
# [{'Submitted': 'D0120/Periodic Eval',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '39.00',
#   'Considered': '23.00',
#   'Covered': '23.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '23.00'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '36.00',
#   'Considered': '15.00',
#   'Covered': '15.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '15.00'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '39.00',
#   'Considered': '23.00',
#   'Covered': '23.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '23.00'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '27.00',
#   'Considered': '16.00',
#   'Covered': '16.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '16.00'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '27.00',
#   'Considered': '16.00',
#   'Covered': '16.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '16.00'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '36.00',
#   'Considered': '22.00',
#   'Covered': '22.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '22.00'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '52.00',
#   'Considered': '35.00',
#   'Covered': '35.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '35.00'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '36.00',
#   'Considered': '15.00',
#   'Covered': '15.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '15.00'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '39.00',
#   'Considered': '23.00',
#   'Covered': '23.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '23.00'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '27.00',
#   'Considered': '16.00',
#   'Covered': '16.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '16.00'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '27.00',
#   'Considered': '16.00',
#   'Covered': '16.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '16.00'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '36.00',
#   'Considered': '22.00',
#   'Covered': '22.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '22.00'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '52.00',
#   'Considered': '35.00',
#   'Covered': '35.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '35.00'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '36.00',
#   'Considered': '15.00',
#   'Covered': '15.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '15.00'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '39.00',
#   'Considered': '23.00',
#   'Covered': '23.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '23.00'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '36.00',
#   'Considered': '22.00',
#   'Covered': '22.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '22.00'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '52.00',
#   'Considered': '35.00',
#   'Covered': '35.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '35.00'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '36.00',
#   'Considered': '15.00',
#   'Covered': '15.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '15.00'},
#  {'Submitted': 'D0330/Panoramic',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '82.00',
#   'Considered': '53.00',
#   'Covered': '53.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '53.00'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '27.00',
#   'Considered': '16.00',
#   'Covered': '16.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '16.00'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'Alt': '',
#   'Tooth': 'FM',
#   'Date': '05/11/23',
#   'Submitted.1': '27.00',
#   'Considered': '16.00',
#   'Covered': '16.00',
#   'Deductible': '',
#   'Coverage': '100%',
#   'Benefit': '16.00'}]

# %%
tab_dict = []

change_keys = [("Alt","AltCode"),("Tooth", "ToothNo"),("Date", "ServiceDate"), ("Submitted.1", "SubmittedCharges"),
               ("Benefit", "PayableAmount"), ("Considered", "ActualAllowed"),
               ("Deductible", "ContractualObligations"),("Covered", "CoveredCharge"),("Coverage", "CoveragePercent")]
for d in new_dict:
    for k in change_keys:
        old_key = k[0]
        new_key = k[1]
        value = d[old_key]
        d[new_key] = value
        
        
    for k in change_keys:
        del d[k[0]]
    print("D",d)
    tab_dict.append(d)
# Out:
# D {'Submitted': 'D0120/Periodic Eval', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '39.00', 'PayableAmount': '23.00', 'ActualAllowed': '23.00', 'ContractualObligations': '', 'CoveredCharge': '23.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1206/Fluoride Varn', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '36.00', 'PayableAmount': '15.00', 'ActualAllowed': '15.00', 'ContractualObligations': '', 'CoveredCharge': '15.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0120/Periodic Eval', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '39.00', 'PayableAmount': '23.00', 'ActualAllowed': '23.00', 'ContractualObligations': '', 'CoveredCharge': '23.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0240/Occlusal Image', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '27.00', 'PayableAmount': '16.00', 'ActualAllowed': '16.00', 'ContractualObligations': '', 'CoveredCharge': '16.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0240/Occlusal Image', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '27.00', 'PayableAmount': '16.00', 'ActualAllowed': '16.00', 'ContractualObligations': '', 'CoveredCharge': '16.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0272/Bitewing - 2', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '36.00', 'PayableAmount': '22.00', 'ActualAllowed': '22.00', 'ContractualObligations': '', 'CoveredCharge': '22.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1120/Child Cleaning', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '52.00', 'PayableAmount': '35.00', 'ActualAllowed': '35.00', 'ContractualObligations': '', 'CoveredCharge': '35.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1206/Fluoride Varn', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '36.00', 'PayableAmount': '15.00', 'ActualAllowed': '15.00', 'ContractualObligations': '', 'CoveredCharge': '15.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0120/Periodic Eval', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '39.00', 'PayableAmount': '23.00', 'ActualAllowed': '23.00', 'ContractualObligations': '', 'CoveredCharge': '23.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0240/Occlusal Image', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '27.00', 'PayableAmount': '16.00', 'ActualAllowed': '16.00', 'ContractualObligations': '', 'CoveredCharge': '16.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0240/Occlusal Image', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '27.00', 'PayableAmount': '16.00', 'ActualAllowed': '16.00', 'ContractualObligations': '', 'CoveredCharge': '16.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0272/Bitewing - 2', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '36.00', 'PayableAmount': '22.00', 'ActualAllowed': '22.00', 'ContractualObligations': '', 'CoveredCharge': '22.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1120/Child Cleaning', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '52.00', 'PayableAmount': '35.00', 'ActualAllowed': '35.00', 'ContractualObligations': '', 'CoveredCharge': '35.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1206/Fluoride Varn', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '36.00', 'PayableAmount': '15.00', 'ActualAllowed': '15.00', 'ContractualObligations': '', 'CoveredCharge': '15.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0120/Periodic Eval', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '39.00', 'PayableAmount': '23.00', 'ActualAllowed': '23.00', 'ContractualObligations': '', 'CoveredCharge': '23.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0272/Bitewing - 2', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '36.00', 'PayableAmount': '22.00', 'ActualAllowed': '22.00', 'ContractualObligations': '', 'CoveredCharge': '22.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1120/Child Cleaning', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '52.00', 'PayableAmount': '35.00', 'ActualAllowed': '35.00', 'ContractualObligations': '', 'CoveredCharge': '35.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D1206/Fluoride Varn', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '36.00', 'PayableAmount': '15.00', 'ActualAllowed': '15.00', 'ContractualObligations': '', 'CoveredCharge': '15.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0330/Panoramic', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '82.00', 'PayableAmount': '53.00', 'ActualAllowed': '53.00', 'ContractualObligations': '', 'CoveredCharge': '53.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0240/Occlusal Image', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '27.00', 'PayableAmount': '16.00', 'ActualAllowed': '16.00', 'ContractualObligations': '', 'CoveredCharge': '16.00', 'CoveragePercent': '100%'}
# D {'Submitted': 'D0240/Occlusal Image', 'AltCode': '', 'ToothNo': 'FM', 'ServiceDate': '05/11/23', 'SubmittedCharges': '27.00', 'PayableAmount': '16.00', 'ActualAllowed': '16.00', 'ContractualObligations': '', 'CoveredCharge': '16.00', 'CoveragePercent': '100%'}

# %%
tab_dict
# Out:
# [{'Submitted': 'D0120/Periodic Eval',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '39.00',
#   'PayableAmount': '23.00',
#   'ActualAllowed': '23.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '23.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '36.00',
#   'PayableAmount': '15.00',
#   'ActualAllowed': '15.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '15.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '39.00',
#   'PayableAmount': '23.00',
#   'ActualAllowed': '23.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '23.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '27.00',
#   'PayableAmount': '16.00',
#   'ActualAllowed': '16.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '16.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '27.00',
#   'PayableAmount': '16.00',
#   'ActualAllowed': '16.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '16.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '36.00',
#   'PayableAmount': '22.00',
#   'ActualAllowed': '22.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '22.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '52.00',
#   'PayableAmount': '35.00',
#   'ActualAllowed': '35.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '35.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '36.00',
#   'PayableAmount': '15.00',
#   'ActualAllowed': '15.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '15.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '39.00',
#   'PayableAmount': '23.00',
#   'ActualAllowed': '23.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '23.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '27.00',
#   'PayableAmount': '16.00',
#   'ActualAllowed': '16.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '16.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '27.00',
#   'PayableAmount': '16.00',
#   'ActualAllowed': '16.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '16.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '36.00',
#   'PayableAmount': '22.00',
#   'ActualAllowed': '22.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '22.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '52.00',
#   'PayableAmount': '35.00',
#   'ActualAllowed': '35.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '35.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '36.00',
#   'PayableAmount': '15.00',
#   'ActualAllowed': '15.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '15.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0120/Periodic Eval',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '39.00',
#   'PayableAmount': '23.00',
#   'ActualAllowed': '23.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '23.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0272/Bitewing - 2',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '36.00',
#   'PayableAmount': '22.00',
#   'ActualAllowed': '22.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '22.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1120/Child Cleaning',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '52.00',
#   'PayableAmount': '35.00',
#   'ActualAllowed': '35.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '35.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D1206/Fluoride Varn',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '36.00',
#   'PayableAmount': '15.00',
#   'ActualAllowed': '15.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '15.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0330/Panoramic',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '82.00',
#   'PayableAmount': '53.00',
#   'ActualAllowed': '53.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '53.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '27.00',
#   'PayableAmount': '16.00',
#   'ActualAllowed': '16.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '16.00',
#   'CoveragePercent': '100%'},
#  {'Submitted': 'D0240/Occlusal Image',
#   'AltCode': '',
#   'ToothNo': 'FM',
#   'ServiceDate': '05/11/23',
#   'SubmittedCharges': '27.00',
#   'PayableAmount': '16.00',
#   'ActualAllowed': '16.00',
#   'ContractualObligations': '',
#   'CoveredCharge': '16.00',
#   'CoveragePercent': '100%'}]

# %%
# dfs = []
# x2 = 0
# for text_d in text_list:
#     x = text_d['cordx']
#     if x2<x:
#         x2 = text_d['cordx']
# x2 = x2+20      
# for i in range(len(text_list)):
#     x1 = y1 = y2 = ''
#     if 'Line' in text_list[i]['text']:
#         print("Line", text_list[i]['text'])
#         x1 = text_list[i]['cordx']
#         y1 = text_list[i]['cordy']
#         page_number = text_list[i]['page'])
#         for j in range(i,len(text_list)):
#             if 'BENEFIT SUMMARY' in text_list[j]['text']:
#                 print("Bene", text_list[j]['text'])
#                 page = int(text_list[j]['page'])
#                 y2 = text_list[j]['cordy']
#                 print(f"x1 = {x1}, y1 = {y1}, x2 = {x2}, y2 = {y2}")
#                 tabula_dfs = tabula.read_pdf(pdf_path, guess=False, pages=page , stream=True, encoding="utf-8",
#                                  area=(y1, x1, y2, x2), multiple_tables=True)
#                 dfs.append(tabula_dfs[0])
                
#                 break
